# %% [markdown]
# <a href="https://colab.research.google.com/github/aalling93/ENGR562_CNN/blob/master/NocelStudyOfCNN.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # CNN MODEL
#
# This notebook illustrates the usages of the theory from (...)

# %% [markdown]
# ## Initialization
# Firstly, install needed packages and check for version.
#
#
# GO TO https://medium.com/nybles/create-your-first-image-recognition-classifier-using-cnn-keras-and-tensorflow-backend-6eaab98d14dd
#
# and
#
#
# https://towardsdatascience.com/cnn-architectures-a-deep-dive-a99441d18049

# %%
#! pip install torch
#! pip install torchvision
#! pip install pandas==0.23.4
#! pip install geopandas
#! pip install keras
#! pip install tensorflow
#! pip install tf-nightly
#! pip install ggplot

try:
  # %tensorflow_version only exists in Colab.
  # %tensorflow_version 2.x
except Exception:
  pass

from __future__ import absolute_import, division, print_function, unicode_literals
# TensorFlow and tf.keras
import tensorflow as tf
from tensorflow import keras
from keras import regularizers
# Helper libraries
import numpy as np
import matplotlib.pyplot as plt
from tensorflow.keras.datasets import cifar10
from tensorflow.keras.preprocessing.image import ImageDataGenerator
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Dense, Dropout, Activation, Flatten, BatchNormalization
from tensorflow.keras.layers import Conv2D, MaxPooling2D
import os
#To visualize it..
from tensorflow.keras.utils import plot_model
from IPython.display import SVG
from tensorflow.keras.utils import model_to_dot

print(tf.__version__)
# Out:
# TensorFlow 2.x selected.
# 2.0.0
# Using TensorFlow backend.

# %%
# FUNCTIONS
import numpy as np
import time
import matplotlib.pyplot as plt
from __future__ import print_function
from sklearn import svm, datasets
from sklearn.model_selection import train_test_split
from sklearn.metrics import confusion_matrix
from sklearn.utils.multiclass import unique_labels
from PIL import Image as pil_image
from tensorflow.keras.preprocessing.image import save_img
from tensorflow.keras import layers
from tensorflow.keras.applications import vgg16
from tensorflow.keras import backend as K

def plot_confusion_matrix(y_true, y_pred, classes,
                          normalize=False,
                          title=None,
                          cmap=plt.cm.Blues,want_title=None):
    """
    This function prints and plots the confusion matrix. Noting more... It uses the sklearn lib.
    Normalization can be applied by setting `normalize=True`.
    """
    #making title.. (for my article, i dont want then, thus the want_title)
    if not title:
        if normalize:
            title = 'Normalized confusion matrix'
        else:
            title = 'Confusion matrix, without normalization'

    # Compute confusion matrix
    cm = confusion_matrix(y_true, y_pred)
    # Only use the labels that appear in the data
    classes = classes[unique_labels(y_true, y_pred)]
    if normalize:
        cm = cm.astype('float') / cm.sum(axis=1)[:, np.newaxis]
        print("Normalized confusion matrix")
    else:
        print('Confusion matrix, without normalization')

    print(cm)

    fig, ax = plt.subplots(figsize=(6,6))
    im = ax.imshow(cm, interpolation='nearest', cmap=cmap)
    ax.figure.colorbar(im, ax=ax)
    
    # We want to show all ticks...
    if want_title!= None:
      ax.set(xticks=np.arange(cm.shape[1]),
             yticks=np.arange(cm.shape[0]),
             # ... and label them with the respective list entries
             xticklabels=classes, yticklabels=classes,
             title=title,
             ylabel='True label',
             xlabel='Predicted label')
    else:
      ax.set(xticks=np.arange(cm.shape[1]),
             yticks=np.arange(cm.shape[0]),
             # ... and label them with the respective list entries
             xticklabels=classes, yticklabels=classes,
             ylabel='True label',
             xlabel='Predicted label')        

    # Rotate the tick labels and set their alignment.
    plt.setp(ax.get_xticklabels(), rotation=45, ha="right",
             rotation_mode="anchor")
    # I dont want the actualy probabilities in the plot, since its meassy when exporting to latex. 
    # but, for examinations it's fine. 
    """
    Loop over data dimensions and create text annotations.
    fmt = '.2f' if normalize else 'd'
    thresh = cm.max() / 2.
    for i in range(cm.shape[0]):
        for j in range(cm.shape[1]):
            ax.text(j, i, format(cm[i, j], fmt),
                    ha="center", va="center",
                    color="white" if cm[i, j] > thresh else "black")
    fig.tight_layout()
    """
    return ax

# %% [markdown]
# ## Importing a dataset
#
# Here, im important a dataset from keras pre-defined data sets, see https://keras.io/datasets/
#
# The CIFAR10 dataset:
# Dataset of 50,000 32x32 color training images, labeled over 10 categories, and 10,000 test images. It is thus good for illustrating pupose of a CNN. https://www.cs.toronto.edu/~kriz/cifar.html
#
# The images are uint8 array of RGB image data with shape (num_samples, 3, 32, 32) or (num_samples, 32, 32, 3) based on the image_data_format backend setting of either
# Since the dataset is predefined in Keras, it can do the labelling. Otherwise classes must be defined>

# %%
#loading the set directly from keras bucket.
cifar100 = tf.keras.datasets.cifar100
#defining training(test) data and its labels. The data, split between train and test sets:
(x_train, y_train), (x_test, y_test) = cifar10.load_data()
#see a bit of stats..
print('x_train shape:', x_train.shape)
print(x_train.shape[0], 'train samples')
print(x_test.shape[0], 'test samples')
# The data is already labbeled.. Othervise, define into classes like:
# class_names = ['dolphin', 'dog', 'cat', 'mouse', 'ape',  '...']
# Out:
# x_train shape: (50000, 32, 32, 3)
# 50000 train samples
# 10000 test samples

# %% [markdown]
# ## Preparing the model

# %%
# Convert class vectors to binary class matrices.
num_classes = 10 #from 100 to 10 classes....# in the CIFAR10 theres 10 classes extracted from the CIFAR100 dataset..
y_test_scivit = np.squeeze(np.copy(y_test)) #used for confusin matrix in scilearn lib. AFTER predictions are made...
y_train = tf.keras.utils.to_categorical(y_train, num_classes)
y_test = tf.keras.utils.to_categorical(y_test, num_classes)

# %% [markdown]
# Here, the defined test data can be used to evaluate the model using the error function described in the theory. It could be applied as K-fold, leave-on-out or even a cross validation (take hella long time tho).
#
# ## Exploring the classes

# %%
plt.figure()
plt.imshow(x_train[3])
plt.colorbar()
plt.grid(False)
plt.show()

# %% [markdown]
# ## Building the CNN
# layers, as described in the theory can now be added to the model
# see https://towardsdatascience.com/building-a-convolutional-neural-network-cnn-in-keras-329fbbadc5f5

# %% [markdown]
# ### Defining Hyper parameters
#
# Hyper parameters to control the size of the output of CNN layer. Depth, stride and zero padding..

# %%
#filter size
filter_size = 5
#If padding isnt the deafult, this value should be used (now keras defult is used..)
padding  = (filter_size-1)/2
filter_size = (filter_size,filter_size)
# Stride controls the "overlap" between neighoboring convolutions. For sattellite image, a strid of e.g. 10 is smart . This reduces the dimension.. If stride=1, we move filter one pixel at a time. 
# atm, keras deafult is used = the same size as pooling.. 
stride = 3 
#depth is number of neurons(filters) in the given layer connected to the input (either original img or feature img).
filters_first_layer = 32 #currencty, this value is also used for other layers..
# Epoch is the number each batch is trained
epoch=200
#Using batch learning as in the theory
batch_size = 1000
#num_predictions = 20

# %% [markdown]
# ### Making model

# %%
#------------------------ BUILING THE MODEL ------------------------------------
# Initializing the model using Sequntial(), The Sequential model is a linear stack of layers. https://keras.io/getting-started/sequential-model-guide/
model = Sequential()
#adding a convolutional layer, https://keras.io/layers/convolutional/
model.add(Conv2D(filters_first_layer, filter_size, padding='same',input_shape=x_train.shape[1:]))
#adding activation function
model.add(Activation('relu'))
#adding Maxpooling as described in the theory and https://keras.io/layers/pooling/. Default stride is the same as pool..
#regularization, https://keras.io/layers/core/
model.add(Dropout(0.1))
#this "block" of layers (convolutional layer, activation, pooling and regularization) can now be applied a number of times.... i.e copy pastye..
# ---- 2nd block
model.add(Conv2D(filters_first_layer*4, filter_size))
model.add(Activation('relu'))
model.add(BatchNormalization())
model.add(MaxPooling2D(pool_size=(2, 2)))
# --- 3rd block -------
model.add(Conv2D(filters_first_layer*6, filter_size, padding='same'))
model.add(Activation('relu'))
model.add(BatchNormalization())
# --- 4rd block -------
model.add(Conv2D(filters_first_layer*8, filter_size, padding='same'))
model.add(Activation('relu'))
model.add(BatchNormalization())
model.add(MaxPooling2D(pool_size=(2, 2)))
model.add(Dropout(0.1))
# --- 5rd block -------
model.add(Conv2D(filters_first_layer*8, filter_size, padding='same'))
model.add(Activation('relu'))
model.add(BatchNormalization())
model.add(MaxPooling2D(pool_size=(2, 2)))
model.add(Dropout(0.1))
# ---6th block -------
model.add(Conv2D(filters_first_layer*2, filter_size, padding='same'))
model.add(Activation('relu'))
model.add(BatchNormalization())
model.add(MaxPooling2D(pool_size=(2, 2)))
model.add(Dropout(0.1))
#Flattens the input. Does not affect the batch size needed for FC... see https://medium.com/nybles/create-your-first-image-recognition-classifier-using-cnn-keras-and-tensorflow-backend-6eaab98d14dd
model.add(Flatten())
#Just your regular densely-connected NN layer, i.e. the FC...adding different weight regularizers. Lastly,activation function to classify...
model.add(Dense(10, kernel_regularizer=regularizers.l2(0.0005),bias_regularizer=regularizers.l2(0.001),activity_regularizer=regularizers.l2(0.001),activation='softmax',use_bias=False))
#model.add(Dense(10, activation='softmax',use_bias=False))

# %% [markdown]
# ## Training the model

# %% [markdown]
# ### Define back propagation optimizer and loss function.
# In the theory, the equation for the Gradient Descent is explained. This is optimizer is used with the loss of cross entropy.
#
# Recall. Gradient descent applied to a batch is called mini-batch learning.
#
#
# Optimizer: https://keras.io/optimizers/.
#
# Loss function: https://keras.io/losses/.

# %%
# an optimizer is required to train a keras model, https://keras.io/optimizers/. As described in the theory, as GRADIENT DESCENT is used here..
#  The loss function is here defined, https://keras.io/losses/. In the theory, the kullback_leibler_divergence and cross entropy..  Since classes are integer, sparse_categorical_crossentropy is used
optimizer = keras.optimizers.SGD(lr=0.0001)
model.compile(loss='categorical_crossentropy',optimizer=optimizer,metrics=['accuracy'])
print("Showing sizes of datasets..")
print(x_train.shape,y_train.shape,x_test.shape,y_test.shape)
# Out:
# Showing sizes of datasets..
# (50000, 32, 32, 3) (50000, 10) (10000, 32, 32, 3) (10000, 10)

# %% [markdown]
# In illustation of the data, we saw the scale on the colour plot. This is scalled to [0,1] before its used to fit the model.

# %%
#Scaling the data from [0:255] to [0:1]..
x_test = x_test.astype('float32')
x_train = x_train.astype('float32')
x_train /= 255
x_test /= 255

# %% [markdown]
# ### Fitting the model:
# Using the model of the CNN, the model is not TRAINED using the labels.
# - the batch size is used (how many feature maps in one batch)
# - the epochs are used (how many times a batch is trained)
# Moreover, the training data is used (data and labels) to train, and is validated on the test data (data and labels)

# %%
#https://keras.io/models/sequential/
# History is used to track the changed for plotting..
history = model.fit(x_train, y_train,batch_size=batch_size,epochs=epoch, validation_data=(x_test, y_test),shuffle=True)
# Out:
# Train on 50000 samples, validate on 10000 samples
# Epoch 1/200
# 50000/50000 [==============================] - 34s 680us/sample - loss: 3.1830 - accuracy: 0.1278 - val_loss: 2.3499 - val_accuracy: 0.1000
# Epoch 2/200
# 50000/50000 [==============================] - 20s 405us/sample - loss: 2.6805 - accuracy: 0.1737 - val_loss: 2.4577 - val_accuracy: 0.1000
# Epoch 3/200
# 50000/50000 [==============================] - 20s 409us/sample - loss: 2.4965 - accuracy: 0.2009 - val_loss: 2.6021 - val_accuracy: 0.1000
# Epoch 4/200
# 50000/50000 [==============================] - 21s 410us/sample - loss: 2.3854 - accuracy: 0.2204 - val_loss: 2.7447 - val_accuracy: 0.1000
# Epoch 5/200
# 50000/50000 [==============================] - 21s 416us/sample - loss: 2.3129 - accuracy: 0.2383 - val_loss: 2.8523 - val_accuracy: 0.0997
# Epoch 6/200
# 50000/50000 [==============================] - 21s 420us/sample - loss: 2.2548 - accuracy: 0.2499 - val_loss: 2.9178 - val_accuracy: 0.0988
# Epoch 7/200
# 50000/50000 [==============================] - 21s 424us/sample - loss: 2.2120 - accuracy: 0.2583 - val_loss: 2.9304 - val_accuracy: 0.0962
# Epoch 8/200
# 50000/50000 [==============================] - 21s 426us/sample - loss: 2.1725 - accuracy: 0.2693 - val_loss: 2.8771 - val_accuracy: 0.0982
# Epoch 9/200
# 50000/50000 [==============================] - 21s 429us/sample - loss: 2.1470 - accuracy: 0.2719 - val_loss: 2.7744 - val_accuracy: 0.1030
# Epoch 10/200
# 50000/50000 [==============================] - 22s 431us/sample - loss: 2.1031 - accuracy: 0.2846 - val_loss: 2.6432 - val_accuracy: 0.1212
# Epoch 11/200
# 50000/50000 [==============================] - 22s 431us/sample - loss: 2.0840 - accuracy: 0.2907 - val_loss: 2.4772 - val_accuracy: 0.1495
# Epoch 12/200
# 50000/50000 [==============================] - 22s 431us/sample - loss: 2.0649 - accuracy: 0.2933 - val_loss: 2.3209 - val_accuracy: 0.1865
# Epoch 13/200
# 50000/50000 [==============================] - 22s 432us/sample - loss: 2.0394 - accuracy: 0.3010 - val_loss: 2.2253 - val_accuracy: 0.2115
# Epoch 14/200
# 50000/50000 [==============================] - 22s 432us/sample - loss: 2.0204 - accuracy: 0.3047 - val_loss: 2.1284 - val_accuracy: 0.2371
# Epoch 15/200
# 50000/50000 [==============================] - 22s 432us/sample - loss: 2.0038 - accuracy: 0.3075 - val_loss: 2.0635 - val_accuracy: 0.2564
# Epoch 16/200
# 50000/50000 [==============================] - 22s 432us/sample - loss: 1.9837 - accuracy: 0.3142 - val_loss: 2.0443 - val_accuracy: 0.2639
# Epoch 17/200
# 50000/50000 [==============================] - 22s 432us/sample - loss: 1.9626 - accuracy: 0.3198 - val_loss: 2.0147 - val_accuracy: 0.2747
# Epoch 18/200
# 50000/50000 [==============================] - 22s 431us/sample - loss: 1.9525 - accuracy: 0.3218 - val_loss: 1.9743 - val_accuracy: 0.2846
# Epoch 19/200
# 50000/50000 [==============================] - 22s 432us/sample - loss: 1.9367 - accuracy: 0.3245 - val_loss: 1.9644 - val_accuracy: 0.2892
# Epoch 20/200
# 50000/50000 [==============================] - 22s 432us/sample - loss: 1.9307 - accuracy: 0.3312 - val_loss: 1.9601 - val_accuracy: 0.2897
# Epoch 21/200
# 50000/50000 [==============================] - 22s 431us/sample - loss: 1.9188 - accuracy: 0.3337 - val_loss: 1.9454 - val_accuracy: 0.2962
# Epoch 22/200
# 50000/50000 [==============================] - 22s 431us/sample - loss: 1.9005 - accuracy: 0.3371 - val_loss: 1.9307 - val_accuracy: 0.3010
# Epoch 23/200
# 50000/50000 [==============================] - 22s 431us/sample - loss: 1.8913 - accuracy: 0.3407 - val_loss: 1.9316 - val_accuracy: 0.3002
# Epoch 24/200
# 50000/50000 [==============================] - 22s 431us/sample - loss: 1.8838 - accuracy: 0.3401 - val_loss: 1.9028 - val_accuracy: 0.3088
# Epoch 25/200
# 50000/50000 [==============================] - 22s 432us/sample - loss: 1.8673 - accuracy: 0.3478 - val_loss: 1.8924 - val_accuracy: 0.3153
# Epoch 26/200
# 50000/50000 [==============================] - 22s 432us/sample - loss: 1.8527 - accuracy: 0.3501 - val_loss: 1.8757 - val_accuracy: 0.3202
# Epoch 27/200
# 50000/50000 [==============================] - 22s 432us/sample - loss: 1.8474 - accuracy: 0.3503 - val_loss: 1.8682 - val_accuracy: 0.3241
# Epoch 28/200
# 50000/50000 [==============================] - 22s 433us/sample - loss: 1.8331 - accuracy: 0.3559 - val_loss: 1.8533 - val_accuracy: 0.3272
# Epoch 29/200
# 50000/50000 [==============================] - 22s 432us/sample - loss: 1.8281 - accuracy: 0.3631 - val_loss: 1.8695 - val_accuracy: 0.3227
# Epoch 30/200
# 50000/50000 [==============================] - 22s 431us/sample - loss: 1.8181 - accuracy: 0.3633 - val_loss: 1.8535 - val_accuracy: 0.3271
# Epoch 31/200
# 50000/50000 [==============================] - 22s 431us/sample - loss: 1.8180 - accuracy: 0.3617 - val_loss: 1.8532 - val_accuracy: 0.3257
# Epoch 32/200
# 50000/50000 [==============================] - 22s 432us/sample - loss: 1.8007 - accuracy: 0.3656 - val_loss: 1.8341 - val_accuracy: 0.3344
# Epoch 33/200
# 50000/50000 [==============================] - 22s 432us/sample - loss: 1.7886 - accuracy: 0.3706 - val_loss: 1.8247 - val_accuracy: 0.3369
# Epoch 34/200
# 50000/50000 [==============================] - 22s 432us/sample - loss: 1.7875 - accuracy: 0.3720 - val_loss: 1.8149 - val_accuracy: 0.3398
# Epoch 35/200
# 50000/50000 [==============================] - 22s 431us/sample - loss: 1.7769 - accuracy: 0.3761 - val_loss: 1.8014 - val_accuracy: 0.3469
# Epoch 36/200
# 50000/50000 [==============================] - 22s 432us/sample - loss: 1.7732 - accuracy: 0.3769 - val_loss: 1.8055 - val_accuracy: 0.3453
# Epoch 37/200
# 50000/50000 [==============================] - 22s 432us/sample - loss: 1.7627 - accuracy: 0.3789 - val_loss: 1.7968 - val_accuracy: 0.3470
# Epoch 38/200
# 50000/50000 [==============================] - 22s 431us/sample - loss: 1.7517 - accuracy: 0.3811 - val_loss: 1.7919 - val_accuracy: 0.3477
# Epoch 39/200
# 50000/50000 [==============================] - 22s 432us/sample - loss: 1.7493 - accuracy: 0.3825 - val_loss: 1.7874 - val_accuracy: 0.3485
# Epoch 40/200
# 50000/50000 [==============================] - 22s 431us/sample - loss: 1.7414 - accuracy: 0.3851 - val_loss: 1.7903 - val_accuracy: 0.3491
# Epoch 41/200
# 50000/50000 [==============================] - 22s 432us/sample - loss: 1.7349 - accuracy: 0.3829 - val_loss: 1.7726 - val_accuracy: 0.3569
# Epoch 42/200
# 50000/50000 [==============================] - 22s 432us/sample - loss: 1.7247 - accuracy: 0.3913 - val_loss: 1.7609 - val_accuracy: 0.3612
# Epoch 43/200
# 50000/50000 [==============================] - 22s 431us/sample - loss: 1.7202 - accuracy: 0.3908 - val_loss: 1.7499 - val_accuracy: 0.3641
# Epoch 44/200
# 50000/50000 [==============================] - 22s 431us/sample - loss: 1.7205 - accuracy: 0.3917 - val_loss: 1.7408 - val_accuracy: 0.3659
# Epoch 45/200
# 50000/50000 [==============================] - 22s 431us/sample - loss: 1.7095 - accuracy: 0.3961 - val_loss: 1.7332 - val_accuracy: 0.3715
# Epoch 46/200
# 50000/50000 [==============================] - 22s 431us/sample - loss: 1.7067 - accuracy: 0.3944 - val_loss: 1.7351 - val_accuracy: 0.3710
# Epoch 47/200
# 50000/50000 [==============================] - 22s 431us/sample - loss: 1.7021 - accuracy: 0.3997 - val_loss: 1.7195 - val_accuracy: 0.3738
# Epoch 48/200
# 50000/50000 [==============================] - 22s 432us/sample - loss: 1.6967 - accuracy: 0.4001 - val_loss: 1.7075 - val_accuracy: 0.3794
# Epoch 49/200
# 50000/50000 [==============================] - 22s 432us/sample - loss: 1.6906 - accuracy: 0.3999 - val_loss: 1.7189 - val_accuracy: 0.3774
# Epoch 50/200
# 50000/50000 [==============================] - 22s 433us/sample - loss: 1.6838 - accuracy: 0.4042 - val_loss: 1.7082 - val_accuracy: 0.3804
# Epoch 51/200
# 50000/50000 [==============================] - 22s 431us/sample - loss: 1.6734 - accuracy: 0.4076 - val_loss: 1.7140 - val_accuracy: 0.3804
# Epoch 52/200
# 50000/50000 [==============================] - 22s 431us/sample - loss: 1.6742 - accuracy: 0.4078 - val_loss: 1.7068 - val_accuracy: 0.3825
# Epoch 53/200
# 50000/50000 [==============================] - 22s 431us/sample - loss: 1.6667 - accuracy: 0.4120 - val_loss: 1.6967 - val_accuracy: 0.3882
# Epoch 54/200
# 50000/50000 [==============================] - 22s 432us/sample - loss: 1.6671 - accuracy: 0.4073 - val_loss: 1.6931 - val_accuracy: 0.3864
# Epoch 55/200
# 50000/50000 [==============================] - 22s 432us/sample - loss: 1.6588 - accuracy: 0.4109 - val_loss: 1.6739 - val_accuracy: 0.3923
# Epoch 56/200
# 50000/50000 [==============================] - 22s 431us/sample - loss: 1.6515 - accuracy: 0.4150 - val_loss: 1.6738 - val_accuracy: 0.3913
# Epoch 57/200
# 50000/50000 [==============================] - 22s 432us/sample - loss: 1.6449 - accuracy: 0.4155 - val_loss: 1.6663 - val_accuracy: 0.3947
# Epoch 58/200
# 50000/50000 [==============================] - 22s 431us/sample - loss: 1.6412 - accuracy: 0.4166 - val_loss: 1.6659 - val_accuracy: 0.3954
# Epoch 59/200
# 50000/50000 [==============================] - 22s 431us/sample - loss: 1.6385 - accuracy: 0.4191 - val_loss: 1.6603 - val_accuracy: 0.3984
# Epoch 60/200
# 50000/50000 [==============================] - 22s 431us/sample - loss: 1.6386 - accuracy: 0.4195 - val_loss: 1.6451 - val_accuracy: 0.4020
# Epoch 61/200
# 50000/50000 [==============================] - 22s 432us/sample - loss: 1.6273 - accuracy: 0.4217 - val_loss: 1.6477 - val_accuracy: 0.3998
# Epoch 62/200
# 50000/50000 [==============================] - 22s 432us/sample - loss: 1.6212 - accuracy: 0.4250 - val_loss: 1.6440 - val_accuracy: 0.4017
# Epoch 63/200
# 50000/50000 [==============================] - 22s 432us/sample - loss: 1.6198 - accuracy: 0.4277 - val_loss: 1.6397 - val_accuracy: 0.4048
# Epoch 64/200
# 50000/50000 [==============================] - 22s 432us/sample - loss: 1.6170 - accuracy: 0.4241 - val_loss: 1.6387 - val_accuracy: 0.4068
# Epoch 65/200
# 50000/50000 [==============================] - 22s 431us/sample - loss: 1.6120 - accuracy: 0.4274 - val_loss: 1.6333 - val_accuracy: 0.4064
# Epoch 66/200
# 50000/50000 [==============================] - 22s 432us/sample - loss: 1.6094 - accuracy: 0.4268 - val_loss: 1.6262 - val_accuracy: 0.4110
# Epoch 67/200
# 50000/50000 [==============================] - 22s 432us/sample - loss: 1.6029 - accuracy: 0.4296 - val_loss: 1.6246 - val_accuracy: 0.4118
# Epoch 68/200
# 50000/50000 [==============================] - 22s 431us/sample - loss: 1.5982 - accuracy: 0.4300 - val_loss: 1.6145 - val_accuracy: 0.4163
# Epoch 69/200
# 50000/50000 [==============================] - 22s 432us/sample - loss: 1.5953 - accuracy: 0.4330 - val_loss: 1.6055 - val_accuracy: 0.4183
# Epoch 70/200
# 50000/50000 [==============================] - 22s 431us/sample - loss: 1.5913 - accuracy: 0.4341 - val_loss: 1.6009 - val_accuracy: 0.4219
# Epoch 71/200
# 50000/50000 [==============================] - 22s 432us/sample - loss: 1.5865 - accuracy: 0.4345 - val_loss: 1.6065 - val_accuracy: 0.4219
# Epoch 72/200
# 50000/50000 [==============================] - 22s 432us/sample - loss: 1.5836 - accuracy: 0.4365 - val_loss: 1.5967 - val_accuracy: 0.4232
# Epoch 73/200
# 50000/50000 [==============================] - 22s 432us/sample - loss: 1.5745 - accuracy: 0.4423 - val_loss: 1.5952 - val_accuracy: 0.4237
# Epoch 74/200
# 50000/50000 [==============================] - 22s 431us/sample - loss: 1.5732 - accuracy: 0.4423 - val_loss: 1.5926 - val_accuracy: 0.4232
# Epoch 75/200
# 50000/50000 [==============================] - 22s 431us/sample - loss: 1.5746 - accuracy: 0.4398 - val_loss: 1.5997 - val_accuracy: 0.4217
# Epoch 76/200
# 50000/50000 [==============================] - 22s 432us/sample - loss: 1.5669 - accuracy: 0.4433 - val_loss: 1.5892 - val_accuracy: 0.4255
# Epoch 77/200
# 50000/50000 [==============================] - 22s 431us/sample - loss: 1.5668 - accuracy: 0.4430 - val_loss: 1.5923 - val_accuracy: 0.4242
# Epoch 78/200
# 50000/50000 [==============================] - 22s 431us/sample - loss: 1.5583 - accuracy: 0.4453 - val_loss: 1.5781 - val_accuracy: 0.4289
# Epoch 79/200
# 50000/50000 [==============================] - 22s 433us/sample - loss: 1.5572 - accuracy: 0.4450 - val_loss: 1.5726 - val_accuracy: 0.4310
# Epoch 80/200
# 50000/50000 [==============================] - 22s 432us/sample - loss: 1.5558 - accuracy: 0.4484 - val_loss: 1.5667 - val_accuracy: 0.4316
# Epoch 81/200
# 50000/50000 [==============================] - 22s 432us/sample - loss: 1.5540 - accuracy: 0.4476 - val_loss: 1.5636 - val_accuracy: 0.4341
# Epoch 82/200
# 50000/50000 [==============================] - 22s 432us/sample - loss: 1.5469 - accuracy: 0.4495 - val_loss: 1.5771 - val_accuracy: 0.4303
# Epoch 83/200
# 50000/50000 [==============================] - 22s 432us/sample - loss: 1.5469 - accuracy: 0.4494 - val_loss: 1.5656 - val_accuracy: 0.4353
# Epoch 84/200
# 50000/50000 [==============================] - 22s 432us/sample - loss: 1.5400 - accuracy: 0.4499 - val_loss: 1.5742 - val_accuracy: 0.4319
# Epoch 85/200
# 50000/50000 [==============================] - 22s 432us/sample - loss: 1.5397 - accuracy: 0.4517 - val_loss: 1.5638 - val_accuracy: 0.4362
# Epoch 86/200
# 50000/50000 [==============================] - 22s 432us/sample - loss: 1.5334 - accuracy: 0.4542 - val_loss: 1.5493 - val_accuracy: 0.4394
# Epoch 87/200
# 50000/50000 [==============================] - 22s 432us/sample - loss: 1.5335 - accuracy: 0.4522 - val_loss: 1.5435 - val_accuracy: 0.4429
# Epoch 88/200
# 50000/50000 [==============================] - 22s 432us/sample - loss: 1.5334 - accuracy: 0.4557 - val_loss: 1.5477 - val_accuracy: 0.4418
# Epoch 89/200
# 50000/50000 [==============================] - 22s 432us/sample - loss: 1.5304 - accuracy: 0.4554 - val_loss: 1.5471 - val_accuracy: 0.4428
# Epoch 90/200
# 50000/50000 [==============================] - 22s 432us/sample - loss: 1.5229 - accuracy: 0.4573 - val_loss: 1.5510 - val_accuracy: 0.4402
# Epoch 91/200
# 50000/50000 [==============================] - 22s 432us/sample - loss: 1.5198 - accuracy: 0.4617 - val_loss: 1.5443 - val_accuracy: 0.4428
# Epoch 92/200
# 50000/50000 [==============================] - 22s 432us/sample - loss: 1.5161 - accuracy: 0.4623 - val_loss: 1.5400 - val_accuracy: 0.4424
# Epoch 93/200
# 50000/50000 [==============================] - 22s 432us/sample - loss: 1.5080 - accuracy: 0.4617 - val_loss: 1.5383 - val_accuracy: 0.4468
# Epoch 94/200
# 50000/50000 [==============================] - 22s 431us/sample - loss: 1.5093 - accuracy: 0.4607 - val_loss: 1.5334 - val_accuracy: 0.4467
# Epoch 95/200
# 50000/50000 [==============================] - 22s 432us/sample - loss: 1.5064 - accuracy: 0.4632 - val_loss: 1.5293 - val_accuracy: 0.4494
# Epoch 96/200
# 50000/50000 [==============================] - 22s 431us/sample - loss: 1.5074 - accuracy: 0.4645 - val_loss: 1.5164 - val_accuracy: 0.4530
# Epoch 97/200
# 50000/50000 [==============================] - 22s 433us/sample - loss: 1.5000 - accuracy: 0.4678 - val_loss: 1.5266 - val_accuracy: 0.4482
# Epoch 98/200
# 50000/50000 [==============================] - 22s 433us/sample - loss: 1.5010 - accuracy: 0.4675 - val_loss: 1.5193 - val_accuracy: 0.4520
# Epoch 99/200
# 50000/50000 [==============================] - 22s 432us/sample - loss: 1.4977 - accuracy: 0.4660 - val_loss: 1.5174 - val_accuracy: 0.4518
# Epoch 100/200
# 50000/50000 [==============================] - 22s 432us/sample - loss: 1.4974 - accuracy: 0.4680 - val_loss: 1.5124 - val_accuracy: 0.4557
# Epoch 101/200
# 50000/50000 [==============================] - 22s 432us/sample - loss: 1.4955 - accuracy: 0.4680 - val_loss: 1.5129 - val_accuracy: 0.4559
# Epoch 102/200
# 50000/50000 [==============================] - 22s 431us/sample - loss: 1.4897 - accuracy: 0.4701 - val_loss: 1.5135 - val_accuracy: 0.4570
# Epoch 103/200
# 50000/50000 [==============================] - 22s 431us/sample - loss: 1.4886 - accuracy: 0.4729 - val_loss: 1.5177 - val_accuracy: 0.4549
# Epoch 104/200
# 50000/50000 [==============================] - 22s 432us/sample - loss: 1.4868 - accuracy: 0.4725 - val_loss: 1.4985 - val_accuracy: 0.4607
# Epoch 105/200
# 50000/50000 [==============================] - 22s 432us/sample - loss: 1.4833 - accuracy: 0.4733 - val_loss: 1.5037 - val_accuracy: 0.4586
# Epoch 106/200
# 50000/50000 [==============================] - 22s 432us/sample - loss: 1.4835 - accuracy: 0.4711 - val_loss: 1.5127 - val_accuracy: 0.4547
# Epoch 107/200
# 50000/50000 [==============================] - 22s 431us/sample - loss: 1.4782 - accuracy: 0.4746 - val_loss: 1.4990 - val_accuracy: 0.4620
# Epoch 108/200
# 50000/50000 [==============================] - 22s 432us/sample - loss: 1.4734 - accuracy: 0.4776 - val_loss: 1.5001 - val_accuracy: 0.4611
# Epoch 109/200
# 50000/50000 [==============================] - 22s 431us/sample - loss: 1.4719 - accuracy: 0.4772 - val_loss: 1.5025 - val_accuracy: 0.4604
# Epoch 110/200
# 50000/50000 [==============================] - 22s 432us/sample - loss: 1.4758 - accuracy: 0.4740 - val_loss: 1.4931 - val_accuracy: 0.4657
# Epoch 111/200
# 50000/50000 [==============================] - 22s 432us/sample - loss: 1.4696 - accuracy: 0.4763 - val_loss: 1.4936 - val_accuracy: 0.4627
# Epoch 112/200
# 50000/50000 [==============================] - 22s 432us/sample - loss: 1.4747 - accuracy: 0.4749 - val_loss: 1.4869 - val_accuracy: 0.4673
# Epoch 113/200
# 50000/50000 [==============================] - 22s 432us/sample - loss: 1.4635 - accuracy: 0.4779 - val_loss: 1.4986 - val_accuracy: 0.4626
# Epoch 114/200
# 50000/50000 [==============================] - 22s 432us/sample - loss: 1.4590 - accuracy: 0.4817 - val_loss: 1.4795 - val_accuracy: 0.4693
# Epoch 115/200
# 50000/50000 [==============================] - 22s 432us/sample - loss: 1.4663 - accuracy: 0.4761 - val_loss: 1.4843 - val_accuracy: 0.4666
# Epoch 116/200
# 50000/50000 [==============================] - 22s 432us/sample - loss: 1.4543 - accuracy: 0.4845 - val_loss: 1.4859 - val_accuracy: 0.4670
# Epoch 117/200
# 50000/50000 [==============================] - 22s 432us/sample - loss: 1.4556 - accuracy: 0.4821 - val_loss: 1.4700 - val_accuracy: 0.4746
# Epoch 118/200
# 50000/50000 [==============================] - 22s 431us/sample - loss: 1.4467 - accuracy: 0.4869 - val_loss: 1.4721 - val_accuracy: 0.4754
# Epoch 119/200
# 50000/50000 [==============================] - 22s 431us/sample - loss: 1.4502 - accuracy: 0.4850 - val_loss: 1.4944 - val_accuracy: 0.4654
# Epoch 120/200
# 50000/50000 [==============================] - 22s 433us/sample - loss: 1.4467 - accuracy: 0.4849 - val_loss: 1.4739 - val_accuracy: 0.4731
# Epoch 121/200
# 50000/50000 [==============================] - 22s 432us/sample - loss: 1.4449 - accuracy: 0.4858 - val_loss: 1.4646 - val_accuracy: 0.4774
# Epoch 122/200
# 50000/50000 [==============================] - 22s 432us/sample - loss: 1.4456 - accuracy: 0.4849 - val_loss: 1.4688 - val_accuracy: 0.4727
# Epoch 123/200
# 50000/50000 [==============================] - 22s 432us/sample - loss: 1.4413 - accuracy: 0.4881 - val_loss: 1.4769 - val_accuracy: 0.4723
# Epoch 124/200
# 50000/50000 [==============================] - 22s 432us/sample - loss: 1.4380 - accuracy: 0.4885 - val_loss: 1.4639 - val_accuracy: 0.4757
# Epoch 125/200
# 50000/50000 [==============================] - 22s 432us/sample - loss: 1.4304 - accuracy: 0.4907 - val_loss: 1.4627 - val_accuracy: 0.4777
# Epoch 126/200
# 50000/50000 [==============================] - 22s 432us/sample - loss: 1.4333 - accuracy: 0.4914 - val_loss: 1.4668 - val_accuracy: 0.4758
# Epoch 127/200
# 50000/50000 [==============================] - 22s 432us/sample - loss: 1.4334 - accuracy: 0.4903 - val_loss: 1.4708 - val_accuracy: 0.4746
# Epoch 128/200
# 50000/50000 [==============================] - 22s 432us/sample - loss: 1.4275 - accuracy: 0.4918 - val_loss: 1.4717 - val_accuracy: 0.4741
# Epoch 129/200
# 50000/50000 [==============================] - 22s 432us/sample - loss: 1.4305 - accuracy: 0.4918 - val_loss: 1.4575 - val_accuracy: 0.4790
# Epoch 130/200
# 50000/50000 [==============================] - 22s 432us/sample - loss: 1.4264 - accuracy: 0.4911 - val_loss: 1.4463 - val_accuracy: 0.4841
# Epoch 131/200
# 50000/50000 [==============================] - 22s 431us/sample - loss: 1.4260 - accuracy: 0.4927 - val_loss: 1.4657 - val_accuracy: 0.4776
# Epoch 132/200
# 50000/50000 [==============================] - 22s 432us/sample - loss: 1.4253 - accuracy: 0.4937 - val_loss: 1.4545 - val_accuracy: 0.4824
# Epoch 133/200
# 50000/50000 [==============================] - 22s 432us/sample - loss: 1.4172 - accuracy: 0.4975 - val_loss: 1.4461 - val_accuracy: 0.4832
# Epoch 134/200
# 50000/50000 [==============================] - 22s 432us/sample - loss: 1.4219 - accuracy: 0.4987 - val_loss: 1.4404 - val_accuracy: 0.4860
# Epoch 135/200
# 50000/50000 [==============================] - 22s 432us/sample - loss: 1.4189 - accuracy: 0.4958 - val_loss: 1.4308 - val_accuracy: 0.4887
# Epoch 136/200
# 50000/50000 [==============================] - 22s 432us/sample - loss: 1.4117 - accuracy: 0.4980 - val_loss: 1.4374 - val_accuracy: 0.4872
# Epoch 137/200
# 50000/50000 [==============================] - 22s 432us/sample - loss: 1.4115 - accuracy: 0.4962 - val_loss: 1.4345 - val_accuracy: 0.4879
# Epoch 138/200
# 50000/50000 [==============================] - 22s 432us/sample - loss: 1.4080 - accuracy: 0.4984 - val_loss: 1.4470 - val_accuracy: 0.4858
# Epoch 139/200
# 50000/50000 [==============================] - 22s 433us/sample - loss: 1.4090 - accuracy: 0.4985 - val_loss: 1.4471 - val_accuracy: 0.4865
# Epoch 140/200
# 50000/50000 [==============================] - 22s 432us/sample - loss: 1.4053 - accuracy: 0.5000 - val_loss: 1.4335 - val_accuracy: 0.4903
# Epoch 141/200
# 50000/50000 [==============================] - 22s 431us/sample - loss: 1.4043 - accuracy: 0.5007 - val_loss: 1.4336 - val_accuracy: 0.4898
# Epoch 142/200
# 50000/50000 [==============================] - 22s 433us/sample - loss: 1.3981 - accuracy: 0.5018 - val_loss: 1.4379 - val_accuracy: 0.4894
# Epoch 143/200
# 50000/50000 [==============================] - 22s 431us/sample - loss: 1.4010 - accuracy: 0.5016 - val_loss: 1.4299 - val_accuracy: 0.4925
# Epoch 144/200
# 50000/50000 [==============================] - 22s 432us/sample - loss: 1.4002 - accuracy: 0.5016 - val_loss: 1.4287 - val_accuracy: 0.4907
# Epoch 145/200
# 50000/50000 [==============================] - 22s 432us/sample - loss: 1.3995 - accuracy: 0.4997 - val_loss: 1.4254 - val_accuracy: 0.4931
# Epoch 146/200
# 50000/50000 [==============================] - 22s 432us/sample - loss: 1.3950 - accuracy: 0.5047 - val_loss: 1.4270 - val_accuracy: 0.4910
# Epoch 147/200
# 50000/50000 [==============================] - 22s 432us/sample - loss: 1.3898 - accuracy: 0.5060 - val_loss: 1.4297 - val_accuracy: 0.4923
# Epoch 148/200
# 50000/50000 [==============================] - 22s 432us/sample - loss: 1.3927 - accuracy: 0.5057 - val_loss: 1.4171 - val_accuracy: 0.4938
# Epoch 149/200
# 50000/50000 [==============================] - 22s 431us/sample - loss: 1.3895 - accuracy: 0.5065 - val_loss: 1.4175 - val_accuracy: 0.4946
# Epoch 150/200
# 50000/50000 [==============================] - 22s 432us/sample - loss: 1.3859 - accuracy: 0.5079 - val_loss: 1.4238 - val_accuracy: 0.4919
# Epoch 151/200
# 50000/50000 [==============================] - 22s 432us/sample - loss: 1.3855 - accuracy: 0.5060 - val_loss: 1.4182 - val_accuracy: 0.4956
# Epoch 152/200
# 50000/50000 [==============================] - 22s 431us/sample - loss: 1.3836 - accuracy: 0.5070 - val_loss: 1.4145 - val_accuracy: 0.4962
# Epoch 153/200
# 50000/50000 [==============================] - 22s 432us/sample - loss: 1.3829 - accuracy: 0.5093 - val_loss: 1.4136 - val_accuracy: 0.4959
# Epoch 154/200
# 50000/50000 [==============================] - 22s 431us/sample - loss: 1.3787 - accuracy: 0.5083 - val_loss: 1.4093 - val_accuracy: 0.4984
# Epoch 155/200
# 50000/50000 [==============================] - 22s 432us/sample - loss: 1.3773 - accuracy: 0.5112 - val_loss: 1.4135 - val_accuracy: 0.4973
# Epoch 156/200
# 50000/50000 [==============================] - 22s 432us/sample - loss: 1.3803 - accuracy: 0.5091 - val_loss: 1.4098 - val_accuracy: 0.4988
# Epoch 157/200
# 50000/50000 [==============================] - 22s 432us/sample - loss: 1.3735 - accuracy: 0.5118 - val_loss: 1.4060 - val_accuracy: 0.4994
# Epoch 158/200
# 50000/50000 [==============================] - 22s 432us/sample - loss: 1.3748 - accuracy: 0.5112 - val_loss: 1.4113 - val_accuracy: 0.4994
# Epoch 159/200
# 50000/50000 [==============================] - 22s 431us/sample - loss: 1.3690 - accuracy: 0.5165 - val_loss: 1.4071 - val_accuracy: 0.4994
# Epoch 160/200
# 50000/50000 [==============================] - 22s 431us/sample - loss: 1.3719 - accuracy: 0.5176 - val_loss: 1.4182 - val_accuracy: 0.4970
# Epoch 161/200
# 50000/50000 [==============================] - 22s 432us/sample - loss: 1.3650 - accuracy: 0.5144 - val_loss: 1.4037 - val_accuracy: 0.5027
# Epoch 162/200
# 50000/50000 [==============================] - 22s 432us/sample - loss: 1.3651 - accuracy: 0.5160 - val_loss: 1.4007 - val_accuracy: 0.5041
# Epoch 163/200
# 50000/50000 [==============================] - 22s 432us/sample - loss: 1.3609 - accuracy: 0.5191 - val_loss: 1.3940 - val_accuracy: 0.5045
# Epoch 164/200
# 50000/50000 [==============================] - 22s 431us/sample - loss: 1.3597 - accuracy: 0.5165 - val_loss: 1.4044 - val_accuracy: 0.5012
# Epoch 165/200
# 50000/50000 [==============================] - 22s 431us/sample - loss: 1.3571 - accuracy: 0.5193 - val_loss: 1.3912 - val_accuracy: 0.5063
# Epoch 166/200
# 50000/50000 [==============================] - 22s 432us/sample - loss: 1.3585 - accuracy: 0.5185 - val_loss: 1.4025 - val_accuracy: 0.5037
# Epoch 167/200
# 50000/50000 [==============================] - 22s 432us/sample - loss: 1.3581 - accuracy: 0.5184 - val_loss: 1.3889 - val_accuracy: 0.5050
# Epoch 168/200
# 50000/50000 [==============================] - 22s 432us/sample - loss: 1.3607 - accuracy: 0.5150 - val_loss: 1.3933 - val_accuracy: 0.5054
# Epoch 169/200
# 50000/50000 [==============================] - 22s 432us/sample - loss: 1.3521 - accuracy: 0.5180 - val_loss: 1.3889 - val_accuracy: 0.5057
# Epoch 170/200
# 50000/50000 [==============================] - 22s 431us/sample - loss: 1.3484 - accuracy: 0.5235 - val_loss: 1.3816 - val_accuracy: 0.5090
# Epoch 171/200
# 50000/50000 [==============================] - 22s 433us/sample - loss: 1.3543 - accuracy: 0.5200 - val_loss: 1.3830 - val_accuracy: 0.5084
# Epoch 172/200
# 50000/50000 [==============================] - 22s 432us/sample - loss: 1.3469 - accuracy: 0.5199 - val_loss: 1.3827 - val_accuracy: 0.5072
# Epoch 173/200
# 50000/50000 [==============================] - 22s 432us/sample - loss: 1.3493 - accuracy: 0.5205 - val_loss: 1.3899 - val_accuracy: 0.5061
# Epoch 174/200
# 50000/50000 [==============================] - 22s 432us/sample - loss: 1.3483 - accuracy: 0.5220 - val_loss: 1.3882 - val_accuracy: 0.5077
# Epoch 175/200
# 50000/50000 [==============================] - 22s 431us/sample - loss: 1.3424 - accuracy: 0.5249 - val_loss: 1.3841 - val_accuracy: 0.5105
# Epoch 176/200
# 50000/50000 [==============================] - 22s 431us/sample - loss: 1.3459 - accuracy: 0.5223 - val_loss: 1.3837 - val_accuracy: 0.5106
# Epoch 177/200
# 50000/50000 [==============================] - 22s 432us/sample - loss: 1.3413 - accuracy: 0.5247 - val_loss: 1.3823 - val_accuracy: 0.5092
# Epoch 178/200
# 50000/50000 [==============================] - 22s 431us/sample - loss: 1.3446 - accuracy: 0.5246 - val_loss: 1.3776 - val_accuracy: 0.5086
# Epoch 179/200
# 50000/50000 [==============================] - 22s 431us/sample - loss: 1.3355 - accuracy: 0.5256 - val_loss: 1.3770 - val_accuracy: 0.5098
# Epoch 180/200
# 50000/50000 [==============================] - 22s 431us/sample - loss: 1.3366 - accuracy: 0.5268 - val_loss: 1.3686 - val_accuracy: 0.5122
# Epoch 181/200
# 50000/50000 [==============================] - 22s 433us/sample - loss: 1.3307 - accuracy: 0.5264 - val_loss: 1.3743 - val_accuracy: 0.5092
# Epoch 182/200
# 50000/50000 [==============================] - 22s 432us/sample - loss: 1.3351 - accuracy: 0.5275 - val_loss: 1.3833 - val_accuracy: 0.5074
# Epoch 183/200
# 50000/50000 [==============================] - 22s 432us/sample - loss: 1.3272 - accuracy: 0.5290 - val_loss: 1.3794 - val_accuracy: 0.5073
# Epoch 184/200
# 50000/50000 [==============================] - 22s 432us/sample - loss: 1.3305 - accuracy: 0.5285 - val_loss: 1.3670 - val_accuracy: 0.5151
# Epoch 185/200
# 50000/50000 [==============================] - 22s 432us/sample - loss: 1.3246 - accuracy: 0.5317 - val_loss: 1.3612 - val_accuracy: 0.5170
# Epoch 186/200
# 50000/50000 [==============================] - 22s 432us/sample - loss: 1.3224 - accuracy: 0.5300 - val_loss: 1.3630 - val_accuracy: 0.5150
# Epoch 187/200
# 50000/50000 [==============================] - 22s 432us/sample - loss: 1.3273 - accuracy: 0.5296 - val_loss: 1.3698 - val_accuracy: 0.5148
# Epoch 188/200
# 50000/50000 [==============================] - 22s 431us/sample - loss: 1.3222 - accuracy: 0.5316 - val_loss: 1.3574 - val_accuracy: 0.5164
# Epoch 189/200
# 50000/50000 [==============================] - 22s 431us/sample - loss: 1.3206 - accuracy: 0.5327 - val_loss: 1.3626 - val_accuracy: 0.5160
# Epoch 190/200
# 50000/50000 [==============================] - 22s 432us/sample - loss: 1.3186 - accuracy: 0.5326 - val_loss: 1.3633 - val_accuracy: 0.5138
# Epoch 191/200
# 50000/50000 [==============================] - 22s 432us/sample - loss: 1.3209 - accuracy: 0.5333 - val_loss: 1.3606 - val_accuracy: 0.5145
# Epoch 192/200
# 50000/50000 [==============================] - 22s 432us/sample - loss: 1.3171 - accuracy: 0.5340 - val_loss: 1.3506 - val_accuracy: 0.5184
# Epoch 193/200
# 50000/50000 [==============================] - 22s 431us/sample - loss: 1.3173 - accuracy: 0.5318 - val_loss: 1.3622 - val_accuracy: 0.5162
# Epoch 194/200
# 50000/50000 [==============================] - 22s 432us/sample - loss: 1.3111 - accuracy: 0.5361 - val_loss: 1.3625 - val_accuracy: 0.5167
# Epoch 195/200
# 50000/50000 [==============================] - 22s 432us/sample - loss: 1.3090 - accuracy: 0.5359 - val_loss: 1.3507 - val_accuracy: 0.5175
# Epoch 196/200
# 50000/50000 [==============================] - 22s 431us/sample - loss: 1.3114 - accuracy: 0.5351 - val_loss: 1.3540 - val_accuracy: 0.5180
# Epoch 197/200
# 50000/50000 [==============================] - 22s 432us/sample - loss: 1.3053 - accuracy: 0.5361 - val_loss: 1.3511 - val_accuracy: 0.5184
# Epoch 198/200
# 50000/50000 [==============================] - 22s 432us/sample - loss: 1.3111 - accuracy: 0.5357 - val_loss: 1.3507 - val_accuracy: 0.5184
# Epoch 199/200
# 50000/50000 [==============================] - 22s 432us/sample - loss: 1.3059 - accuracy: 0.5353 - val_loss: 1.3550 - val_accuracy: 0.5181
# Epoch 200/200
# 50000/50000 [==============================] - 22s 432us/sample - loss: 1.3069 - accuracy: 0.5380 - val_loss: 1.3500 - val_accuracy: 0.5195

# %% [markdown]
# ##  Visualization of results
# Here, I will visualize the model and the results.. Firstly, the model itself will be shown in graph form. Thereafter, a summary of the statistics and more will be shown.
# Latsly, plots showing accuracy, preccision and more will be made.

# %% [markdown]
# ### Model illustartion
#
# Not only does the graph model illustrates the layers, where we easily can see e.g. the downsampling in the maxpooling layer.  We also see the order of the layers. Here we can check that the layers indeed are in correct order (conv, activation, normalization, pooling ect)..
#
# Similarty, the number of parameters is seen and the shape of especially the output layers.

# %%
plot_model(model, to_file='model_plot.png', show_shapes=True, show_layer_names=True)

# %% [markdown]
# ### Statistics
#
# In the statistics, we see the shape of the model, the number of weights in each layer as well as the total number of trained and non-trained parameters.

# %%
print(model.summary())
# Out:
# Model: "sequential"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# conv2d (Conv2D)              (None, 32, 32, 32)        2432
# _________________________________________________________________
# activation (Activation)      (None, 32, 32, 32)        0
# _________________________________________________________________
# dropout (Dropout)            (None, 32, 32, 32)        0
# _________________________________________________________________
# conv2d_1 (Conv2D)            (None, 28, 28, 128)       102528
# _________________________________________________________________
# activation_1 (Activation)    (None, 28, 28, 128)       0
# _________________________________________________________________
# batch_normalization (BatchNo (None, 28, 28, 128)       512
# _________________________________________________________________
# max_pooling2d (MaxPooling2D) (None, 14, 14, 128)       0
# _________________________________________________________________
# conv2d_2 (Conv2D)            (None, 14, 14, 192)       614592
# _________________________________________________________________
# activation_2 (Activation)    (None, 14, 14, 192)       0
# _________________________________________________________________
# batch_normalization_1 (Batch (None, 14, 14, 192)       768
# _________________________________________________________________
# conv2d_3 (Conv2D)            (None, 14, 14, 256)       1229056
# _________________________________________________________________
# activation_3 (Activation)    (None, 14, 14, 256)       0
# _________________________________________________________________
# batch_normalization_2 (Batch (None, 14, 14, 256)       1024
# _________________________________________________________________
# max_pooling2d_1 (MaxPooling2 (None, 7, 7, 256)         0
# _________________________________________________________________
# dropout_1 (Dropout)          (None, 7, 7, 256)         0
# _________________________________________________________________
# conv2d_4 (Conv2D)            (None, 7, 7, 256)         1638656
# _________________________________________________________________
# activation_4 (Activation)    (None, 7, 7, 256)         0
# _________________________________________________________________
# batch_normalization_3 (Batch (None, 7, 7, 256)         1024
# _________________________________________________________________
# max_pooling2d_2 (MaxPooling2 (None, 3, 3, 256)         0
# _________________________________________________________________
# dropout_2 (Dropout)          (None, 3, 3, 256)         0
# _________________________________________________________________
# conv2d_5 (Conv2D)            (None, 3, 3, 64)          409664
# _________________________________________________________________
# activation_5 (Activation)    (None, 3, 3, 64)          0
# _________________________________________________________________
# batch_normalization_4 (Batch (None, 3, 3, 64)          256
# _________________________________________________________________
# max_pooling2d_3 (MaxPooling2 (None, 1, 1, 64)          0
# _________________________________________________________________
# dropout_3 (Dropout)          (None, 1, 1, 64)          0
# _________________________________________________________________
# flatten (Flatten)            (None, 64)                0
# _________________________________________________________________
# dense (Dense)                (None, 10)                640
# =================================================================
# Total params: 4,001,152
# Trainable params: 3,999,360
# Non-trainable params: 1,792
# _________________________________________________________________
# None

# %% [markdown]
# ### training and validation accuracy values

# %%
scores = model.evaluate(x_test, y_test, verbose=1)
print('Test loss:', scores[0])
print('Test accuracy:', scores[1])
# Out:
# 10000/1 [======================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================= ...
# Test loss: 1.3500599193572997
# Test accuracy: 0.5195

# %%
# list all data in history
print(history.history.keys())
# Out:
# dict_keys(['loss', 'accuracy', 'val_loss', 'val_accuracy'])

# %%
#can render the model myself..
SVG(model_to_dot(model).create(prog='dot', format='svg'))
#sometime it changes from acc to accuracy, use the list above to write correct names...
if epoch>1:
  # display if theres more than one epoch.
  # Plot training & validation accuracy values
  plt.plot(history.history['accuracy'])
  plt.plot(history.history['val_accuracy'])
  plt.title('Model accuracy')
  plt.ylabel('Accuracy')
  plt.xlabel('Epoch')
  plt.legend(['Train', 'Test'], loc='upper left')
  plt.show()
  
  # Plot training & validation loss values
  plt.plot(history.history['loss'])
  plt.plot(history.history['val_loss'])
  plt.title('Model loss')
  plt.ylabel('Loss')
  plt.xlabel('Epoch')
  plt.legend(['Train', 'Test'], loc='upper left')
  plt.show()

# %% [markdown]
#  here, it can be seen after which epoch (if more are used) the odel starts to overfit..
#
#  Here, it can be seen that after XX epochs,the model starts to overfit. (Training acc is larger than valdation acc, which should be possible without overfitting, and training loss is less than actual valdation loss)...

# %% [markdown]
# ## Make predictions

# %% [markdown]
# #### Making predictions based on model and test data..

# %%
predictions = model.predict(x_test, verbose=0)  #https://www.tensorflow.org/tutorials/keras/classification
# Get most likely class
predicted_classes = np.argmax(predictions, axis=1)

# %% [markdown]
# #### Making a classification 'report' and a confusion matrix

# %%
# Have true classes (y_test). in order to make confusion matrix im chaning to Pythn scikit lib. (could use others)
import sklearn.metrics as metrics
#therefore, getting stats in scicit (even if I have it fron keras..)
report = metrics.classification_report(y_test_scivit, predicted_classes)
print(report)
# Out:
#               precision    recall  f1-score   support
#
#            0       0.69      0.44      0.54      1000
#            1       0.73      0.60      0.66      1000
#            2       0.32      0.57      0.41      1000
#            3       0.34      0.49      0.40      1000
#            4       0.47      0.45      0.46      1000
#            5       0.44      0.41      0.43      1000
#            6       0.70      0.53      0.61      1000
#            7       0.67      0.53      0.59      1000
#            8       0.57      0.77      0.65      1000
#            9       0.76      0.41      0.53      1000
#
#     accuracy                           0.52     10000
#    macro avg       0.57      0.52      0.53     10000
# weighted avg       0.57      0.52      0.53     10000

# %% [markdown]
# Making confusion matrix and showing (normalized and not). If values are wanted, remove ''' in function...

# %%
import numpy as np
#Defining classes for confusion matrix plot
classes = np.array(['airplanes', 'cars', 'birds', 'cats', 'deer', 'dogs', 'frogs', 'horses', 'ships', 'trucks']);
# Plot non-normalized confusion matrix
plot_confusion_matrix(y_test_scivit, predicted_classes, classes=classes,title='Confusion matrix, without normalization');
# Plot normalized confusion matrix
plot_confusion_matrix(y_test_scivit, predicted_classes, classes=classes, normalize=True,title='Normalized confusion matrix');
# Out:
# Confusion matrix, without normalization
# [[444  22 166  66  33  11  15  16 213  14]
#  [ 34 601  59  41  15  11  18  14 127  80]
#  [ 37   5 570 123 105  62  43  29  22   4]
#  [  2   7 179 487  53 192  38  27  13   2]
#  [ 18   3 249  93 445  62  40  64  24   2]
#  [  3   4 191 270  54 412  14  36  15   1]
#  [  1   8 166 151  89  32 534  11   5   3]
#  [ 12   5 102  96 114 113  12 529   7  10]
#  [ 55  37  47  32  24  15   4   9 765  12]
#  [ 38 132  72  57  19  25  45  51 153 408]]
# Normalized confusion matrix
# [[0.444 0.022 0.166 0.066 0.033 0.011 0.015 0.016 0.213 0.014]
#  [0.034 0.601 0.059 0.041 0.015 0.011 0.018 0.014 0.127 0.08 ]
#  [0.037 0.005 0.57  0.123 0.105 0.062 0.043 0.029 0.022 0.004]
#  [0.002 0.007 0.179 0.487 0.053 0.192 0.038 0.027 0.013 0.002]
#  [0.018 0.003 0.249 0.093 0.445 0.062 0.04  0.064 0.024 0.002]
#  [0.003 0.004 0.191 0.27  0.054 0.412 0.014 0.036 0.015 0.001]
#  [0.001 0.008 0.166 0.151 0.089 0.032 0.534 0.011 0.005 0.003]
#  [0.012 0.005 0.102 0.096 0.114 0.113 0.012 0.529 0.007 0.01 ]
#  [0.055 0.037 0.047 0.032 0.024 0.015 0.004 0.009 0.765 0.012]
#  [0.038 0.132 0.072 0.057 0.019 0.025 0.045 0.051 0.153 0.408]]

# %% [markdown]
# ## expect layers

# %% [markdown]
# We can see how small all layers are. This is intentional so it is possible to interpret them.

# %% [markdown]
# ### Using pred

# %%
#preds = clf.predictions(Xtest)[:,1]
from sklearn import metrics
import pandas as pd
#from ggplot import *

fpr, tpr, threshold = metrics.roc_curve(y_test, predictions)
roc_auc = metrics.auc(fpr, tpr)

plt.title('Receiver Operating Characteristic')
plt.plot(fpr, tpr, 'b', label = 'AUC = %0.2f' % roc_auc)
plt.legend(loc = 'lower right')
plt.plot([0, 1], [0, 1],'r--')
plt.xlim([0, 1])
plt.ylim([0, 1])
plt.ylabel('True Positive Rate')
plt.xlabel('False Positive Rate')
plt.show()
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-19-23e8f5ecf0d8> in <module>()
#       3 #from ggplot import *
#       4
# ----> 5 fpr, tpr, threshold = metrics.roc_curve(y_test, predictions)
#       6 roc_auc = metrics.auc(fpr, tpr)
#       7
#
# /usr/local/lib/python3.6/dist-packages/sklearn/metrics/ranking.py in roc_curve(y_true, y_score, pos_label, sample_weight, drop_intermediate)
#     620     """
#     621     fps, tps, thresholds = _binary_clf_curve(
# --> 622         y_true, y_score, pos_label=pos_label, sample_weight=sample_weight)
#     623
#     624     # Attempt to drop thresholds corresponding to points in between and
#
# /usr/local/lib/python3.6/dist-packages/sklearn/metrics/ranking.py in _binary_clf_curve(y_true, y_score, pos_label, sample_weight)
#     394     if not (y_type == "binary" or
#     395             (y_type == "multiclass" and pos_label is not None)):
# --> 396         raise ValueError("{0} format is not supported".format(y_type))
#     397
#     398     check_consistent_length(y_true, y_score, sample_weight)
#
# ValueError: multilabel-indicator format is not supported

# %% [markdown]
# # Testing

# %% [markdown]
# ## Save model and weights for further use.

# %%
# Save model and weights
model_name = '5Blocks_1.h5'

# Save model and weights
if not os.path.isdir(save_dir):
    os.makedirs(save_dir)
model_path = os.path.join(save_dir, model_name)
model.save(model_path)
print('Saved trained model at %s ' % model_path)

# %% [markdown]
# ## Trying with my own pic
