# %% [markdown]
# <a href="https://colab.research.google.com/github/aalling93/ENGR562_CNN/blob/master/CNN_Presentation_Class2.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # CNN MODEL
#
# Building a CNN model is easy! In this notebook, the theory from the article 'A study of Convolutional Neural Network'[Sorensen(2019)] will be implemented in a simple CNN.
#
# This model is a simpler version of the one covered in [Sorensen(2019)]. Here, a model is build for the sole purpose of showing a predictions
#
# Many frameworks and libraries usefull for machine learning exists.  Here, the keras library is used in order to utilize the Tensorflow framework.
#
# This notebook covers the following:
#
# - Initialization: installing and importing packages.
# - Importing a dataset: A dataset is needed to build and train a model.
# - Preparing the model: Defining the hyperparamters used.
# - Building a model: Using layers, fundtions ect as seen in [Sorensen(2019)].
# - Training the model: Using the imported data, the build model is trained using a loss function and optimizer.
# - Visualization of intermediate CNN results and statistics
# - Saving the model
# - Prediction.
#
# For further tutorials, see e.g.  https://medium.com/nybles/create-your-first-image-recognition-classifier-using-cnn-keras-and-tensorflow-backend-6eaab98d14dd or https://towardsdatascience.com/cnn-architectures-a-deep-dive-a99441d18049

# %% [markdown]
# ## Initialization
# Firstly, install needed packages and check for version.

# %%
#! pip install torch
#! pip install torchvision
#! pip install pandas==0.23.4
#! pip install geopandas
#! pip install keras
#! pip install tensorflow
#! pip install tf-nightly
#! pip install ggplot
#! pip install -U PyYAML
try:
  # %tensorflow_version only exists in Colab.
  # %tensorflow_version 2.x
except Exception:
  pass

from __future__ import absolute_import, division, print_function, unicode_literals
# TensorFlow and tf.keras
import tensorflow as tf
from tensorflow import keras
from keras import regularizers
# Helper libraries
import numpy as np
import matplotlib.pyplot as plt
from tensorflow.keras.datasets import cifar10
from tensorflow.keras.preprocessing.image import ImageDataGenerator, save_img
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Dense, Dropout, Activation, Flatten, BatchNormalization
from tensorflow.keras.layers import Conv2D, MaxPooling2D
import os
import time
from sklearn import svm, datasets
from sklearn.model_selection import train_test_split
from sklearn.metrics import confusion_matrix
from sklearn.utils.multiclass import unique_labels
from PIL import Image as pil_image
from tensorflow.keras import layers
from tensorflow.keras import backend as K
from keras.constraints import max_norm
#To visualize it..
from tensorflow.keras.utils import plot_model
from IPython.display import SVG
from tensorflow.keras.utils import model_to_dot
# FUNCTIONS
def plot_confusion_matrix(y_true, y_pred, classes,
                          normalize=False,
                          title=None,
                          cmap=plt.cm.Blues,want_title=None):
    """
    This function prints and plots the confusion matrix. Noting more... It uses the sklearn lib.
    Normalization can be applied by setting `normalize=True`.
    """
    #making title.. (for my article, i dont want then, thus the want_title)
    if not title:
        if normalize:
            title = 'Normalized confusion matrix'
        else:
            title = 'Confusion matrix, without normalization'

    # Compute confusion matrix
    cm = confusion_matrix(y_true, y_pred)
    # Only use the labels that appear in the data
    classes = classes[unique_labels(y_true, y_pred)]
    if normalize:
        cm = cm.astype('float') / cm.sum(axis=1)[:, np.newaxis]
        print("Normalized confusion matrix")
    else:
        print('Confusion matrix, without normalization')

    print(cm)

    fig, ax = plt.subplots(figsize=(6,6))
    im = ax.imshow(cm, interpolation='nearest', cmap=cmap)
    ax.figure.colorbar(im, ax=ax)
    
    # We want to show all ticks...
    if want_title!= None:
      ax.set(xticks=np.arange(cm.shape[1]),
             yticks=np.arange(cm.shape[0]),
             # ... and label them with the respective list entries
             xticklabels=classes, yticklabels=classes,
             title=title,
             ylabel='True label',
             xlabel='Predicted label')
    else:
      ax.set(xticks=np.arange(cm.shape[1]),
             yticks=np.arange(cm.shape[0]),
             # ... and label them with the respective list entries
             xticklabels=classes, yticklabels=classes,
             ylabel='True label',
             xlabel='Predicted label')        

    # Rotate the tick labels and set their alignment.
    plt.setp(ax.get_xticklabels(), rotation=45, ha="right",
             rotation_mode="anchor")
    # I dont want the actualy probabilities in the plot, since its meassy when exporting to latex. 
    # but, for examinations it's fine. 
    """
    Loop over data dimensions and create text annotations.
    fmt = '.2f' if normalize else 'd'
    thresh = cm.max() / 2.
    for i in range(cm.shape[0]):
        for j in range(cm.shape[1]):
            ax.text(j, i, format(cm[i, j], fmt),
                    ha="center", va="center",
                    color="white" if cm[i, j] > thresh else "black")
    fig.tight_layout()
    """
    return ax



print(tf.__version__)
# Out:
# TensorFlow 2.x selected.
# Using TensorFlow backend.
# 2.0.0

# %% [markdown]
# ## Importing a dataset
#
# Here, im important a dataset from keras pre-defined data sets, see https://keras.io/datasets/
#
# The CIFAR10 dataset:
# Dataset of 50,000 32x32 color training images, labeled over 10 categories, and 10,000 test images. It is thus good for illustrating pupose of a CNN. https://www.cs.toronto.edu/~kriz/cifar.html
#
# The images are uint8 array of RGB image data with shape (num_samples, 3, 32, 32) or (num_samples, 32, 32, 3) based on the image_data_format backend setting of either
# Since the dataset is predefined in Keras, it can do the labelling. Otherwise classes must be defined>

# %%
#loading the set directly from keras bucket.
cifar100 = tf.keras.datasets.cifar100
#defining training(test) data and its labels. The data, split between train and test sets:
(x_train, y_train), (x_test, y_test) = cifar10.load_data()
#see a bit of stats..
print('x_train shape:', x_train.shape)
print(x_train.shape[0], 'train samples')
print(x_test.shape[0], 'test samples')
# The data is already labbeled.. Othervise, define into classes
# Out:
# x_train shape: (50000, 32, 32, 3)
# 50000 train samples
# 10000 test samples

# %% [markdown]
# ## Preparing the model

# %%
# Convert class vectors to binary class matrices.
num_classes = 10 #from 100 to 10 classes....# in the CIFAR10 theres 10 classes extracted from the CIFAR100 dataset..
y_test_scivit = np.squeeze(np.copy(y_test)) #used for confusin matrix in scilearn lib. AFTER predictions are made...
y_train = tf.keras.utils.to_categorical(y_train, num_classes)
y_test = tf.keras.utils.to_categorical(y_test, num_classes)

# %% [markdown]
# Here, the defined test data can be used to evaluate the model using the error function described in the theory. It could be applied as K-fold, leave-on-out or even a cross validation (take hella long time tho).
#
# ## Exploring the classes

# %%
plt.figure()
plt.imshow(x_train[1])
plt.colorbar()
plt.grid(False)
plt.show()
#lets see what we have.

# %% [markdown]
# ## Building the CNN
# layers, as described in the theory can now be added to the model
# see https://towardsdatascience.com/building-a-convolutional-neural-network-cnn-in-keras-329fbbadc5f5

# %% [markdown]
# ### Defining Hyper parameters
#
# Hyper parameters to control the size of the output of CNN layer. Depth, stride and zero padding..

# %%
model_name = 'inClass_presentation'
#filter size
filter_size = 3
#If padding isnt the deafult, this value should be used (now keras defult is used..)
padding  = (filter_size-1)/2
filter_size = (filter_size,filter_size)
# Stride controls the "overlap" between neighoboring convolutions. For sattellite image, a strid of e.g. 10 is smart . This reduces the dimension.. If stride=1, we move filter one pixel at a time. 
# atm, keras deafult is used = the same size as pooling.. 
stride = 3 
#depth is number of neurons(filters) in the given layer connected to the input (either original img or feature img).
filters_first_layer = 66 #currently this value is also used for other layers..
# Epoch is the number each batch is trained
epoch=100
#Using batch learning as in the theory
batch_size = 1000

# %% [markdown]
# ### Making model

# %%
#------------------------ BUILING THE MODEL ------------------------------------
# Initializing the model using Sequntial(), The Sequential model is a linear stack of layers. https://keras.io/getting-started/sequential-model-guide/
model = Sequential()
#adding a convolutional layer, https://keras.io/layers/convolutional/
model.add(Conv2D(filters_first_layer, filter_size, padding='same',input_shape=x_train.shape[1:]))
#adding activation function
model.add(BatchNormalization())
model.add(Activation('relu'))
#adding Maxpooling as described in the theory and https://keras.io/layers/pooling/. Default stride is the same as pool..
model.add(MaxPooling2D(pool_size=(2, 2)))
#regularization, https://keras.io/layers/core/
model.add(Dropout(0.1))
#this "block" of layers (convolutional layer, activation, pooling and regularization) can now be applied a number of times.... i.e copy pastye..
# ---- 2nd block
model.add(Conv2D(filters_first_layer, filter_size))
model.add(BatchNormalization())
model.add(Activation('relu'))
model.add(MaxPooling2D(pool_size=(2,2)))
# --- 3rd block -------
model.add(Conv2D(filters_first_layer*2, filter_size, padding='same'))
model.add(BatchNormalization())
model.add(Activation('relu'))
model.add(MaxPooling2D(pool_size=(2,2)))
# --- 4rd block -------
model.add(Conv2D(filters_first_layer*2, filter_size, padding='same'))
model.add(BatchNormalization())
model.add(Activation('relu'))
model.add(MaxPooling2D(pool_size=(2,2)))
model.add(Dropout(0.2))
# --- 5th block -------
model.add(Conv2D(filters_first_layer*2, filter_size, padding='same'))
model.add(BatchNormalization())
model.add(Activation('relu'))
model.add(Dropout(0.4))
#Flattens the input. Does not affect the batch size needed for FC... see https://medium.com/nybles/create-your-first-image-recognition-classifier-using-cnn-keras-and-tensorflow-backend-6eaab98d14dd
model.add(Flatten())
#model.add(Dense(512, kernel_constraint=max_norm(2.)))
model.add(Dense(512))
model.add(Activation('relu'))
model.add(Dropout(0.2))
#Just your regular densely-connected NN layer, i.e. the FC...adding different weight regularizers. Lastly,activation function to classify...
model.add(Dense(num_classes, kernel_regularizer=regularizers.l2(0.001),bias_regularizer=regularizers.l2(0.001),activity_regularizer=regularizers.l2(0.001),activation='softmax'))

# %% [markdown]
# ## Training the model

# %% [markdown]
# ### Define back propagation optimizer and loss function.
# In the theory, the equation for the Gradient Descent is explained. This is optimizer is used with the loss of cross entropy.
#
# Recall. Gradient descent applied to a batch is called mini-batch learning.
#
#
# Optimizer: https://keras.io/optimizers/.
#
# Loss function: https://keras.io/losses/.

# %%
# an optimizer is required to train a keras model, https://keras.io/optimizers/. As described in the theory, as GRADIENT DESCENT is used here..
#  The loss function is here defined, https://keras.io/losses/. In the theory, the kullback_leibler_divergence and cross entropy..  Since classes are integer, sparse_categorical_crossentropy is used
optimizer = keras.optimizers.SGD(lr=0.005)
model.compile(loss='categorical_crossentropy',optimizer=optimizer,metrics=['accuracy'])
print("Showing sizes of datasets..")
print(x_train.shape,y_train.shape,x_test.shape,y_test.shape)
# Out:
# Showing sizes of datasets..
# (50000, 32, 32, 3) (50000, 10) (10000, 32, 32, 3) (10000, 10)

# %% [markdown]
# In illustation of the data, we saw the scale on the colour plot. This is scalled to [0,1] before its used to fit the model.

# %%
#Scaling the data from [0:255] to [0:1]..
x_test = x_test.astype('float32')
x_train = x_train.astype('float32')
x_train /= 255
x_test /= 255

# %% [markdown]
# ### Fitting the model:
# Using the model of the CNN, the model is not TRAINED using the labels.
# - the batch size is used (how many feature maps in one batch)
# - the epochs are used (how many times a batch is trained)
# Moreover, the training data is used (data and labels) to train, and is validated on the test data (data and labels)

# %%
#https://keras.io/models/sequential/
# History is used to track the changed for plotting..
history = model.fit(x_train, y_train,batch_size=batch_size,epochs=epoch, validation_data=(x_test, y_test),shuffle=True)
# Out:
# Train on 50000 samples, validate on 10000 samples
# Epoch 1/100
# 50000/50000 [==============================] - 6s 113us/sample - loss: 2.3554 - accuracy: 0.1375 - val_loss: 2.3226 - val_accuracy: 0.0982
# Epoch 2/100
# 50000/50000 [==============================] - 3s 52us/sample - loss: 2.1859 - accuracy: 0.1998 - val_loss: 2.3261 - val_accuracy: 0.0997
# Epoch 3/100
# 50000/50000 [==============================] - 3s 51us/sample - loss: 2.0858 - accuracy: 0.2395 - val_loss: 2.3423 - val_accuracy: 0.1008
# Epoch 4/100
# 50000/50000 [==============================] - 3s 51us/sample - loss: 2.0164 - accuracy: 0.2644 - val_loss: 2.3769 - val_accuracy: 0.1002
# Epoch 5/100
# 50000/50000 [==============================] - 3s 52us/sample - loss: 1.9590 - accuracy: 0.2816 - val_loss: 2.4236 - val_accuracy: 0.1020
# Epoch 6/100
# 50000/50000 [==============================] - 3s 52us/sample - loss: 1.9044 - accuracy: 0.3034 - val_loss: 2.4645 - val_accuracy: 0.1098
# Epoch 7/100
# 50000/50000 [==============================] - 3s 52us/sample - loss: 1.8641 - accuracy: 0.3138 - val_loss: 2.4801 - val_accuracy: 0.1164
# Epoch 8/100
# 50000/50000 [==============================] - 3s 51us/sample - loss: 1.8210 - accuracy: 0.3300 - val_loss: 2.4596 - val_accuracy: 0.1225
# Epoch 9/100
# 50000/50000 [==============================] - 3s 52us/sample - loss: 1.7847 - accuracy: 0.3421 - val_loss: 2.3815 - val_accuracy: 0.1474
# Epoch 10/100
# 50000/50000 [==============================] - 3s 52us/sample - loss: 1.7565 - accuracy: 0.3521 - val_loss: 2.2322 - val_accuracy: 0.1922
# Epoch 11/100
# 50000/50000 [==============================] - 3s 52us/sample - loss: 1.7280 - accuracy: 0.3614 - val_loss: 2.0563 - val_accuracy: 0.2482
# Epoch 12/100
# 50000/50000 [==============================] - 3s 52us/sample - loss: 1.6970 - accuracy: 0.3738 - val_loss: 1.9554 - val_accuracy: 0.2905
# Epoch 13/100
# 50000/50000 [==============================] - 3s 52us/sample - loss: 1.6761 - accuracy: 0.3828 - val_loss: 1.8089 - val_accuracy: 0.3450
# Epoch 14/100
# 50000/50000 [==============================] - 3s 52us/sample - loss: 1.6550 - accuracy: 0.3901 - val_loss: 1.7035 - val_accuracy: 0.3843
# Epoch 15/100
# 50000/50000 [==============================] - 3s 52us/sample - loss: 1.6346 - accuracy: 0.3978 - val_loss: 1.6197 - val_accuracy: 0.4171
# Epoch 16/100
# 50000/50000 [==============================] - 3s 52us/sample - loss: 1.6138 - accuracy: 0.4065 - val_loss: 1.6197 - val_accuracy: 0.4205
# Epoch 17/100
# 50000/50000 [==============================] - 3s 52us/sample - loss: 1.5934 - accuracy: 0.4152 - val_loss: 1.5357 - val_accuracy: 0.4473
# Epoch 18/100
# 50000/50000 [==============================] - 3s 51us/sample - loss: 1.5761 - accuracy: 0.4203 - val_loss: 1.5295 - val_accuracy: 0.4548
# Epoch 19/100
# 50000/50000 [==============================] - 3s 51us/sample - loss: 1.5630 - accuracy: 0.4271 - val_loss: 1.5114 - val_accuracy: 0.4586
# Epoch 20/100
# 50000/50000 [==============================] - 3s 53us/sample - loss: 1.5436 - accuracy: 0.4358 - val_loss: 1.4991 - val_accuracy: 0.4615
# Epoch 21/100
# 50000/50000 [==============================] - 3s 52us/sample - loss: 1.5330 - accuracy: 0.4409 - val_loss: 1.4385 - val_accuracy: 0.4809
# Epoch 22/100
# 50000/50000 [==============================] - 3s 51us/sample - loss: 1.5146 - accuracy: 0.4482 - val_loss: 1.4499 - val_accuracy: 0.4834
# Epoch 23/100
# 50000/50000 [==============================] - 3s 53us/sample - loss: 1.5064 - accuracy: 0.4507 - val_loss: 1.4652 - val_accuracy: 0.4803
# Epoch 24/100
# 50000/50000 [==============================] - 3s 52us/sample - loss: 1.4882 - accuracy: 0.4561 - val_loss: 1.4171 - val_accuracy: 0.4982
# Epoch 25/100
# 50000/50000 [==============================] - 3s 52us/sample - loss: 1.4734 - accuracy: 0.4620 - val_loss: 1.4634 - val_accuracy: 0.4839
# Epoch 26/100
# 50000/50000 [==============================] - 3s 52us/sample - loss: 1.4630 - accuracy: 0.4668 - val_loss: 1.4145 - val_accuracy: 0.4980
# Epoch 27/100
# 50000/50000 [==============================] - 3s 52us/sample - loss: 1.4541 - accuracy: 0.4710 - val_loss: 1.3853 - val_accuracy: 0.5054
# Epoch 28/100
# 50000/50000 [==============================] - 3s 52us/sample - loss: 1.4424 - accuracy: 0.4769 - val_loss: 1.3783 - val_accuracy: 0.5118
# Epoch 29/100
# 50000/50000 [==============================] - 3s 52us/sample - loss: 1.4250 - accuracy: 0.4832 - val_loss: 1.3703 - val_accuracy: 0.5143
# Epoch 30/100
# 50000/50000 [==============================] - 3s 51us/sample - loss: 1.4106 - accuracy: 0.4882 - val_loss: 1.3294 - val_accuracy: 0.5284
# Epoch 31/100
# 50000/50000 [==============================] - 3s 52us/sample - loss: 1.4060 - accuracy: 0.4923 - val_loss: 1.3604 - val_accuracy: 0.5191
# Epoch 32/100
# 50000/50000 [==============================] - 3s 52us/sample - loss: 1.3952 - accuracy: 0.4961 - val_loss: 1.3200 - val_accuracy: 0.5268
# Epoch 33/100
# 50000/50000 [==============================] - 3s 51us/sample - loss: 1.3827 - accuracy: 0.5024 - val_loss: 1.3341 - val_accuracy: 0.5287
# Epoch 34/100
# 50000/50000 [==============================] - 3s 52us/sample - loss: 1.3761 - accuracy: 0.5043 - val_loss: 1.3470 - val_accuracy: 0.5226
# Epoch 35/100
# 50000/50000 [==============================] - 3s 51us/sample - loss: 1.3647 - accuracy: 0.5083 - val_loss: 1.3492 - val_accuracy: 0.5117
# Epoch 36/100
# 50000/50000 [==============================] - 3s 52us/sample - loss: 1.3541 - accuracy: 0.5131 - val_loss: 1.2855 - val_accuracy: 0.5385
# Epoch 37/100
# 50000/50000 [==============================] - 3s 51us/sample - loss: 1.3419 - accuracy: 0.5183 - val_loss: 1.3819 - val_accuracy: 0.5164
# Epoch 38/100
# 50000/50000 [==============================] - 3s 51us/sample - loss: 1.3378 - accuracy: 0.5200 - val_loss: 1.2751 - val_accuracy: 0.5459
# Epoch 39/100
# 50000/50000 [==============================] - 3s 51us/sample - loss: 1.3298 - accuracy: 0.5231 - val_loss: 1.3643 - val_accuracy: 0.5105
# Epoch 40/100
# 50000/50000 [==============================] - 3s 51us/sample - loss: 1.3194 - accuracy: 0.5285 - val_loss: 1.4018 - val_accuracy: 0.5101
# Epoch 41/100
# 50000/50000 [==============================] - 3s 51us/sample - loss: 1.3081 - accuracy: 0.5337 - val_loss: 1.2178 - val_accuracy: 0.5618
# Epoch 42/100
# 50000/50000 [==============================] - 3s 51us/sample - loss: 1.3014 - accuracy: 0.5340 - val_loss: 1.2093 - val_accuracy: 0.5691
# Epoch 43/100
# 50000/50000 [==============================] - 3s 51us/sample - loss: 1.2918 - accuracy: 0.5387 - val_loss: 1.2835 - val_accuracy: 0.5457
# Epoch 44/100
# 50000/50000 [==============================] - 3s 51us/sample - loss: 1.2857 - accuracy: 0.5409 - val_loss: 1.2352 - val_accuracy: 0.5618
# Epoch 45/100
# 50000/50000 [==============================] - 3s 52us/sample - loss: 1.2778 - accuracy: 0.5447 - val_loss: 1.3437 - val_accuracy: 0.5301
# Epoch 46/100
# 50000/50000 [==============================] - 3s 51us/sample - loss: 1.2691 - accuracy: 0.5473 - val_loss: 1.2180 - val_accuracy: 0.5573
# Epoch 47/100
# 50000/50000 [==============================] - 3s 52us/sample - loss: 1.2624 - accuracy: 0.5512 - val_loss: 1.6368 - val_accuracy: 0.4337
# Epoch 48/100
# 50000/50000 [==============================] - 3s 51us/sample - loss: 1.2563 - accuracy: 0.5514 - val_loss: 1.2702 - val_accuracy: 0.5534
# Epoch 49/100
# 50000/50000 [==============================] - 3s 51us/sample - loss: 1.2479 - accuracy: 0.5570 - val_loss: 1.2857 - val_accuracy: 0.5486
# Epoch 50/100
# 50000/50000 [==============================] - 3s 51us/sample - loss: 1.2375 - accuracy: 0.5624 - val_loss: 1.2110 - val_accuracy: 0.5657
# Epoch 51/100
# 50000/50000 [==============================] - 3s 50us/sample - loss: 1.2349 - accuracy: 0.5638 - val_loss: 1.2031 - val_accuracy: 0.5620
# Epoch 52/100
# 50000/50000 [==============================] - 3s 51us/sample - loss: 1.2255 - accuracy: 0.5677 - val_loss: 1.3502 - val_accuracy: 0.5286
# Epoch 53/100
# 50000/50000 [==============================] - 3s 51us/sample - loss: 1.2245 - accuracy: 0.5677 - val_loss: 1.3842 - val_accuracy: 0.5197
# Epoch 54/100
# 50000/50000 [==============================] - 3s 51us/sample - loss: 1.2151 - accuracy: 0.5717 - val_loss: 1.2233 - val_accuracy: 0.5648
# Epoch 55/100
# 50000/50000 [==============================] - 3s 51us/sample - loss: 1.2056 - accuracy: 0.5731 - val_loss: 1.3020 - val_accuracy: 0.5392
# Epoch 56/100
# 50000/50000 [==============================] - 3s 52us/sample - loss: 1.2056 - accuracy: 0.5737 - val_loss: 1.2228 - val_accuracy: 0.5511
# Epoch 57/100
# 50000/50000 [==============================] - 3s 52us/sample - loss: 1.1968 - accuracy: 0.5760 - val_loss: 1.4332 - val_accuracy: 0.5135
# Epoch 58/100
# 50000/50000 [==============================] - 3s 51us/sample - loss: 1.1852 - accuracy: 0.5815 - val_loss: 1.1829 - val_accuracy: 0.5682
# Epoch 59/100
# 50000/50000 [==============================] - 3s 52us/sample - loss: 1.1836 - accuracy: 0.5797 - val_loss: 1.4862 - val_accuracy: 0.5029
# Epoch 60/100
# 50000/50000 [==============================] - 3s 52us/sample - loss: 1.1742 - accuracy: 0.5863 - val_loss: 1.1332 - val_accuracy: 0.5872
# Epoch 61/100
# 50000/50000 [==============================] - 3s 51us/sample - loss: 1.1772 - accuracy: 0.5873 - val_loss: 1.2234 - val_accuracy: 0.5572
# Epoch 62/100
# 50000/50000 [==============================] - 3s 50us/sample - loss: 1.1669 - accuracy: 0.5896 - val_loss: 1.1946 - val_accuracy: 0.5706
# Epoch 63/100
# 50000/50000 [==============================] - 3s 53us/sample - loss: 1.1600 - accuracy: 0.5920 - val_loss: 1.2198 - val_accuracy: 0.5654
# Epoch 64/100
# 50000/50000 [==============================] - 3s 52us/sample - loss: 1.1563 - accuracy: 0.5934 - val_loss: 1.1980 - val_accuracy: 0.5664
# Epoch 65/100
# 50000/50000 [==============================] - 3s 51us/sample - loss: 1.1467 - accuracy: 0.5983 - val_loss: 1.1584 - val_accuracy: 0.5850
# Epoch 66/100
# 50000/50000 [==============================] - 3s 51us/sample - loss: 1.1499 - accuracy: 0.5947 - val_loss: 1.1938 - val_accuracy: 0.5723
# Epoch 67/100
# 50000/50000 [==============================] - 3s 51us/sample - loss: 1.1431 - accuracy: 0.5962 - val_loss: 1.3021 - val_accuracy: 0.5420
# Epoch 68/100
# 50000/50000 [==============================] - 3s 51us/sample - loss: 1.1362 - accuracy: 0.6003 - val_loss: 1.3335 - val_accuracy: 0.5314
# Epoch 69/100
# 50000/50000 [==============================] - 3s 51us/sample - loss: 1.1315 - accuracy: 0.6032 - val_loss: 1.1874 - val_accuracy: 0.5830
# Epoch 70/100
# 50000/50000 [==============================] - 3s 52us/sample - loss: 1.1240 - accuracy: 0.6046 - val_loss: 1.1471 - val_accuracy: 0.5922
# Epoch 71/100
# 50000/50000 [==============================] - 3s 51us/sample - loss: 1.1220 - accuracy: 0.6075 - val_loss: 1.1538 - val_accuracy: 0.5929
# Epoch 72/100
# 50000/50000 [==============================] - 3s 52us/sample - loss: 1.1113 - accuracy: 0.6100 - val_loss: 1.2241 - val_accuracy: 0.5702
# Epoch 73/100
# 50000/50000 [==============================] - 3s 51us/sample - loss: 1.1072 - accuracy: 0.6130 - val_loss: 1.1861 - val_accuracy: 0.5792
# Epoch 74/100
# 50000/50000 [==============================] - 3s 52us/sample - loss: 1.1086 - accuracy: 0.6104 - val_loss: 1.0922 - val_accuracy: 0.6144
# Epoch 75/100
# 50000/50000 [==============================] - 3s 52us/sample - loss: 1.1012 - accuracy: 0.6162 - val_loss: 1.1016 - val_accuracy: 0.6041
# Epoch 76/100
# 50000/50000 [==============================] - 3s 52us/sample - loss: 1.0983 - accuracy: 0.6173 - val_loss: 1.0579 - val_accuracy: 0.6314
# Epoch 77/100
# 50000/50000 [==============================] - 3s 52us/sample - loss: 1.0924 - accuracy: 0.6170 - val_loss: 1.1504 - val_accuracy: 0.5968
# Epoch 78/100
# 50000/50000 [==============================] - 3s 54us/sample - loss: 1.0857 - accuracy: 0.6189 - val_loss: 1.0580 - val_accuracy: 0.6263
# Epoch 79/100
# 50000/50000 [==============================] - 3s 52us/sample - loss: 1.0823 - accuracy: 0.6202 - val_loss: 1.1180 - val_accuracy: 0.6115
# Epoch 80/100
# 50000/50000 [==============================] - 3s 51us/sample - loss: 1.0793 - accuracy: 0.6228 - val_loss: 1.1032 - val_accuracy: 0.6118
# Epoch 81/100
# 50000/50000 [==============================] - 3s 51us/sample - loss: 1.0713 - accuracy: 0.6238 - val_loss: 1.1848 - val_accuracy: 0.5840
# Epoch 82/100
# 50000/50000 [==============================] - 3s 51us/sample - loss: 1.0666 - accuracy: 0.6267 - val_loss: 1.1958 - val_accuracy: 0.5841
# Epoch 83/100
# 50000/50000 [==============================] - 3s 51us/sample - loss: 1.0682 - accuracy: 0.6278 - val_loss: 1.1278 - val_accuracy: 0.5947
# Epoch 84/100
# 50000/50000 [==============================] - 3s 51us/sample - loss: 1.0580 - accuracy: 0.6314 - val_loss: 1.2401 - val_accuracy: 0.5713
# Epoch 85/100
# 50000/50000 [==============================] - 3s 51us/sample - loss: 1.0583 - accuracy: 0.6313 - val_loss: 1.0163 - val_accuracy: 0.6419
# Epoch 86/100
# 50000/50000 [==============================] - 3s 50us/sample - loss: 1.0489 - accuracy: 0.6349 - val_loss: 1.0574 - val_accuracy: 0.6264
# Epoch 87/100
# 50000/50000 [==============================] - 3s 51us/sample - loss: 1.0444 - accuracy: 0.6345 - val_loss: 1.2215 - val_accuracy: 0.5787
# Epoch 88/100
# 50000/50000 [==============================] - 3s 50us/sample - loss: 1.0420 - accuracy: 0.6361 - val_loss: 1.0164 - val_accuracy: 0.6416
# Epoch 89/100
# 50000/50000 [==============================] - 3s 52us/sample - loss: 1.0422 - accuracy: 0.6365 - val_loss: 1.1946 - val_accuracy: 0.5836
# Epoch 90/100
# 50000/50000 [==============================] - 3s 52us/sample - loss: 1.0328 - accuracy: 0.6425 - val_loss: 1.0816 - val_accuracy: 0.6141
# Epoch 91/100
# 50000/50000 [==============================] - 3s 51us/sample - loss: 1.0286 - accuracy: 0.6421 - val_loss: 1.2172 - val_accuracy: 0.5767
# Epoch 92/100
# 50000/50000 [==============================] - 3s 52us/sample - loss: 1.0236 - accuracy: 0.6450 - val_loss: 1.1262 - val_accuracy: 0.5949
# Epoch 93/100
# 50000/50000 [==============================] - 3s 51us/sample - loss: 1.0155 - accuracy: 0.6476 - val_loss: 1.1124 - val_accuracy: 0.6119
# Epoch 94/100
# 50000/50000 [==============================] - 3s 52us/sample - loss: 1.0178 - accuracy: 0.6479 - val_loss: 1.1017 - val_accuracy: 0.6115
# Epoch 95/100
# 50000/50000 [==============================] - 3s 52us/sample - loss: 1.0144 - accuracy: 0.6467 - val_loss: 1.0376 - val_accuracy: 0.6433
# Epoch 96/100
# 50000/50000 [==============================] - 3s 51us/sample - loss: 1.0110 - accuracy: 0.6485 - val_loss: 1.2235 - val_accuracy: 0.5661
# Epoch 97/100
# 50000/50000 [==============================] - 3s 52us/sample - loss: 1.0089 - accuracy: 0.6507 - val_loss: 1.0374 - val_accuracy: 0.6300
# Epoch 98/100
# 50000/50000 [==============================] - 3s 51us/sample - loss: 0.9979 - accuracy: 0.6535 - val_loss: 1.1402 - val_accuracy: 0.6027
# Epoch 99/100
# 50000/50000 [==============================] - 3s 51us/sample - loss: 0.9981 - accuracy: 0.6553 - val_loss: 1.0426 - val_accuracy: 0.6360
# Epoch 100/100
# 50000/50000 [==============================] - 3s 51us/sample - loss: 0.9954 - accuracy: 0.6565 - val_loss: 1.1115 - val_accuracy: 0.6142

# %% [markdown]
# ##  Visualization of results
# Here, I will visualize the model and the results.. Firstly, the model itself will be shown in graph form. Thereafter, a summary of the statistics and more will be shown.
# Latsly, plots showing accuracy, preccision and more will be made.

# %% [markdown]
# ### Model illustartion
#
# Not only does the graph model illustrates the layers, where we easily can see e.g. the downsampling in the maxpooling layer.  We also see the order of the layers. Here we can check that the layers indeed are in correct order (conv, activation, normalization, pooling ect)..
#
# Similarty, the number of parameters is seen and the shape of especially the output layers.

# %%
plot_model(model, to_file='model_plot_CNNmodel_name.png', show_shapes=True, show_layer_names=True)

# %% [markdown]
# ### Statistics
#
# In the statistics, we see the shape of the model, the number of weights in each layer as well as the total number of trained and non-trained parameters.

# %%
print(model.summary())
# Out:
# Model: "sequential"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# conv2d (Conv2D)              (None, 32, 32, 66)        1848
# _________________________________________________________________
# batch_normalization (BatchNo (None, 32, 32, 66)        264
# _________________________________________________________________
# activation (Activation)      (None, 32, 32, 66)        0
# _________________________________________________________________
# max_pooling2d (MaxPooling2D) (None, 16, 16, 66)        0
# _________________________________________________________________
# dropout (Dropout)            (None, 16, 16, 66)        0
# _________________________________________________________________
# conv2d_1 (Conv2D)            (None, 14, 14, 66)        39270
# _________________________________________________________________
# batch_normalization_1 (Batch (None, 14, 14, 66)        264
# _________________________________________________________________
# activation_1 (Activation)    (None, 14, 14, 66)        0
# _________________________________________________________________
# max_pooling2d_1 (MaxPooling2 (None, 7, 7, 66)          0
# _________________________________________________________________
# conv2d_2 (Conv2D)            (None, 7, 7, 132)         78540
# _________________________________________________________________
# batch_normalization_2 (Batch (None, 7, 7, 132)         528
# _________________________________________________________________
# activation_2 (Activation)    (None, 7, 7, 132)         0
# _________________________________________________________________
# max_pooling2d_2 (MaxPooling2 (None, 3, 3, 132)         0
# _________________________________________________________________
# conv2d_3 (Conv2D)            (None, 3, 3, 132)         156948
# _________________________________________________________________
# batch_normalization_3 (Batch (None, 3, 3, 132)         528
# _________________________________________________________________
# activation_3 (Activation)    (None, 3, 3, 132)         0
# _________________________________________________________________
# max_pooling2d_3 (MaxPooling2 (None, 1, 1, 132)         0
# _________________________________________________________________
# dropout_1 (Dropout)          (None, 1, 1, 132)         0
# _________________________________________________________________
# conv2d_4 (Conv2D)            (None, 1, 1, 132)         156948
# _________________________________________________________________
# batch_normalization_4 (Batch (None, 1, 1, 132)         528
# _________________________________________________________________
# activation_4 (Activation)    (None, 1, 1, 132)         0
# _________________________________________________________________
# dropout_2 (Dropout)          (None, 1, 1, 132)         0
# _________________________________________________________________
# flatten (Flatten)            (None, 132)               0
# _________________________________________________________________
# dense (Dense)                (None, 512)               68096
# _________________________________________________________________
# activation_5 (Activation)    (None, 512)               0
# _________________________________________________________________
# dropout_3 (Dropout)          (None, 512)               0
# _________________________________________________________________
# dense_1 (Dense)              (None, 10)                5130
# =================================================================
# Total params: 508,892
# Trainable params: 507,836
# Non-trainable params: 1,056
# _________________________________________________________________
# None

# %% [markdown]
# ### training and validation accuracy values

# %%
#scores = model.evaluate(x_test, y_test, verbose=1);
#print('Test loss:', scores[0])
#print('Test accuracy:', scores[1])

# %%
# list all data in history
print(history.history.keys());
# Out:
# dict_keys(['loss', 'accuracy', 'val_loss', 'val_accuracy'])

# %%
#can render the model myself..
SVG(model_to_dot(model).create(prog='dot', format='svg'))
#sometime it changes from acc to accuracy, use the list above to write correct names...
if epoch>1:
  # display if theres more than one epoch.
  # Plot training & validation accuracy values
  plt.plot(history.history['accuracy'])
  plt.plot(history.history['val_accuracy'])
  plt.title('Model accuracy')
  plt.ylabel('Accuracy')
  plt.xlabel('Epoch')
  plt.legend(['Train', 'Test'], loc='upper left')
  plt.show()
  
  # Plot training & validation loss values
  plt.plot(history.history['loss'])
  plt.plot(history.history['val_loss'])
  plt.title('Model loss')
  plt.ylabel('Loss')
  plt.xlabel('Epoch')
  plt.legend(['Train', 'Test'], loc='upper left')
  plt.show()

# %% [markdown]
#  here, it can be seen after which epoch (if more are used) the odel starts to overfit..
#
#  Here, it can be seen that after 175 epochs,the model starts to overfit. (Training acc is larger than valdation acc, which should be possible without overfitting, and training loss is less than actual valdation loss)...

# %% [markdown]
# ## Make predictions

# %% [markdown]
# #### Making a classification 'report' and a confusion matrix

# %%
predictions = model.predict(x_test, verbose=0)  #https://www.tensorflow.org/tutorials/keras/classification
# Get most likely class
predicted_classes = np.argmax(predictions, axis=1)



# Have true classes (y_test). in order to make confusion matrix im chaning to Pythn scikit lib. (could use others)
import sklearn.metrics as metrics
#therefore, getting stats in scicit (even if I have it fron keras..)
report = metrics.classification_report(y_test_scivit, predicted_classes)
print(report)
# Out:
#               precision    recall  f1-score   support
#
#            0       0.88      0.36      0.51      1000
#            1       0.89      0.64      0.74      1000
#            2       0.60      0.38      0.46      1000
#            3       0.43      0.47      0.45      1000
#            4       0.50      0.62      0.55      1000
#            5       0.56      0.56      0.56      1000
#            6       0.49      0.92      0.64      1000
#            7       0.87      0.54      0.67      1000
#            8       0.66      0.85      0.75      1000
#            9       0.72      0.81      0.76      1000
#
#     accuracy                           0.61     10000
#    macro avg       0.66      0.61      0.61     10000
# weighted avg       0.66      0.61      0.61     10000

# %% [markdown]
# Making confusion matrix and showing (normalized and not). If values are wanted, remove ''' in function...

# %%
import numpy as np
#Defining classes for confusion matrix plot
classes = np.array(['airplanes', 'cars', 'birds', 'cats', 'deer', 'dogs', 'frogs', 'horses', 'ships', 'trucks']);
# Plot non-normalized confusion matrix
plot_confusion_matrix(y_test_scivit, predicted_classes, classes=classes,title='Confusion matrix, without normalization');
# Plot normalized confusion matrix
plot_confusion_matrix(y_test_scivit, predicted_classes, classes=classes, normalize=True,title='Normalized confusion matrix');
# Out:
# Confusion matrix, without normalization
# [[357  17 130  32  81   9  51   6 261  56]
#  [  2 637   1  12  13   7  67   4  64 193]
#  [ 22   1 379  93 174  81 214  12  16   8]
#  [  2   3  32 473  63 169 231   8  15   4]
#  [  3   1  29  67 616  30 212  23  16   3]
#  [  2   1  21 257  62 559  74  17   6   1]
#  [  0   0  12  48  12   4 923   0   1   0]
#  [  2   1  20  58 191 123  50 542   1  12]
#  [ 12  17   5  34  16   3  32   2 849  30]
#  [  3  37   4  27  15   5  45   7  50 807]]
# Normalized confusion matrix
# [[0.357 0.017 0.13  0.032 0.081 0.009 0.051 0.006 0.261 0.056]
#  [0.002 0.637 0.001 0.012 0.013 0.007 0.067 0.004 0.064 0.193]
#  [0.022 0.001 0.379 0.093 0.174 0.081 0.214 0.012 0.016 0.008]
#  [0.002 0.003 0.032 0.473 0.063 0.169 0.231 0.008 0.015 0.004]
#  [0.003 0.001 0.029 0.067 0.616 0.03  0.212 0.023 0.016 0.003]
#  [0.002 0.001 0.021 0.257 0.062 0.559 0.074 0.017 0.006 0.001]
#  [0.    0.    0.012 0.048 0.012 0.004 0.923 0.    0.001 0.   ]
#  [0.002 0.001 0.02  0.058 0.191 0.123 0.05  0.542 0.001 0.012]
#  [0.012 0.017 0.005 0.034 0.016 0.003 0.032 0.002 0.849 0.03 ]
#  [0.003 0.037 0.004 0.027 0.015 0.005 0.045 0.007 0.05  0.807]]

# %% [markdown]
# ## Save model and weights for further use.

# %%
from keras.models import load_model
from keras.models import model_from_json
from keras.models import model_from_yaml
import keras
 # creates a HDF5 file 
model_name
model.save(model_name) 
# Creates json file, to see architecture
# serialize model to JSON
model_json = model.to_json()
with open(model_name+"json.json", "w") as json_file:
    json_file.write(model_json)
# serialize weights to HDF5
model.save_weights(model_name+"weights.h5")
print("Saved model to disk")

print(model_name)
# Out:
# WARNING:tensorflow:From /tensorflow-2.0.0/python3.6/tensorflow_core/python/ops/resource_variable_ops.py:1781: calling BaseResourceVariable.__init__ (from tensorflow.python.ops.resource_variable_ops) with constraint is deprecated and will be removed in a future version.
# Instructions for updating:
# If using Keras pass *_constraint arguments to layers.
# INFO:tensorflow:Assets written to: inClass_presentation/assets
# Saved model to disk
# inClass_presentation

# %%
# !ls
# Out:
# airplane.jpg				inClass_presentationjson.json
# Anas_car.jpg				inClass_presentationweights.h5
# deer.jpg				model_plot_CNNmodel_name.png
# frog.jpg				myCar2.png
# good_prediction_presentation		myCar.jpg
# good_prediction_presentationjson.json	sample_data
# good_prediction_presentationweights.h5	ship.jpg
# inClass_presentation

# %%
print(model_name+"weights.h5")
# Out:
# inClass_presentationweights.h5

# %%
from keras.preprocessing import image
image2 = image.load_img('airplane.jpg',target_size=(32,32))
plt.imshow(image2)
image2 = image.img_to_array(image2)/255
image2 = np.expand_dims(image2,axis=0)
result = model.predict(image2)
predicted_class_indices=np.argmax(result)
print(result)
classes = np.array(['airplanes', 'cars', 'birds', 'cats', 'deer', 'dogs', 'frogs', 'horses', 'ships', 'trucks']);
print('The picture belongs to class: ',classes[predicted_class_indices])
# Out:
# [[9.7265583e-01 2.7563795e-04 1.7209252e-02 1.5160485e-04 1.0762571e-03
#   4.9440278e-05 4.8037575e-05 1.9586206e-04 8.1884973e-03 1.4952314e-04]]
# The picture belongs to class:  airplanes

# %%
from keras.preprocessing import image
image2 = image.load_img('frog.jpg',target_size=(32,32))
plt.imshow(image2)
image2 = image.img_to_array(image2)/255
image2 = np.expand_dims(image2,axis=0)
result = model.predict(image2)
predicted_class_indices=np.argmax(result)
print(result)
classes = np.array(['airplanes', 'cars', 'birds', 'cats', 'deer', 'dogs', 'frogs', 'horses', 'ships', 'trucks']);
print('The picture belongs to class: ',classes[predicted_class_indices])
# Out:
# [[1.8728893e-03 7.3363859e-04 7.0706867e-02 9.6613606e-03 5.2940897e-03
#   1.4119061e-03 9.0946895e-01 1.9893366e-04 3.4947891e-04 3.0176825e-04]]
# The picture belongs to class:  frogs

# %%
image2 = image.load_img('myCar.jpg',target_size=(32,32))
plt.imshow(image2)
image2 = image.img_to_array(image2)/255
image2 = np.expand_dims(image2,axis=0)
result = model.predict(image2)
predicted_class_indices=np.argmax(result,axis=1)
predicted_class_indices=np.argmax(result)
classes = np.array(['airplanes', 'cars', 'birds', 'cats', 'deer', 'dogs', 'frogs', 'horses', 'ships', 'trucks']);
print('The picture belongs to class: ',classes[predicted_class_indices])
# Out:
# The picture belongs to class:  airplanes

# %%
image2 = image.load_img('ship.jpg',target_size=(32,32))
plt.imshow(image2)
image2 = image.img_to_array(image2)/255
image2 = np.expand_dims(image2,axis=0)
result = model.predict(image2)
predicted_class_indices=np.argmax(result)
classes = np.array(['airplanes', 'cars', 'birds', 'cats', 'deer', 'dogs', 'frogs', 'horses', 'ships', 'trucks']);
print('The picture belongs to class: ',classes[predicted_class_indices])
# Out:
# The picture belongs to class:  ships

# %%
image2 = image.load_img('deer.jpg',target_size=(32,32))
image2 = x_train[105]
plt.imshow(image2)
image2 = image.img_to_array(image2)
image2 = np.expand_dims(image2,axis=0)
result = model.predict(image2)
predicted_class_indices=np.argmax(result)
classes = np.array(['airplanes', 'cars', 'birds', 'cats', 'deer', 'dogs', 'frogs', 'horses', 'ships', 'trucks']);
print('The picture belongs to class: ',classes[predicted_class_indices])
# Out:
# The picture belongs to class:  cars

# %%
image2 = x_train[1]
plt.imshow(image2)
image2 = image.img_to_array(image2)
image2 = np.expand_dims(image2,axis=0)
result = model.predict(image2)
predicted_class_indices=np.argmax(result)
classes = np.array(['airplanes', 'cars', 'birds', 'cats', 'deer', 'dogs', 'frogs', 'horses', 'ships', 'trucks']);
print('The picture belongs to class: ',classes[predicted_class_indices])
# Out:
# The picture belongs to class:  trucks

# %%
image2 = image.load_img('deer.jpg',target_size=(32,32))
plt.imshow(image2)
image2 = image.img_to_array(image2)/255
image2 = np.expand_dims(image2,axis=0)
result = model.predict(image2)
predicted_class_indices=np.argmax(result)
classes = np.array(['airplanes', 'cars', 'birds', 'cats', 'deer', 'dogs', 'frogs', 'horses', 'ships', 'trucks']);
print('The picture belongs to class: ',classes[predicted_class_indices])
# Out:
# The picture belongs to class:  frogs

# %%
weights1, biases1 = model.layers[0].get_weights()
plt.imshow(weights1[:, :,0,0])

# %%
image2 = image.load_img('AnasCar.png',target_size=(32,32))
plt.imshow(image2)
image2 = image.img_to_array(image2)/255
image2 = np.expand_dims(image2,axis=0)
result = model.predict(image2)
print(result)
predicted_class_indices=np.argmax(result)
classes = np.array(['airplanes', 'cars', 'birds', 'cats', 'deer', 'dogs', 'frogs', 'horses', 'ships', 'trucks']);
print('The picture belongs to class: ',classes[predicted_class_indices])
# Out:
# [[0.05282349 0.6818236  0.0072037  0.00648317 0.00470515 0.00199727
#   0.02559766 0.00095957 0.1443672  0.07403915]]
# The picture belongs to class:  cars

# %%
image2 = image.load_img('Anas_car.jpg',target_size=(32,32))
plt.imshow(image2)
image2 = image.img_to_array(image2)/255
image2 = np.expand_dims(image2,axis=0)
result = model.predict(image2)
print(result)
predicted_class_indices=np.argmax(result)
classes = np.array(['airplanes', 'cars', 'birds', 'cats', 'deer', 'dogs', 'frogs', 'horses', 'ships', 'trucks']);
print('The picture belongs to class: ',classes[predicted_class_indices])
# Out:
# [[0.16392598 0.10598155 0.14121945 0.04701359 0.10523752 0.01204185
#   0.24105196 0.01096496 0.14553106 0.02703208]]
# The picture belongs to class:  frogs
