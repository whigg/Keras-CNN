# %% [markdown]
# <a href="https://colab.research.google.com/github/aalling93/ENGR562_CNN/blob/master/A_study_of_CNN_github.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # CNN MODEL
#
# Building a CNN model is easy! In this notebook, the theory from the article 'A study of Convolutional Neural Network'[Sorensen(2019)] will be implemented in a simple CNN.
#
# Many frameworks and libraries usefull for machine learning exists.  Here, the keras library is used in order to utilize the Tensorflow framework.
#
# This notebook covers the following:
#
# - Initialization: installing and importing packages.
# - Importing a dataset: A dataset is needed to build and train a model.
# - Preparing the model: Defining the hyperparamters used.
# - Building a model: Using layers, fundtions ect as seen in [Sorensen(2019)].
# - Training the model: Using the imported data, the build model is trained using a loss function and optimizer.
# - Visualization of intermediate CNN results and statistics
# - Saving the model
#
# For further tutorials, see e.g.  https://medium.com/nybles/create-your-first-image-recognition-classifier-using-cnn-keras-and-tensorflow-backend-6eaab98d14dd or https://towardsdatascience.com/cnn-architectures-a-deep-dive-a99441d18049

# %% [markdown]
# ## Initialization
# Firstly, install needed packages and check for version.

# %%
#! pip install torch
#! pip install torchvision
#! pip install pandas==0.23.4
#! pip install geopandas
#! pip install keras
#! pip install tensorflow
#! pip install tf-nightly
#! pip install ggplot
#! pip install -U PyYAML
try:
  # %tensorflow_version only exists in Colab.
  # %tensorflow_version 2.x
except Exception:
  pass

from __future__ import absolute_import, division, print_function, unicode_literals
# TensorFlow and tf.keras
import tensorflow as tf
from tensorflow import keras
from keras import regularizers
# Helper libraries
import numpy as np
import matplotlib.pyplot as plt
from tensorflow.keras.datasets import cifar10
from tensorflow.keras.preprocessing.image import ImageDataGenerator
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Dense, Dropout, Activation, Flatten, BatchNormalization
from tensorflow.keras.layers import Conv2D, MaxPooling2D
import os
#To visualize it..
from tensorflow.keras.utils import plot_model
from IPython.display import SVG
from tensorflow.keras.utils import model_to_dot

print(tf.__version__)
# Out:
# TensorFlow 2.x selected.
# 2.0.0
# Using TensorFlow backend.

# %%
# FUNCTIONS
import numpy as np
import time
import matplotlib.pyplot as plt
from __future__ import print_function
from sklearn import svm, datasets
from sklearn.model_selection import train_test_split
from sklearn.metrics import confusion_matrix
from sklearn.utils.multiclass import unique_labels
from PIL import Image as pil_image
from tensorflow.keras.preprocessing.image import save_img
from tensorflow.keras import layers
from tensorflow.keras.applications import vgg16
from tensorflow.keras import backend as K

def plot_confusion_matrix(y_true, y_pred, classes,
                          normalize=False,
                          title=None,
                          cmap=plt.cm.Blues,want_title=None):
    """
    This function prints and plots the confusion matrix. Noting more... It uses the sklearn lib.
    Normalization can be applied by setting `normalize=True`.
    """
    #making title.. (for my article, i dont want then, thus the want_title)
    if not title:
        if normalize:
            title = 'Normalized confusion matrix'
        else:
            title = 'Confusion matrix, without normalization'

    # Compute confusion matrix
    cm = confusion_matrix(y_true, y_pred)
    # Only use the labels that appear in the data
    classes = classes[unique_labels(y_true, y_pred)]
    if normalize:
        cm = cm.astype('float') / cm.sum(axis=1)[:, np.newaxis]
        print("Normalized confusion matrix")
    else:
        print('Confusion matrix, without normalization')

    print(cm)

    fig, ax = plt.subplots(figsize=(6,6))
    im = ax.imshow(cm, interpolation='nearest', cmap=cmap)
    ax.figure.colorbar(im, ax=ax)
    
    # We want to show all ticks...
    if want_title!= None:
      ax.set(xticks=np.arange(cm.shape[1]),
             yticks=np.arange(cm.shape[0]),
             # ... and label them with the respective list entries
             xticklabels=classes, yticklabels=classes,
             title=title,
             ylabel='True label',
             xlabel='Predicted label')
    else:
      ax.set(xticks=np.arange(cm.shape[1]),
             yticks=np.arange(cm.shape[0]),
             # ... and label them with the respective list entries
             xticklabels=classes, yticklabels=classes,
             ylabel='True label',
             xlabel='Predicted label')        

    # Rotate the tick labels and set their alignment.
    plt.setp(ax.get_xticklabels(), rotation=45, ha="right",
             rotation_mode="anchor")
    # I dont want the actualy probabilities in the plot, since its meassy when exporting to latex. 
    # but, for examinations it's fine. 
    """
    Loop over data dimensions and create text annotations.
    fmt = '.2f' if normalize else 'd'
    thresh = cm.max() / 2.
    for i in range(cm.shape[0]):
        for j in range(cm.shape[1]):
            ax.text(j, i, format(cm[i, j], fmt),
                    ha="center", va="center",
                    color="white" if cm[i, j] > thresh else "black")
    fig.tight_layout()
    """
    return ax

# %% [markdown]
# ## Importing a dataset
#
# Here, im important a dataset from keras pre-defined data sets, see https://keras.io/datasets/
#
# The CIFAR10 dataset:
# Dataset of 50,000 32x32 color training images, labeled over 10 categories, and 10,000 test images. It is thus good for illustrating pupose of a CNN. https://www.cs.toronto.edu/~kriz/cifar.html
#
# The images are uint8 array of RGB image data with shape (num_samples, 3, 32, 32) or (num_samples, 32, 32, 3) based on the image_data_format backend setting of either
# Since the dataset is predefined in Keras, it can do the labelling. Otherwise classes must be defined>

# %%
#loading the set directly from keras bucket.
cifar100 = tf.keras.datasets.cifar100
#defining training(test) data and its labels. The data, split between train and test sets:
(x_train, y_train), (x_test, y_test) = cifar10.load_data()
#see a bit of stats..
print('x_train shape:', x_train.shape)
print(x_train.shape[0], 'train samples')
print(x_test.shape[0], 'test samples')
# The data is already labbeled.. Othervise, define into classes like:
# class_names = ['dolphin', 'dog', 'cat', 'mouse', 'ape',  '...']
# Out:
# x_train shape: (50000, 32, 32, 3)
# 50000 train samples
# 10000 test samples

# %% [markdown]
# ## Preparing the model

# %%
# Convert class vectors to binary class matrices.
num_classes = 10 #from 100 to 10 classes....# in the CIFAR10 theres 10 classes extracted from the CIFAR100 dataset..
y_test_scivit = np.squeeze(np.copy(y_test)) #used for confusin matrix in scilearn lib. AFTER predictions are made...
y_train = tf.keras.utils.to_categorical(y_train, num_classes)
y_test = tf.keras.utils.to_categorical(y_test, num_classes)

# %% [markdown]
# Here, the defined test data can be used to evaluate the model using the error function described in the theory. It could be applied as K-fold, leave-on-out or even a cross validation (take hella long time tho).
#
# ## Exploring the classes

# %%
plt.figure()
plt.imshow(x_train[0])
plt.colorbar()
plt.grid(False)
plt.show()

# %% [markdown]
# ## Building the CNN
# layers, as described in the theory can now be added to the model
# see https://towardsdatascience.com/building-a-convolutional-neural-network-cnn-in-keras-329fbbadc5f5

# %% [markdown]
# ### Defining Hyper parameters
#
# Hyper parameters to control the size of the output of CNN layer. Depth, stride and zero padding..

# %%
# Save model and weights
model_name = 'model_100_epochs_5.h5'
#filter size
filter_size = 2
#If padding isnt the deafult, this value should be used (now keras defult is used..)
padding  = (filter_size-1)/2
filter_size = (filter_size,filter_size)
# Stride controls the "overlap" between neighoboring convolutions. For sattellite image, a strid of e.g. 10 is smart . This reduces the dimension.. If stride=1, we move filter one pixel at a time. 
# atm, keras deafult is used = the same size as pooling.. 
stride = 3 
#depth is number of neurons(filters) in the given layer connected to the input (either original img or feature img).
filters_first_layer = 32 #currencty, this value is also used for other layers..
# Epoch is the number each batch is trained
epoch=200
#Using batch learning as in the theory
batch_size = 1000
#num_predictions = 20

# %% [markdown]
# ### Making model

# %%
#------------------------ BUILING THE MODEL ------------------------------------
# Initializing the model using Sequntial(), The Sequential model is a linear stack of layers. https://keras.io/getting-started/sequential-model-guide/
model = Sequential()
#adding a convolutional layer, https://keras.io/layers/convolutional/
model.add(Conv2D(filters_first_layer, filter_size, padding='same',input_shape=x_train.shape[1:]))
#adding activation function
model.add(Activation('relu'))
#adding Maxpooling as described in the theory and https://keras.io/layers/pooling/. Default stride is the same as pool..
#regularization, https://keras.io/layers/core/
model.add(Dropout(0.1))
#this "block" of layers (convolutional layer, activation, pooling and regularization) can now be applied a number of times.... i.e copy pastye..
# ---- 2nd block
model.add(Conv2D(filters_first_layer, filter_size))
model.add(Activation('relu'))
model.add(BatchNormalization())
model.add(MaxPooling2D(pool_size=(2, 2)))
# --- 3rd block -------
model.add(Conv2D(filters_first_layer*2, filter_size, padding='same'))
model.add(Activation('relu'))
model.add(BatchNormalization())
# --- 4rd block -------
model.add(Conv2D(filters_first_layer*3, filter_size, padding='same'))
model.add(Activation('relu'))
model.add(BatchNormalization())
model.add(MaxPooling2D(pool_size=(2, 2)))
model.add(Dropout(0.2))
# --- 5rd block -------
model.add(Conv2D(filters_first_layer*4, filter_size, padding='same'))
model.add(Activation('relu'))
model.add(BatchNormalization())
model.add(MaxPooling2D(pool_size=(2, 2)))
model.add(Dropout(0.3))
# ---6th block -------
model.add(Conv2D(filters_first_layer, filter_size, padding='same'))
model.add(Activation('relu'))
model.add(BatchNormalization())
model.add(MaxPooling2D(pool_size=(2, 2)))
model.add(Dropout(0.1))
#Flattens the input. Does not affect the batch size needed for FC... see https://medium.com/nybles/create-your-first-image-recognition-classifier-using-cnn-keras-and-tensorflow-backend-6eaab98d14dd
model.add(Flatten())
#Just your regular densely-connected NN layer, i.e. the FC...adding different weight regularizers. Lastly,activation function to classify...
model.add(Dense(10, kernel_regularizer=regularizers.l2(0.0001),bias_regularizer=regularizers.l2(0.001),activity_regularizer=regularizers.l2(0.001),activation='softmax',use_bias=False))
#model.add(Dense(10, activation='softmax',use_bias=False))

# %% [markdown]
# ## Training the model

# %% [markdown]
# ### Define back propagation optimizer and loss function.
# In the theory, the equation for the Gradient Descent is explained. This is optimizer is used with the loss of cross entropy.
#
# Recall. Gradient descent applied to a batch is called mini-batch learning.
#
#
# Optimizer: https://keras.io/optimizers/.
#
# Loss function: https://keras.io/losses/.

# %%
# an optimizer is required to train a keras model, https://keras.io/optimizers/. As described in the theory, as GRADIENT DESCENT is used here..
#  The loss function is here defined, https://keras.io/losses/. In the theory, the kullback_leibler_divergence and cross entropy..  Since classes are integer, sparse_categorical_crossentropy is used
optimizer = keras.optimizers.SGD(lr=0.05)
model.compile(loss='categorical_crossentropy',optimizer=optimizer,metrics=['accuracy'])
print("Showing sizes of datasets..")
print(x_train.shape,y_train.shape,x_test.shape,y_test.shape)
# Out:
# Showing sizes of datasets..
# (50000, 32, 32, 3) (50000, 10) (10000, 32, 32, 3) (10000, 10)

# %% [markdown]
# In illustation of the data, we saw the scale on the colour plot. This is scalled to [0,1] before its used to fit the model.

# %%
#Scaling the data from [0:255] to [0:1]..
x_test = x_test.astype('float32')
x_train = x_train.astype('float32')
x_train /= 255
x_test /= 255

# %% [markdown]
# ### Fitting the model:
# Using the model of the CNN, the model is not TRAINED using the labels.
# - the batch size is used (how many feature maps in one batch)
# - the epochs are used (how many times a batch is trained)
# Moreover, the training data is used (data and labels) to train, and is validated on the test data (data and labels)

# %%
#https://keras.io/models/sequential/
# History is used to track the changed for plotting..
history = model.fit(x_train, y_train,batch_size=batch_size,epochs=epoch, validation_data=(x_test, y_test),shuffle=True)
# Out:
# Train on 50000 samples, validate on 10000 samples
# Epoch 1/200
# 50000/50000 [==============================] - 6s 123us/sample - loss: 2.2112 - accuracy: 0.2446 - val_loss: 2.3442 - val_accuracy: 0.1000
# Epoch 2/200
# 50000/50000 [==============================] - 3s 61us/sample - loss: 1.8099 - accuracy: 0.3332 - val_loss: 2.3686 - val_accuracy: 0.1008
# Epoch 3/200
# 50000/50000 [==============================] - 3s 62us/sample - loss: 1.6832 - accuracy: 0.3748 - val_loss: 2.3820 - val_accuracy: 0.1281
# Epoch 4/200
# 50000/50000 [==============================] - 3s 62us/sample - loss: 1.6010 - accuracy: 0.4110 - val_loss: 2.4006 - val_accuracy: 0.1660
# Epoch 5/200
# 50000/50000 [==============================] - 3s 61us/sample - loss: 1.5358 - accuracy: 0.4310 - val_loss: 2.4059 - val_accuracy: 0.1873
# Epoch 6/200
# 50000/50000 [==============================] - 3s 61us/sample - loss: 1.4841 - accuracy: 0.4545 - val_loss: 2.3645 - val_accuracy: 0.2144
# Epoch 7/200
# 50000/50000 [==============================] - 3s 61us/sample - loss: 1.4363 - accuracy: 0.4726 - val_loss: 2.3036 - val_accuracy: 0.2055
# Epoch 8/200
# 50000/50000 [==============================] - 3s 62us/sample - loss: 1.3934 - accuracy: 0.4907 - val_loss: 2.0401 - val_accuracy: 0.2452
# Epoch 9/200
# 50000/50000 [==============================] - 3s 62us/sample - loss: 1.3604 - accuracy: 0.5060 - val_loss: 2.0219 - val_accuracy: 0.2451
# Epoch 10/200
# 50000/50000 [==============================] - 3s 61us/sample - loss: 1.3236 - accuracy: 0.5184 - val_loss: 1.7274 - val_accuracy: 0.3248
# Epoch 11/200
# 50000/50000 [==============================] - 3s 61us/sample - loss: 1.2903 - accuracy: 0.5317 - val_loss: 1.6139 - val_accuracy: 0.3971
# Epoch 12/200
# 50000/50000 [==============================] - 3s 62us/sample - loss: 1.2679 - accuracy: 0.5405 - val_loss: 1.6662 - val_accuracy: 0.4033
# Epoch 13/200
# 50000/50000 [==============================] - 3s 61us/sample - loss: 1.2424 - accuracy: 0.5501 - val_loss: 1.3827 - val_accuracy: 0.4915
# Epoch 14/200
# 50000/50000 [==============================] - 3s 61us/sample - loss: 1.2176 - accuracy: 0.5604 - val_loss: 1.3644 - val_accuracy: 0.4975
# Epoch 15/200
# 50000/50000 [==============================] - 3s 61us/sample - loss: 1.1994 - accuracy: 0.5677 - val_loss: 1.1726 - val_accuracy: 0.5826
# Epoch 16/200
# 50000/50000 [==============================] - 3s 62us/sample - loss: 1.1796 - accuracy: 0.5742 - val_loss: 1.3986 - val_accuracy: 0.4952
# Epoch 17/200
# 50000/50000 [==============================] - 3s 62us/sample - loss: 1.1559 - accuracy: 0.5829 - val_loss: 1.1547 - val_accuracy: 0.5875
# Epoch 18/200
# 50000/50000 [==============================] - 3s 61us/sample - loss: 1.1391 - accuracy: 0.5904 - val_loss: 1.2531 - val_accuracy: 0.5444
# Epoch 19/200
# 50000/50000 [==============================] - 3s 62us/sample - loss: 1.1260 - accuracy: 0.5923 - val_loss: 1.1683 - val_accuracy: 0.5872
# Epoch 20/200
# 50000/50000 [==============================] - 3s 62us/sample - loss: 1.1083 - accuracy: 0.6021 - val_loss: 1.1678 - val_accuracy: 0.5914
# Epoch 21/200
# 50000/50000 [==============================] - 3s 61us/sample - loss: 1.0930 - accuracy: 0.6072 - val_loss: 1.0774 - val_accuracy: 0.6089
# Epoch 22/200
# 50000/50000 [==============================] - 3s 61us/sample - loss: 1.0760 - accuracy: 0.6145 - val_loss: 1.1937 - val_accuracy: 0.5651
# Epoch 23/200
# 50000/50000 [==============================] - 3s 61us/sample - loss: 1.0648 - accuracy: 0.6180 - val_loss: 1.0320 - val_accuracy: 0.6330
# Epoch 24/200
# 50000/50000 [==============================] - 3s 62us/sample - loss: 1.0555 - accuracy: 0.6202 - val_loss: 1.0568 - val_accuracy: 0.6278
# Epoch 25/200
# 50000/50000 [==============================] - 3s 62us/sample - loss: 1.0391 - accuracy: 0.6287 - val_loss: 1.0803 - val_accuracy: 0.6143
# Epoch 26/200
# 50000/50000 [==============================] - 3s 61us/sample - loss: 1.0334 - accuracy: 0.6296 - val_loss: 1.0080 - val_accuracy: 0.6461
# Epoch 27/200
# 50000/50000 [==============================] - 3s 62us/sample - loss: 1.0168 - accuracy: 0.6371 - val_loss: 1.0136 - val_accuracy: 0.6345
# Epoch 28/200
# 50000/50000 [==============================] - 3s 61us/sample - loss: 1.0039 - accuracy: 0.6387 - val_loss: 0.9916 - val_accuracy: 0.6555
# Epoch 29/200
# 50000/50000 [==============================] - 3s 61us/sample - loss: 1.0013 - accuracy: 0.6406 - val_loss: 1.0754 - val_accuracy: 0.6328
# Epoch 30/200
# 50000/50000 [==============================] - 3s 61us/sample - loss: 0.9893 - accuracy: 0.6476 - val_loss: 0.9718 - val_accuracy: 0.6557
# Epoch 31/200
# 50000/50000 [==============================] - 3s 61us/sample - loss: 0.9787 - accuracy: 0.6491 - val_loss: 0.9830 - val_accuracy: 0.6471
# Epoch 32/200
# 50000/50000 [==============================] - 3s 62us/sample - loss: 0.9724 - accuracy: 0.6522 - val_loss: 0.9092 - val_accuracy: 0.6781
# Epoch 33/200
# 50000/50000 [==============================] - 3s 61us/sample - loss: 0.9603 - accuracy: 0.6578 - val_loss: 0.9327 - val_accuracy: 0.6730
# Epoch 34/200
# 50000/50000 [==============================] - 3s 61us/sample - loss: 0.9532 - accuracy: 0.6571 - val_loss: 0.9216 - val_accuracy: 0.6771
# Epoch 35/200
# 50000/50000 [==============================] - 3s 61us/sample - loss: 0.9475 - accuracy: 0.6601 - val_loss: 0.9429 - val_accuracy: 0.6627
# Epoch 36/200
# 50000/50000 [==============================] - 3s 62us/sample - loss: 0.9368 - accuracy: 0.6673 - val_loss: 0.9358 - val_accuracy: 0.6693
# Epoch 37/200
# 50000/50000 [==============================] - 3s 61us/sample - loss: 0.9312 - accuracy: 0.6678 - val_loss: 0.8858 - val_accuracy: 0.6834
# Epoch 38/200
# 50000/50000 [==============================] - 3s 62us/sample - loss: 0.9247 - accuracy: 0.6703 - val_loss: 0.8977 - val_accuracy: 0.6821
# Epoch 39/200
# 50000/50000 [==============================] - 3s 61us/sample - loss: 0.9214 - accuracy: 0.6721 - val_loss: 0.8938 - val_accuracy: 0.6820
# Epoch 40/200
# 50000/50000 [==============================] - 3s 61us/sample - loss: 0.9116 - accuracy: 0.6752 - val_loss: 1.0275 - val_accuracy: 0.6359
# Epoch 41/200
# 50000/50000 [==============================] - 3s 61us/sample - loss: 0.9085 - accuracy: 0.6785 - val_loss: 0.9280 - val_accuracy: 0.6643
# Epoch 42/200
# 50000/50000 [==============================] - 3s 61us/sample - loss: 0.8987 - accuracy: 0.6804 - val_loss: 0.9392 - val_accuracy: 0.6619
# Epoch 43/200
# 50000/50000 [==============================] - 3s 61us/sample - loss: 0.8924 - accuracy: 0.6827 - val_loss: 1.0063 - val_accuracy: 0.6451
# Epoch 44/200
# 50000/50000 [==============================] - 3s 62us/sample - loss: 0.8882 - accuracy: 0.6867 - val_loss: 0.8813 - val_accuracy: 0.6883
# Epoch 45/200
# 50000/50000 [==============================] - 3s 62us/sample - loss: 0.8781 - accuracy: 0.6873 - val_loss: 0.8497 - val_accuracy: 0.7020
# Epoch 46/200
# 50000/50000 [==============================] - 3s 61us/sample - loss: 0.8730 - accuracy: 0.6910 - val_loss: 0.9325 - val_accuracy: 0.6787
# Epoch 47/200
# 50000/50000 [==============================] - 3s 60us/sample - loss: 0.8664 - accuracy: 0.6915 - val_loss: 0.8843 - val_accuracy: 0.6898
# Epoch 48/200
# 50000/50000 [==============================] - 3s 60us/sample - loss: 0.8629 - accuracy: 0.6940 - val_loss: 0.8452 - val_accuracy: 0.6980
# Epoch 49/200
# 50000/50000 [==============================] - 3s 60us/sample - loss: 0.8559 - accuracy: 0.6971 - val_loss: 0.8924 - val_accuracy: 0.6823
# Epoch 50/200
# 50000/50000 [==============================] - 3s 60us/sample - loss: 0.8528 - accuracy: 0.6964 - val_loss: 0.8309 - val_accuracy: 0.7032
# Epoch 51/200
# 50000/50000 [==============================] - 3s 60us/sample - loss: 0.8386 - accuracy: 0.7023 - val_loss: 0.8912 - val_accuracy: 0.6809
# Epoch 52/200
# 50000/50000 [==============================] - 3s 60us/sample - loss: 0.8407 - accuracy: 0.7010 - val_loss: 0.8845 - val_accuracy: 0.6970
# Epoch 53/200
# 50000/50000 [==============================] - 3s 60us/sample - loss: 0.8340 - accuracy: 0.7011 - val_loss: 0.9051 - val_accuracy: 0.6858
# Epoch 54/200
# 50000/50000 [==============================] - 3s 60us/sample - loss: 0.8269 - accuracy: 0.7055 - val_loss: 0.8304 - val_accuracy: 0.7112
# Epoch 55/200
# 50000/50000 [==============================] - 3s 59us/sample - loss: 0.8274 - accuracy: 0.7069 - val_loss: 0.8012 - val_accuracy: 0.7209
# Epoch 56/200
# 50000/50000 [==============================] - 3s 60us/sample - loss: 0.8186 - accuracy: 0.7079 - val_loss: 0.8561 - val_accuracy: 0.7029
# Epoch 57/200
# 50000/50000 [==============================] - 3s 60us/sample - loss: 0.8146 - accuracy: 0.7098 - val_loss: 0.8432 - val_accuracy: 0.7066
# Epoch 58/200
# 50000/50000 [==============================] - 3s 60us/sample - loss: 0.8083 - accuracy: 0.7150 - val_loss: 0.8331 - val_accuracy: 0.7089
# Epoch 59/200
# 50000/50000 [==============================] - 3s 60us/sample - loss: 0.8039 - accuracy: 0.7146 - val_loss: 0.9507 - val_accuracy: 0.6595
# Epoch 60/200
# 50000/50000 [==============================] - 3s 61us/sample - loss: 0.8017 - accuracy: 0.7134 - val_loss: 0.8103 - val_accuracy: 0.7180
# Epoch 61/200
# 50000/50000 [==============================] - 3s 60us/sample - loss: 0.7978 - accuracy: 0.7173 - val_loss: 0.8100 - val_accuracy: 0.7108
# Epoch 62/200
# 50000/50000 [==============================] - 3s 59us/sample - loss: 0.7960 - accuracy: 0.7178 - val_loss: 0.7730 - val_accuracy: 0.7314
# Epoch 63/200
# 50000/50000 [==============================] - 3s 60us/sample - loss: 0.7862 - accuracy: 0.7227 - val_loss: 0.8288 - val_accuracy: 0.7104
# Epoch 64/200
# 50000/50000 [==============================] - 3s 60us/sample - loss: 0.
200
# 50000/50000 [==============================] - 3s 59us/sample - loss: 0.5937 - accuracy: 0.7931 - val_loss: 0.6539 - val_accuracy: 0.7774
# Epoch 128/200
# 50000/50000 [==============================] - 3s 60us/sample - loss: 0.5964 - accuracy: 0.7907 - val_loss: 0.6530 - val_accuracy: 0.7796
# Epoch 129/200
# 50000/50000 [==============================] - 3s 59us/sample - loss: 0.5914 - accuracy: 0.7912 - val_loss: 0.6489 - val_accuracy: 0.7776
# Epoch 130/200
# 50000/50000 [==============================] - 3s 61us/sample - loss: 0.5848 - accuracy: 0.7941 - val_loss: 0.6933 - val_accuracy: 0.7605
# Epoch 131/200
# 50000/50000 [==============================] - 3s 60us/sample - loss: 0.5849 - accuracy: 0.7942 - val_loss: 0.7294 - val_accuracy: 0.7524
# Epoch 132/200
# 50000/50000 [==============================] - 3s 60us/sample - loss: 0.5840 - accuracy: 0.7940 - val_loss: 0.7033 - val_accuracy: 0.7543
# Epoch 133/200
# 50000/50000 [==============================] - 3s 60us/sample - loss: 0.5837 - accuracy: 0.7955 - val_loss: 0.6628 - val_accuracy: 0.7730
# Epoch 134/200
# 50000/50000 [==============================] - 3s 60us/sample - loss: 0.5810 - accuracy: 0.7957 - val_loss: 0.6363 - val_accuracy: 0.7818
# Epoch 135/200
# 50000/50000 [==============================] - 3s 60us/sample - loss: 0.5770 - accuracy: 0.7970 - val_loss: 0.6397 - val_accuracy: 0.7820
# Epoch 136/200
# 50000/50000 [==============================] - 3s 61us/sample - loss: 0.5792 - accuracy: 0.7971 - val_loss: 0.6608 - val_accuracy: 0.7758
# Epoch 137/200
# 50000/50000 [==============================] - 3s 60us/sample - loss: 0.5726 - accuracy: 0.7973 - val_loss: 0.6771 - val_accuracy: 0.7671
# Epoch 138/200
# 50000/50000 [==============================] - 3s 61us/sample - loss: 0.5717 - accuracy: 0.7996 - val_loss: 0.7045 - val_accuracy: 0.7565
# Epoch 139/200
# 50000/50000 [==============================] - 3s 59us/sample - loss: 0.5689 - accuracy: 0.7985 - val_loss: 0.6639 - val_accuracy: 0.7736
# Epoch 140/200
# 50000/50000 [==============================] - 3s 60us/sample - loss: 0.5683 - accuracy: 0.7997 - val_loss: 0.6629 - val_accuracy: 0.7759
# Epoch 141/200
# 50000/50000 [==============================] - 3s 59us/sample - loss: 0.5649 - accuracy: 0.8010 - val_loss: 0.6713 - val_accuracy: 0.7727
# Epoch 142/200
# 50000/50000 [==============================] - 3s 60us/sample - loss: 0.5657 - accuracy: 0.8016 - val_loss: 0.6580 - val_accuracy: 0.7761
# Epoch 143/200
# 50000/50000 [==============================] - 3s 59us/sample - loss: 0.5628 - accuracy: 0.8014 - val_loss: 0.6982 - val_accuracy: 0.7532
# Epoch 144/200
# 50000/50000 [==============================] - 3s 59us/sample - loss: 0.5602 - accuracy: 0.8023 - val_loss: 0.6436 - val_accuracy: 0.7762
# Epoch 145/200
# 50000/50000 [==============================] - 3s 59us/sample - loss: 0.5585 - accuracy: 0.8056 - val_loss: 0.6418 - val_accuracy: 0.7759
# Epoch 146/200
# 50000/50000 [==============================] - 3s 60us/sample - loss: 0.5577 - accuracy: 0.8044 - val_loss: 0.6567 - val_accuracy: 0.7738
# Epoch 147/200
# 50000/50000 [==============================] - 3s 60us/sample - loss: 0.5551 - accuracy: 0.8056 - val_loss: 0.6035 - val_accuracy: 0.7941
# Epoch 148/200
# 50000/50000 [==============================] - 3s 60us/sample - loss: 0.5537 - accuracy: 0.8051 - val_loss: 0.6871 - val_accuracy: 0.7649
# Epoch 149/200
# 50000/50000 [==============================] - 3s 60us/sample - loss: 0.5542 - accuracy: 0.8040 - val_loss: 0.6857 - val_accuracy: 0.7678
# Epoch 150/200
# 50000/50000 [==============================] - 3s 60us/sample - loss: 0.5476 - accuracy: 0.8081 - val_loss: 0.6294 - val_accuracy: 0.7830
# Epoch 151/200
# 50000/50000 [==============================] - 3s 60us/sample - loss: 0.5437 - accuracy: 0.8080 - val_loss: 0.6270 - val_accuracy: 0.7889
# Epoch 152/200
# 50000/50000 [==============================] - 3s 59us/sample - loss: 0.5465 - accuracy: 0.8080 - val_loss: 0.6300 - val_accuracy: 0.7836
# Epoch 153/200
# 50000/50000 [==============================] - 3s 60us/sample - loss: 0.5427 - accuracy: 0.8096 - val_loss: 0.6690 - val_accuracy: 0.7691
# Epoch 154/200
# 50000/50000 [==============================] - 3s 60us/sample - loss: 0.5410 - accuracy: 0.8088 - val_loss: 0.6650 - val_accuracy: 0.7739
# Epoch 155/200
# 50000/50000 [==============================] - 3s 59us/sample - loss: 0.5445 - accuracy: 0.8094 - val_loss: 0.6231 - val_accuracy: 0.7904
# Epoch 156/200
# 50000/50000 [==============================] - 3s 60us/sample - loss: 0.5363 - accuracy: 0.8104 - val_loss: 0.6366 - val_accuracy: 0.7819
# Epoch 157/200
# 50000/50000 [==============================] - 3s 60us/sample - loss: 0.5413 - accuracy: 0.8107 - val_loss: 0.6581 - val_accuracy: 0.7750
# Epoch 158/200
# 50000/50000 [==============================] - 3s 60us/sample - loss: 0.5375 - accuracy: 0.8119 - val_loss: 0.6068 - val_accuracy: 0.7913
# Epoch 159/200
# 50000/50000 [==============================] - 3s 59us/sample - loss: 0.5356 - accuracy: 0.8108 - val_loss: 0.6773 - val_accuracy: 0.7704
# Epoch 160/200
# 50000/50000 [==============================] - 3s 60us/sample - loss: 0.5293 - accuracy: 0.8133 - val_loss: 0.6521 - val_accuracy: 0.7769
# Epoch 161/200
# 50000/50000 [==============================] - 3s 61us/sample - loss: 0.5323 - accuracy: 0.8144 - val_loss: 0.6261 - val_accuracy: 0.7887
# Epoch 162/200
# 50000/50000 [==============================] - 3s 59us/sample - loss: 0.5303 - accuracy: 0.8131 - val_loss: 0.6254 - val_accuracy: 0.7867
# Epoch 163/200
# 50000/50000 [==============================] - 3s 60us/sample - loss: 0.5267 - accuracy: 0.8144 - val_loss: 0.6292 - val_accuracy: 0.7862
# Epoch 164/200
# 50000/50000 [==============================] - 3s 60us/sample - loss: 0.5221 - accuracy: 0.8166 - val_loss: 0.6198 - val_accuracy: 0.7916
# Epoch 165/200
# 50000/50000 [==============================] - 3s 60us/sample - loss: 0.5231 - accuracy: 0.8172 - val_loss: 0.6356 - val_accuracy: 0.7857
# Epoch 166/200
# 50000/50000 [==============================] - 3s 60us/sample - loss: 0.5237 - accuracy: 0.8151 - val_loss: 0.6232 - val_accuracy: 0.7860
# Epoch 167/200
# 50000/50000 [==============================] - 3s 59us/sample - loss: 0.5218 - accuracy: 0.8185 - val_loss: 0.6546 - val_accuracy: 0.7776
# Epoch 168/200
# 50000/50000 [==============================] - 3s 60us/sample - loss: 0.5209 - accuracy: 0.8160 - val_loss: 0.6204 - val_accuracy: 0.7865
# Epoch 169/200
# 50000/50000 [==============================] - 3s 60us/sample - loss: 0.5206 - accuracy: 0.8159 - val_loss: 0.6412 - val_accuracy: 0.7799
# Epoch 170/200
# 50000/50000 [==============================] - 3s 59us/sample - loss: 0.5130 - accuracy: 0.8183 - val_loss: 0.6990 - val_accuracy: 0.7594
# Epoch 171/200
# 50000/50000 [==============================] - 3s 60us/sample - loss: 0.5152 - accuracy: 0.8177 - val_loss: 0.6040 - val_accuracy: 0.7932
# Epoch 172/200
# 50000/50000 [==============================] - 3s 60us/sample - loss: 0.5134 - accuracy: 0.8188 - val_loss: 0.6048 - val_accuracy: 0.7940
# Epoch 173/200
# 50000/50000 [==============================] - 3s 60us/sample - loss: 0.5112 - accuracy: 0.8206 - val_loss: 0.6074 - val_accuracy: 0.7899
# Epoch 174/200
# 50000/50000 [==============================] - 3s 60us/sample - loss: 0.5138 - accuracy: 0.8190 - val_loss: 0.6407 - val_accuracy: 0.7808
# Epoch 175/200
# 50000/50000 [==============================] - 3s 60us/sample - loss: 0.5100 - accuracy: 0.8196 - val_loss: 0.6151 - val_accuracy: 0.7893
# Epoch 176/200
# 50000/50000 [==============================] - 3s 59us/sample - loss: 0.5100 - accuracy: 0.8210 - val_loss: 0.6469 - val_accuracy: 0.7822
# Epoch 177/200
# 50000/50000 [==============================] - 3s 59us/sample - loss: 0.5003 - accuracy: 0.8239 - val_loss: 0.7334 - val_accuracy: 0.7529
# Epoch 178/200
# 50000/50000 [==============================] - 3s 60us/sample - loss: 0.5075 - accuracy: 0.8220 - val_loss: 0.6297 - val_accuracy: 0.7872
# Epoch 179/200
# 50000/50000 [==============================] - 3s 59us/sample - loss: 0.5072 - accuracy: 0.8218 - val_loss: 0.6082 - val_accuracy: 0.7914
# Epoch 180/200
# 50000/50000 [==============================] - 3s 60us/sample - loss: 0.5065 - accuracy: 0.8210 - val_loss: 0.6244 - val_accuracy: 0.7866
# Epoch 181/200
# 50000/50000 [==============================] - 3s 59us/sample - loss: 0.5067 - accuracy: 0.8226 - val_loss: 0.6347 - val_accuracy: 0.7852
# Epoch 182/200
# 50000/50000 [==============================] - 3s 60us/sample - loss: 0.5021 - accuracy: 0.8234 - val_loss: 0.6287 - val_accuracy: 0.7877
# Epoch 183/200
# 50000/50000 [==============================] - 3s 60us/sample - loss: 0.4991 - accuracy: 0.8250 - val_loss: 0.6242 - val_accuracy: 0.7888
# Epoch 184/200
# 50000/50000 [==============================] - 3s 60us/sample - loss: 0.4966 - accuracy: 0.8246 - val_loss: 0.6202 - val_accuracy: 0.7870
# Epoch 185/200
# 50000/50000 [==============================] - 3s 60us/sample - loss: 0.4925 - accuracy: 0.8274 - val_loss: 0.6493 - val_accuracy: 0.7799
# Epoch 186/200
# 50000/50000 [==============================] - 3s 60us/sample - loss: 0.4936 - accuracy: 0.8250 - val_loss: 0.6220 - val_accuracy: 0.7946
# Epoch 187/200
# 50000/50000 [==============================] - 3s 59us/sample - loss: 0.4997 - accuracy: 0.8231 - val_loss: 0.6205 - val_accuracy: 0.7917
# Epoch 188/200
# 50000/50000 [==============================] - 3s 60us/sample - loss: 0.4904 - accuracy: 0.8281 - val_loss: 0.6142 - val_accuracy: 0.7923
# Epoch 189/200
# 50000/50000 [==============================] - 3s 60us/sample - loss: 0.4928 - accuracy: 0.8249 - val_loss: 0.6099 - val_accuracy: 0.7931
# Epoch 190/200
# 50000/50000 [==============================] - 3s 59us/sample - loss: 0.4860 - accuracy: 0.8272 - val_loss: 0.6328 - val_accuracy: 0.7868
# Epoch 191/200
# 50000/50000 [==============================] - 3s 60us/sample - loss: 0.4872 - accuracy: 0.8268 - val_loss: 0.6218 - val_accuracy: 0.7907
# Epoch 192/200
# 50000/50000 [==============================] - 3s 60us/sample - loss: 0.4835 - accuracy: 0.8297 - val_loss: 0.6032 - val_accuracy: 0.7943
# Epoch 193/200
# 50000/50000 [==============================] - 3s 60us/sample - loss: 0.4804 - accuracy: 0.8315 - val_loss: 0.6477 - val_accuracy: 0.7781
# Epoch 194/200
# 50000/50000 [==============================] - 3s 60us/sample - loss: 0.4811 - accuracy: 0.8306 - val_loss: 0.6166 - val_accuracy: 0.7915
# Epoch 195/200
# 50000/50000 [==============================] - 3s 60us/sample - loss: 0.4860 - accuracy: 0.8282 - val_loss: 0.5860 - val_accuracy: 0.7987
# Epoch 196/200
# 50000/50000 [==============================] - 3s 60us/sample - loss: 0.4857 - accuracy: 0.8282 - val_loss: 0.6010 - val_accuracy: 0.7926
# Epoch 197/200
# 50000/50000 [==============================] - 3s 60us/sample - loss: 0.4815 - accuracy: 0.8299 - val_loss: 0.6198 - val_accuracy: 0.7868
# Epoch 198/200
# 50000/50000 [==============================] - 3s 59us/sample - loss: 0.4796 - accuracy: 0.8316 - val_loss: 0.6043 - val_accuracy: 0.7936
# Epoch 199/200
# 50000/50000 [==============================] - 3s 60us/sample - loss: 0.4814 - accuracy: 0.8305 - val_loss: 0.6299 - val_accuracy: 0.7896
# Epoch 200/200
# 50000/50000 [==============================] - 3s 60us/sample - loss: 0.4729 - accuracy: 0.8334 - val_loss: 0.6077 - val_accuracy: 0.7924

# %% [markdown]
# ##  Visualization of results
# Here, I will visualize the model and the results.. Firstly, the model itself will be shown in graph form. Thereafter, a summary of the statistics and more will be shown.
# Latsly, plots showing accuracy, preccision and more will be made.

# %% [markdown]
# ### Model illustartion
#
# Not only does the graph model illustrates the layers, where we easily can see e.g. the downsampling in the maxpooling layer.  We also see the order of the layers. Here we can check that the layers indeed are in correct order (conv, activation, normalization, pooling ect)..
#
# Similarty, the number of parameters is seen and the shape of especially the output layers.

# %%
plot_model(model, to_file='model_plot_CNN.png', show_shapes=True, show_layer_names=True)

# %% [markdown]
# ### Statistics
#
# In the statistics, we see the shape of the model, the number of weights in each layer as well as the total number of trained and non-trained parameters.

# %%
print(model.summary())
# Out:
# Model: "sequential"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# conv2d (Conv2D)              (None, 32, 32, 32)        416
# _________________________________________________________________
# activation (Activation)      (None, 32, 32, 32)        0
# _________________________________________________________________
# dropout (Dropout)            (None, 32, 32, 32)        0
# _________________________________________________________________
# conv2d_1 (Conv2D)            (None, 31, 31, 32)        4128
# _________________________________________________________________
# activation_1 (Activation)    (None, 31, 31, 32)        0
# _________________________________________________________________
# batch_normalization (BatchNo (None, 31, 31, 32)        128
# _________________________________________________________________
# max_pooling2d (MaxPooling2D) (None, 15, 15, 32)        0
# _________________________________________________________________
# conv2d_2 (Conv2D)            (None, 15, 15, 64)        8256
# _________________________________________________________________
# activation_2 (Activation)    (None, 15, 15, 64)        0
# _________________________________________________________________
# batch_normalization_1 (Batch (None, 15, 15, 64)        256
# _________________________________________________________________
# conv2d_3 (Conv2D)            (None, 15, 15, 96)        24672
# _________________________________________________________________
# activation_3 (Activation)    (None, 15, 15, 96)        0
# _________________________________________________________________
# batch_normalization_2 (Batch (None, 15, 15, 96)        384
# _________________________________________________________________
# max_pooling2d_1 (MaxPooling2 (None, 7, 7, 96)          0
# _________________________________________________________________
# dropout_1 (Dropout)          (None, 7, 7, 96)          0
# _________________________________________________________________
# conv2d_4 (Conv2D)            (None, 7, 7, 128)         49280
# _________________________________________________________________
# activation_4 (Activation)    (None, 7, 7, 128)         0
# _________________________________________________________________
# batch_normalization_3 (Batch (None, 7, 7, 128)         512
# _________________________________________________________________
# max_pooling2d_2 (MaxPooling2 (None, 3, 3, 128)         0
# _________________________________________________________________
# dropout_2 (Dropout)          (None, 3, 3, 128)         0
# _________________________________________________________________
# conv2d_5 (Conv2D)            (None, 3, 3, 32)          16416
# _________________________________________________________________
# activation_5 (Activation)    (None, 3, 3, 32)          0
# _________________________________________________________________
# batch_normalization_4 (Batch (None, 3, 3, 32)          128
# _________________________________________________________________
# max_pooling2d_3 (MaxPooling2 (None, 1, 1, 32)          0
# _________________________________________________________________
# dropout_3 (Dropout)          (None, 1, 1, 32)          0
# _________________________________________________________________
# flatten (Flatten)            (None, 32)                0
# _________________________________________________________________
# dense (Dense)                (None, 10)                320
# =================================================================
# Total params: 104,896
# Trainable params: 104,192
# Non-trainable params: 704
# _________________________________________________________________
# None

# %% [markdown]
# ### training and validation accuracy values

# %%
scores = model.evaluate(x_test, y_test, verbose=1);
print('Test loss:', scores[0])
print('Test accuracy:', scores[1])
# Out:
# 10000/1 [======================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================= ...
# Test loss: 0.6076523141384125
# Test accuracy: 0.7924

# %%
# list all data in history
print(history.history.keys());
# Out:
# dict_keys(['loss', 'accuracy', 'val_loss', 'val_accuracy'])

# %%
#can render the model myself..
SVG(model_to_dot(model).create(prog='dot', format='svg'))
#sometime it changes from acc to accuracy, use the list above to write correct names...
if epoch>1:
  # display if theres more than one epoch.
  # Plot training & validation accuracy values
  plt.plot(history.history['accuracy'])
  plt.plot(history.history['val_accuracy'])
  plt.title('Model accuracy')
  plt.ylabel('Accuracy')
  plt.xlabel('Epoch')
  plt.legend(['Train', 'Test'], loc='upper left')
  plt.show()
  
  # Plot training & validation loss values
  plt.plot(history.history['loss'])
  plt.plot(history.history['val_loss'])
  plt.title('Model loss')
  plt.ylabel('Loss')
  plt.xlabel('Epoch')
  plt.legend(['Train', 'Test'], loc='upper left')
  plt.show()

# %% [markdown]
#  here, it can be seen after which epoch (if more are used) the odel starts to overfit..
#
#  Here, it can be seen that after 175 epochs,the model starts to overfit. (Training acc is larger than valdation acc, which should be possible without overfitting, and training loss is less than actual valdation loss)...

# %% [markdown]
# ## Make predictions

# %% [markdown]
# #### Making predictions based on model and test data..

# %%
predictions = model.predict(x_test, verbose=0)  #https://www.tensorflow.org/tutorials/keras/classification
# Get most likely class
predicted_classes = np.argmax(predictions, axis=1)

#x = image.img_to_array(img)
#x = np.expand_dims(x, axis=0)
#images = np.vstack([x])
#classes = model.predict_classes(images, batch_size=10)
#print("Predicted class is:",classes)

# %% [markdown]
# #### Making a classification 'report' and a confusion matrix

# %%
# Have true classes (y_test). in order to make confusion matrix im chaning to Pythn scikit lib. (could use others)
import sklearn.metrics as metrics
#therefore, getting stats in scicit (even if I have it fron keras..)
report = metrics.classification_report(y_test_scivit, predicted_classes)
print(report)
# Out:
#               precision    recall  f1-score   support
#
#            0       0.76      0.83      0.79      1000
#            1       0.83      0.94      0.88      1000
#            2       0.75      0.66      0.70      1000
#            3       0.68      0.63      0.65      1000
#            4       0.79      0.77      0.78      1000
#            5       0.73      0.72      0.73      1000
#            6       0.75      0.90      0.82      1000
#            7       0.85      0.78      0.81      1000
#            8       0.90      0.86      0.88      1000
#            9       0.89      0.85      0.87      1000
#
#     accuracy                           0.79     10000
#    macro avg       0.79      0.79      0.79     10000
# weighted avg       0.79      0.79      0.79     10000

# %% [markdown]
# Making confusion matrix and showing (normalized and not). If values are wanted, remove ''' in function...

# %%
import numpy as np
#Defining classes for confusion matrix plot
classes = np.array(['airplanes', 'cars', 'birds', 'cats', 'deer', 'dogs', 'frogs', 'horses', 'ships', 'trucks']);
# Plot non-normalized confusion matrix
plot_confusion_matrix(y_test_scivit, predicted_classes, classes=classes,title='Confusion matrix, without normalization');
# Plot normalized confusion matrix
plot_confusion_matrix(y_test_scivit, predicted_classes, classes=classes, normalize=True,title='Normalized confusion matrix');
# Out:
# Confusion matrix, without normalization
# [[832  34  23  15   2   1  11  11  43  28]
#  [ 10 939   3   2   0   0   5   1   7  33]
#  [ 84   2 657  42  44  49  86  23   7   6]
#  [ 27  13  45 626  37 133  77  24   8  10]
#  [ 21   1  43  30 767  27  69  36   4   2]
#  [ 11   5  24 136  43 722  24  31   1   3]
#  [  5   3  37  32  13   5 898   3   3   1]
#  [ 21   6  37  31  58  48   8 779   0  12]
#  [ 65  40   6   7   2   2   7   2 856  13]
#  [ 20  87   4   6   1   3   7   7  17 848]]
# Normalized confusion matrix
# [[0.832 0.034 0.023 0.015 0.002 0.001 0.011 0.011 0.043 0.028]
#  [0.01  0.939 0.003 0.002 0.    0.    0.005 0.001 0.007 0.033]
#  [0.084 0.002 0.657 0.042 0.044 0.049 0.086 0.023 0.007 0.006]
#  [0.027 0.013 0.045 0.626 0.037 0.133 0.077 0.024 0.008 0.01 ]
#  [0.021 0.001 0.043 0.03  0.767 0.027 0.069 0.036 0.004 0.002]
#  [0.011 0.005 0.024 0.136 0.043 0.722 0.024 0.031 0.001 0.003]
#  [0.005 0.003 0.037 0.032 0.013 0.005 0.898 0.003 0.003 0.001]
#  [0.021 0.006 0.037 0.031 0.058 0.048 0.008 0.779 0.    0.012]
#  [0.065 0.04  0.006 0.007 0.002 0.002 0.007 0.002 0.856 0.013]
#  [0.02  0.087 0.004 0.006 0.001 0.003 0.007 0.007 0.017 0.848]]

# %% [markdown]
# ## Save model and weights for further use.

# %%
from keras.models import load_model
from keras.models import model_from_json
from keras.models import model_from_yaml
import keras
 # creates a HDF5 file 

model.save("Users\28669364\Desktop\model\model_200Epochs.h5") 
# Creates json file, to see architecture
# serialize model to JSON
model_json = model.to_json()
with open("Users\28669364\Downloads\model_200Epochs.json", "w") as json_file:
    json_file.write(model_json)
with open("model_200Epochs.json", "w") as json_file:
    json_file.write(model_json)
# serialize weights to HDF5
model.save_weights("Users\28669364\Downloads\weights_200Epochs.h5")
print("Saved model to disk")

print(model_name)
# Out:
# Saved model to disk
# model_100_epochs_5.h5

# %%
# !ls
# Out:
#  model_100_epochs_5.h5
#  model_plot_CNN.png
#  sample_data
# 'Users'$'\002''8669364\Desktop\model\model_200Epochs.h5'
# 'Users'$'\002''8669364\Downloads'
# 'Users'$'\002''8669364\Downloads\model_200Epochs.h5'
# 'Users'$'\002''8669364\Downloads\model_200Epochs.json'
# 'Users'$'\002''8669364\Downloads\weights_200Epochs.h5'
