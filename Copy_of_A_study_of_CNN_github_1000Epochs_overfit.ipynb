# %% [markdown]
# <a href="https://colab.research.google.com/github/aalling93/ENGR562_CNN/blob/master/Copy_of_A_study_of_CNN_github_1000Epochs_overfit.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # CNN MODEL
#
# Building a CNN model is easy! In this notebook, the theory from the article 'A study of Convolutional Neural Network'[Sorensen(2019)] will be implemented in a simple CNN.
#
# This model is a simpler version of the one covered in [Sorensen(2019)]. Here, a model is build for the sole purpose of showing a predictions
#
# Many frameworks and libraries usefull for machine learning exists.  Here, the keras library is used in order to utilize the Tensorflow framework.
#
# This notebook covers the following:
#
# - Initialization: installing and importing packages.
# - Importing a dataset: A dataset is needed to build and train a model.
# - Preparing the model: Defining the hyperparamters used.
# - Building a model: Using layers, fundtions ect as seen in [Sorensen(2019)].
# - Training the model: Using the imported data, the build model is trained using a loss function and optimizer.
# - Visualization of intermediate CNN results and statistics
# - Saving the model
# - Prediction.
#
# For further tutorials, see e.g.  https://medium.com/nybles/create-your-first-image-recognition-classifier-using-cnn-keras-and-tensorflow-backend-6eaab98d14dd or https://towardsdatascience.com/cnn-architectures-a-deep-dive-a99441d18049

# %% [markdown]
# ## Initialization
# Firstly, install needed packages and check for version.

# %%
#! pip install torch
#! pip install torchvision
#! pip install pandas==0.23.4
#! pip install geopandas
#! pip install keras
#! pip install tensorflow
#! pip install tf-nightly
#! pip install ggplot
#! pip install -U PyYAML
try:
  # %tensorflow_version only exists in Colab.
  # %tensorflow_version 2.x
except Exception:
  pass

from __future__ import absolute_import, division, print_function, unicode_literals
# TensorFlow and tf.keras
import tensorflow as tf
from tensorflow import keras
from keras import regularizers
# Helper libraries
import numpy as np
import matplotlib.pyplot as plt
from tensorflow.keras.datasets import cifar10
from tensorflow.keras.preprocessing.image import ImageDataGenerator, save_img
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Dense, Dropout, Activation, Flatten, BatchNormalization
from tensorflow.keras.layers import Conv2D, MaxPooling2D
import os
import time
from sklearn import svm, datasets
from sklearn.model_selection import train_test_split
from sklearn.metrics import confusion_matrix
from sklearn.utils.multiclass import unique_labels
from PIL import Image as pil_image
from tensorflow.keras import layers
from tensorflow.keras import backend as K
from keras.constraints import max_norm
#To visualize it..
from tensorflow.keras.utils import plot_model
from IPython.display import SVG
from tensorflow.keras.utils import model_to_dot
# FUNCTIONS
def plot_confusion_matrix(y_true, y_pred, classes,
                          normalize=False,
                          title=None,
                          cmap=plt.cm.Blues,want_title=None):
    """
    This function prints and plots the confusion matrix. Noting more... It uses the sklearn lib.
    Normalization can be applied by setting `normalize=True`.
    """
    #making title.. (for my article, i dont want then, thus the want_title)
    if not title:
        if normalize:
            title = 'Normalized confusion matrix'
        else:
            title = 'Confusion matrix, without normalization'

    # Compute confusion matrix
    cm = confusion_matrix(y_true, y_pred)
    # Only use the labels that appear in the data
    classes = classes[unique_labels(y_true, y_pred)]
    if normalize:
        cm = cm.astype('float') / cm.sum(axis=1)[:, np.newaxis]
        print("Normalized confusion matrix")
    else:
        print('Confusion matrix, without normalization')

    print(cm)

    fig, ax = plt.subplots(figsize=(6,6))
    im = ax.imshow(cm, interpolation='nearest', cmap=cmap)
    ax.figure.colorbar(im, ax=ax)
    
    # We want to show all ticks...
    if want_title!= None:
      ax.set(xticks=np.arange(cm.shape[1]),
             yticks=np.arange(cm.shape[0]),
             # ... and label them with the respective list entries
             xticklabels=classes, yticklabels=classes,
             title=title,
             ylabel='True label',
             xlabel='Predicted label')
    else:
      ax.set(xticks=np.arange(cm.shape[1]),
             yticks=np.arange(cm.shape[0]),
             # ... and label them with the respective list entries
             xticklabels=classes, yticklabels=classes,
             ylabel='True label',
             xlabel='Predicted label')        

    # Rotate the tick labels and set their alignment.
    plt.setp(ax.get_xticklabels(), rotation=45, ha="right",
             rotation_mode="anchor")
    # I dont want the actualy probabilities in the plot, since its meassy when exporting to latex. 
    # but, for examinations it's fine. 
    """
    Loop over data dimensions and create text annotations.
    fmt = '.2f' if normalize else 'd'
    thresh = cm.max() / 2.
    for i in range(cm.shape[0]):
        for j in range(cm.shape[1]):
            ax.text(j, i, format(cm[i, j], fmt),
                    ha="center", va="center",
                    color="white" if cm[i, j] > thresh else "black")
    fig.tight_layout()
    """
    return ax



print(tf.__version__)
# Out:
# TensorFlow 2.x selected.
# Using TensorFlow backend.
# 2.0.0

# %% [markdown]
# ## Importing a dataset
#
# Here, im important a dataset from keras pre-defined data sets, see https://keras.io/datasets/
#
# The CIFAR10 dataset:
# Dataset of 50,000 32x32 color training images, labeled over 10 categories, and 10,000 test images. It is thus good for illustrating pupose of a CNN. https://www.cs.toronto.edu/~kriz/cifar.html
#
# The images are uint8 array of RGB image data with shape (num_samples, 3, 32, 32) or (num_samples, 32, 32, 3) based on the image_data_format backend setting of either
# Since the dataset is predefined in Keras, it can do the labelling. Otherwise classes must be defined>

# %%
#loading the set directly from keras bucket.
cifar100 = tf.keras.datasets.cifar100
#defining training(test) data and its labels. The data, split between train and test sets:
(x_train, y_train), (x_test, y_test) = cifar10.load_data()
#see a bit of stats..
print('x_train shape:', x_train.shape)
print(x_train.shape[0], 'train samples')
print(x_test.shape[0], 'test samples')
# The data is already labbeled.. Othervise, define into classes
# Out:
# x_train shape: (50000, 32, 32, 3)
# 50000 train samples
# 10000 test samples

# %% [markdown]
# ## Preparing the model

# %%
# Convert class vectors to binary class matrices.
num_classes = 10 #from 100 to 10 classes....# in the CIFAR10 theres 10 classes extracted from the CIFAR100 dataset..
y_test_scivit = np.squeeze(np.copy(y_test)) #used for confusin matrix in scilearn lib. AFTER predictions are made...
y_train = tf.keras.utils.to_categorical(y_train, num_classes)
y_test = tf.keras.utils.to_categorical(y_test, num_classes)

# %% [markdown]
# Here, the defined test data can be used to evaluate the model using the error function described in the theory. It could be applied as K-fold, leave-on-out or even a cross validation (take hella long time tho).
#
# ## Exploring the classes

# %%
plt.figure()
plt.imshow(x_train[1])
plt.colorbar()
plt.grid(False)
plt.show()
#lets see what we have.

# %% [markdown]
# ## Building the CNN
# layers, as described in the theory can now be added to the model
# see https://towardsdatascience.com/building-a-convolutional-neural-network-cnn-in-keras-329fbbadc5f5

# %% [markdown]
# ### Defining Hyper parameters
#
# Hyper parameters to control the size of the output of CNN layer. Depth, stride and zero padding..

# %%
model_name = 'good_prediction.h5'
#filter size
filter_size = 3
#If padding isnt the deafult, this value should be used (now keras defult is used..)
padding  = (filter_size-1)/2
filter_size = (filter_size,filter_size)
# Stride controls the "overlap" between neighoboring convolutions. For sattellite image, a strid of e.g. 10 is smart . This reduces the dimension.. If stride=1, we move filter one pixel at a time. 
# atm, keras deafult is used = the same size as pooling.. 
stride = 3 
#depth is number of neurons(filters) in the given layer connected to the input (either original img or feature img).
filters_first_layer = 66 #currently this value is also used for other layers..
# Epoch is the number each batch is trained
epoch=1000
#Using batch learning as in the theory
batch_size = 1000

# %% [markdown]
# ### Making model

# %%
#------------------------ BUILING THE MODEL ------------------------------------
# Initializing the model using Sequntial(), The Sequential model is a linear stack of layers. https://keras.io/getting-started/sequential-model-guide/
model = Sequential()
#adding a convolutional layer, https://keras.io/layers/convolutional/
model.add(Conv2D(filters_first_layer, filter_size, padding='same',input_shape=x_train.shape[1:]))
#adding activation function
model.add(BatchNormalization())
model.add(Activation('relu'))
#adding Maxpooling as described in the theory and https://keras.io/layers/pooling/. Default stride is the same as pool..
model.add(MaxPooling2D(pool_size=(2, 2)))
#regularization, https://keras.io/layers/core/
model.add(Dropout(0.1))
#this "block" of layers (convolutional layer, activation, pooling and regularization) can now be applied a number of times.... i.e copy pastye..
# ---- 2nd block
model.add(Conv2D(filters_first_layer, filter_size))
model.add(BatchNormalization())
model.add(Activation('relu'))
model.add(MaxPooling2D(pool_size=(2,2)))
# --- 3rd block -------
model.add(Conv2D(filters_first_layer*2, filter_size, padding='same'))
model.add(BatchNormalization())
model.add(Activation('relu'))
model.add(MaxPooling2D(pool_size=(2,2)))
# --- 4rd block -------
model.add(Conv2D(filters_first_layer*2, filter_size, padding='same'))
model.add(BatchNormalization())
model.add(Activation('relu'))
model.add(MaxPooling2D(pool_size=(2,2)))
model.add(Dropout(0.2))
# --- 5th block -------
model.add(Conv2D(filters_first_layer*2, filter_size, padding='same'))
model.add(BatchNormalization())
model.add(Activation('relu'))
model.add(Dropout(0.4))
#Flattens the input. Does not affect the batch size needed for FC... see https://medium.com/nybles/create-your-first-image-recognition-classifier-using-cnn-keras-and-tensorflow-backend-6eaab98d14dd
model.add(Flatten())
#model.add(Dense(512, kernel_constraint=max_norm(2.)))
model.add(Dense(512))
model.add(Activation('relu'))
model.add(Dropout(0.2))
#Just your regular densely-connected NN layer, i.e. the FC...adding different weight regularizers. Lastly,activation function to classify...
model.add(Dense(num_classes, kernel_regularizer=regularizers.l2(0.001),bias_regularizer=regularizers.l2(0.001),activity_regularizer=regularizers.l2(0.001),activation='softmax'))

# %% [markdown]
# ## Training the model

# %% [markdown]
# ### Define back propagation optimizer and loss function.
# In the theory, the equation for the Gradient Descent is explained. This is optimizer is used with the loss of cross entropy.
#
# Recall. Gradient descent applied to a batch is called mini-batch learning.
#
#
# Optimizer: https://keras.io/optimizers/.
#
# Loss function: https://keras.io/losses/.

# %%
# an optimizer is required to train a keras model, https://keras.io/optimizers/. As described in the theory, as GRADIENT DESCENT is used here..
#  The loss function is here defined, https://keras.io/losses/. In the theory, the kullback_leibler_divergence and cross entropy..  Since classes are integer, sparse_categorical_crossentropy is used
optimizer = keras.optimizers.SGD(lr=0.005)
model.compile(loss='categorical_crossentropy',optimizer=optimizer,metrics=['accuracy'])
print("Showing sizes of datasets..")
print(x_train.shape,y_train.shape,x_test.shape,y_test.shape)
# Out:
# Showing sizes of datasets..
# (50000, 32, 32, 3) (50000, 10) (10000, 32, 32, 3) (10000, 10)

# %% [markdown]
# In illustation of the data, we saw the scale on the colour plot. This is scalled to [0,1] before its used to fit the model.

# %%
#Scaling the data from [0:255] to [0:1]..
x_test = x_test.astype('float32')
x_train = x_train.astype('float32')
x_train /= 255
x_test /= 255

# %% [markdown]
# ### Fitting the model:
# Using the model of the CNN, the model is not TRAINED using the labels.
# - the batch size is used (how many feature maps in one batch)
# - the epochs are used (how many times a batch is trained)
# Moreover, the training data is used (data and labels) to train, and is validated on the test data (data and labels)

# %%
#https://keras.io/models/sequential/
# History is used to track the changed for plotting..
history = model.fit(x_train, y_train,batch_size=batch_size,epochs=epoch, validation_data=(x_test, y_test),shuffle=True)
# Out:
# Train on 50000 samples, validate on 10000 samples
# Epoch 1/1000
# 50000/50000 [==============================] - 6s 116us/sample - loss: 2.3737 - accuracy: 0.1342 - val_loss: 2.3231 - val_accuracy: 0.1000
# Epoch 2/1000
# 50000/50000 [==============================] - 3s 51us/sample - loss: 2.2170 - accuracy: 0.1877 - val_loss: 2.3291 - val_accuracy: 0.1036
# Epoch 3/1000
# 50000/50000 [==============================] - 3s 52us/sample - loss: 2.1265 - accuracy: 0.2204 - val_loss: 2.3555 - val_accuracy: 0.1000
# Epoch 4/1000
# 50000/50000 [==============================] - 3s 51us/sample - loss: 2.0524 - accuracy: 0.2465 - val_loss: 2.4051 - val_accuracy: 0.1000
# Epoch 5/1000
# 50000/50000 [==============================] - 3s 52us/sample - loss: 1.9991 - accuracy: 0.2659 - val_loss: 2.4663 - val_accuracy: 0.1000
# Epoch 6/1000
# 50000/50000 [==============================] - 3s 53us/sample - loss: 1.9439 - accuracy: 0.2870 - val_loss: 2.5096 - val_accuracy: 0.1076
# Epoch 7/1000
# 50000/50000 [==============================] - 3s 52us/sample - loss: 1.9006 - accuracy: 0.3021 - val_loss: 2.5292 - val_accuracy: 0.1192
# Epoch 8/1000
# 50000/50000 [==============================] - 3s 52us/sample - loss: 1.8543 - accuracy: 0.3225 - val_loss: 2.4729 - val_accuracy: 0.1338
# Epoch 9/1000
# 50000/50000 [==============================] - 3s 52us/sample - loss: 1.8169 - accuracy: 0.3292 - val_loss: 2.3895 - val_accuracy: 0.1559
# Epoch 10/1000
# 50000/50000 [==============================] - 3s 53us/sample - loss: 1.7778 - accuracy: 0.3460 - val_loss: 2.2388 - val_accuracy: 0.1931
# Epoch 11/1000
# 50000/50000 [==============================] - 3s 52us/sample - loss: 1.7495 - accuracy: 0.3518 - val_loss: 2.1066 - val_accuracy: 0.2219
# Epoch 12/1000
# 50000/50000 [==============================] - 3s 53us/sample - loss: 1.7176 - accuracy: 0.3689 - val_loss: 1.9511 - val_accuracy: 0.2787
# Epoch 13/1000
# 50000/50000 [==============================] - 3s 52us/sample - loss: 1.6931 - accuracy: 0.3761 - val_loss: 1.8310 - val_accuracy: 0.3351
# Epoch 14/1000
# 50000/50000 [==============================] - 3s 52us/sample - loss: 1.6671 - accuracy: 0.3856 - val_loss: 1.6977 - val_accuracy: 0.3855
# Epoch 15/1000
# 50000/50000 [==============================] - 3s 53us/sample - loss: 1.6497 - accuracy: 0.3920 - val_loss: 1.7014 - val_accuracy: 0.3926
# Epoch 16/1000
# 50000/50000 [==============================] - 3s 52us/sample - loss: 1
1000
# 50000/50000 [==============================] - 3s 52us/sample - loss: 1.2649 - accuracy: 0.5476 - val_loss: 1.5688 - val_accuracy: 0.4598
# Epoch 46/1000
# 50000/50000 [==============================] - 3s 53us/sample - loss: 1.2608 - accuracy: 0.5512 - val_loss: 1.2510 - val_accuracy: 0.5511
# Epoch 47/1000
# 50000/50000 [==============================] - 3s 52us/sample - loss: 1.2541 - accuracy: 0.5556 - val_loss: 1.3285 - val_accuracy: 0.5383
# Epoch 48/1000
# 50000/50000 [==============================] - 3s 52us/sample - loss: 1.2451 - accuracy: 0.5602 - val_loss: 1.1936 - val_accuracy: 0.5691
# Epoch 49/1000
# 50000/50000 [==============================] - 3s 52us/sample - loss: 1.2424 - accuracy: 0.5589 - val_loss: 1.3716 - val_accuracy: 0.5099
# Epoch 50/1000
# 50000/50000 [==============================] - 3s 52us/sample - loss: 1.2332 - accuracy: 0.5636 - val_loss: 1.2286 - val_accuracy: 0.5682
# Epoch 51/1000
# 50000/50000 [==============================] - 3s 52us/sample - loss: 1.2228 - accuracy: 0.5649 - val_loss: 1.2353 - val_accuracy: 0.5563
# Epoch 52/1000
# 50000/50000 [==============================] - 3s 52us/sample - loss: 1.2196 - accuracy: 0.5711 - val_loss: 1.3708 - val_accuracy: 0.5150
# Epoch 53/1000
# 50000/50000 [==============================] - 3s 52us/sample - loss: 1.2082 - accuracy: 0.5729 - val_loss: 1.1595 - val_accuracy: 0.5861
# Epoch 54/1000
# 50000/50000 [==============================] - 3s 52us/sample - loss: 1.2049 - accuracy: 0.5728 - val_loss: 1.3055 - val_accuracy: 0.5272
# Epoch 55/1000
# 50000/50000 [==============================] - 3s 53us/sample - loss: 1.1995 - accuracy: 0.5743 - val_loss: 1.2313 - val_accuracy: 0.5528
# Epoch 56/1000
# 50000/50000 [==============================] - 3s 52us/sample - loss: 1.1902 - accuracy: 0.5818 - val_loss: 1.1544 - val_accuracy: 0.5846
# Epoch 57/1000
# 50000/50000 [==============================] - 3s 52us/sample - loss: 1.1876 - accuracy: 0.5806 - val_loss: 1.2951 - val_accuracy: 0.5463
# Epoch 58/1000
# 50000/50000 [==============================] - 3s 52us/sample - loss: 1.1829 - accuracy: 0.5815 - val_loss: 1.1348 - val_accuracy: 0.6008
# Epoch 59/1000
# 50000/50000 [==============================] - 3s 52us/sample - loss: 1.1713 - accuracy: 0.5865 - val_loss: 1.2572 - val_accuracy: 0.5584
# Epoch 60/1000
# 50000/50000 [==============================] - 3s 52us/sample - loss: 1.1681 - accuracy: 0.5887 - val_loss: 1.1937 - val_accuracy: 0.5734
# Epoch 61/1000
# 50000/50000 [==============================] - 3s 52us/sample - loss: 1.1609 - accuracy: 0.5940 - val_loss: 1.3072 - val_accuracy: 0.5317
# Epoch 62/1000
# 50000/50000 [==============================] - 3s 52us/sample - loss: 1.1535 - accuracy: 0.5970 - val_loss: 1.1584 - val_accuracy: 0.5825
# Epoch 63/1000
# 50000/50000 [==============================] - 3s 53us/sample - loss: 1.1521 - accuracy: 0.5946 - val_loss: 1.2197 - val_accuracy: 0.5666
# Epoch 64/1000
# 50000/50000 [==============================] - 3s 52us/sample - loss: 1.1442 - accuracy: 0.6000 - val_loss: 1.1464 - val_accuracy: 0.5834
# Epoch 65/1000
# 50000/50000 [==============================] - 3s 52us/sample - loss: 1.1391 - accuracy: 0.5998 - val_loss: 1.2468 - val_accuracy: 0.5601
# Epoch 66/1000
# 50000/50000 [==============================] - 3s 52us/sample - loss: 1.1362 - accuracy: 0.6022 - val_loss: 1.1422 - val_accuracy: 0.5917
# Epoch 67/1000
# 50000/50000 [==============================] - 3s 51us/sample - loss: 1.1257 - accuracy: 0.6067 - val_loss: 1.2554 - val_accuracy: 0.5478
# Epoch 68/1000
# 50000/50000 [==============================] - 3s 52us/sample - loss: 1.1258 - accuracy: 0.6070 - val_loss: 1.5807 - val_accuracy: 0.4695
# Epoch 69/1000
# 50000/50000 [==============================] - 3s 51us/sample - loss: 1.1182 - accuracy: 0.6113 - val_loss: 1.2496 - val_accuracy: 0.5567
# Epoch 70/1000
# 50000/50000 [==============================] - 3s 52us/sample - loss: 1.1061 - accuracy: 0.6123 - val_loss: 1.1678 - val_accuracy: 0.5913
# Epoch 71/1000
# 50000/50000 [==============================] - 3s 53us/sample - loss: 1.1086 - accuracy: 0.6107 - val_loss: 1.0718 - val_accuracy: 0.6175
# Epoch 72/1000
# 50000/50000 [==============================] - 3s 53us/sample - loss: 1.1026 - accuracy: 0.6142 - val_loss: 1.1612 - val_accuracy: 0.5914
# Epoch 73/1000
# 50000/50000 [==============================] - 3s 51us/sample - loss: 1.0974 - accuracy: 0.6186 - val_loss: 1.0625 - val_accuracy: 0.6250
# Epoch 74/1000
# 50000/50000 [==============================] - 3s 52us/sample - loss: 1.0919 - accuracy: 0.6195 - val_loss: 1.1360 - val_accuracy: 0.5940
# Epoch 75/1000
# 50000/50000 [==============================] - 3s 52us/sample - loss: 1.0894 - accuracy: 0.6191 - val_loss: 1.5163 - val_accuracy: 0.4941
# Epoch 76/1000
# 50000/50000 [==============================] - 3s 53us/sample - loss: 1.0883 - accuracy: 0.6194 - val_loss: 1.1972 - val_accuracy: 0.5847
# Epoch 77/1000
# 50000/50000 [==============================] - 3s 52us/sample - loss: 1.0798 - accuracy: 0.6230 - val_loss: 1.1955 - val_accuracy: 0.5779
# Epoch 78/1000
# 50000/50000 [==============================] - 3s 52us/sample - loss: 1.0767 - accuracy: 0.6254 - val_loss: 1.0443 - val_accuracy: 0.6310
# Epoch 79/1000
# 50000/50000 [==============================] - 3s 53us/sample - loss: 1.0682 - accuracy: 0.6279 - val_loss: 1.0926 - val_accuracy: 0.6057
# Epoch 80/1000
# 50000/50000 [==============================] - 3s 52us/sample - loss: 1.0628 - accuracy: 0.6295 - val_loss: 1.0593 - val_accuracy: 0.6221
# Epoch 81/1000
# 50000/50000 [==============================] - 3s 51us/sample - loss: 1.0590 - accuracy: 0.6327 - val_loss: 1.1393 - val_accuracy: 0.6040
# Epoch 82/1000
# 50000/50000 [==============================] - 3s 52us/sample - loss: 1.0561 - accuracy: 0.6333 - val_loss: 1.2136 - val_accuracy: 0.5747
# Epoch 83/1000
# 50000/50000 [==============================] - 3s 52us/sample - loss: 1.0539 - accuracy: 0.6342 - val_loss: 1.0208 - val_accuracy: 0.6387
# Epoch 84/1000
# 50000/50000 [==============================] - 3s 51us/sample - loss: 1.0471 - accuracy: 0.6361 - val_loss: 0.9696 - val_accuracy: 0.6592
# Epoch 85/1000
# 50000/50000 [==============================] - 3s 52us/sample - loss: 1.0469 - accuracy: 0.6352 - val_loss: 1.0949 - val_accuracy: 0.6071
# Epoch 86/1000
# 50000/50000 [==============================] - 3s 52us/sample - loss: 1.0359 - accuracy: 0.6391 - val_loss: 1.2853 - val_accuracy: 0.5614
# Epoch 87/1000
# 50000/50000 [==============================] - 3s 52us/sample - loss: 1.0364 - accuracy: 0.6415 - val_loss: 1.0413 - val_accuracy: 0.6376
# Epoch 88/1000
# 50000/50000 [==============================] - 3s 52us/sample - loss: 1.0286 - accuracy: 0.6436 - val_loss: 1.0864 - val_accuracy: 0.6154
# Epoch 89/1000
# 50000/50000 [==============================] - 3s 52us/sample - loss: 1.0278 - accuracy: 0.6449 - val_loss: 1.1042 - val_accuracy: 0.6095
# Epoch 90/1000
# 50000/50000 [==============================] - 3s 53us/sample - loss: 1.0196 - accuracy: 0.6467 - val_loss: 1.1745 - val_accuracy: 0.5885
# Epoch 91/1000
# 50000/50000 [==============================] - 3s 53us/sample - loss: 1.0138 - accuracy: 0.6483 - val_loss: 1.1831 - val_accuracy: 0.5973
# Epoch 92/1000
# 50000/50000 [==============================] - 3s 52us/sample - loss: 1.0118 - accuracy: 0.6491 - val_loss: 1.1953 - val_accuracy: 0.5891
# Epoch 93/1000
# 50000/50000 [==============================] - 3s 51us/sample - loss: 1.0094 - accuracy: 0.6512 - val_loss: 1.0555 - val_accuracy: 0.6276
# Epoch 94/1000
# 50000/50000 [==============================] - 3s 51us/sample - loss: 1.0110 - accuracy: 0.6500 - val_loss: 1.0115 - val_accuracy: 0.6466
# Epoch 95/1000
# 50000/50000 [==============================] - 3s 52us/sample - loss: 1.0032 - accuracy: 0.6531 - val_loss: 0.9964 - val_accuracy: 0.6526
# Epoch 96/1000
# 50000/50000 [==============================] - 3s 52us/sample - loss: 0.9999 - accuracy: 0.6558 - val_loss: 1.0152 - val_accuracy: 0.6501
# Epoch 97/1000
# 50000/50000 [==============================] - 3s 53us/sample - loss: 0.9960 - accuracy: 0.6578 - val_loss: 1.1184 - val_accuracy: 0.6117
# Epoch 98/1000
# 50000/50000 [==============================] - 3s 53us/sample - loss: 0.9923 - accuracy: 0.6555 - val_loss: 1.0655 - val_accuracy: 0.6216
# Epoch 99/1000
# 50000/50000 [==============================] - 3s 52us/sample - loss: 0.9876 - accuracy: 0.6591 - val_loss: 0.9849 - val_accuracy: 0.6557
# Epoch 100/1000
# 50000/50000 [==============================] - 3s 52us/sample - loss: 0.9857 - accuracy: 0.6600 - val_loss: 1.1145 - val_accuracy: 0.6168
# Epoch 101/1000
# 50000/50000 [==============================] - 3s 52us/sample - loss: 0.9829 - accuracy: 0.6606 - val_loss: 0.9657 - val_accuracy: 0.6600
# Epoch 102/1000
# 50000/50000 [==============================] - 3s 52us/sample - loss: 0.9745 - accuracy: 0.6655 - val_loss: 1.0100 - val_accuracy: 0.6430
# Epoch 103/1000
# 50000/50000 [==============================] - 3s 52us/sample - loss: 0.9733 - accuracy: 0.6656 - val_loss: 0.9881 - val_accuracy: 0.6591
# Epoch 104/1000
# 50000/50000 [==============================] - 3s 52us/sample - loss: 0.
1000
# 50000/50000 [==============================] - 3s 52us/sample - loss: 0.8692 - accuracy: 0.7035 - val_loss: 0.8561 - val_accuracy: 0.7007
# Epoch 135/1000
# 50000/50000 [==============================] - 3s 52us/sample - loss: 0.8688 - accuracy: 0.7035 - val_loss: 1.0794 - val_accuracy: 0.6347
# Epoch 136/1000
# 50000/50000 [==============================] - 3s 52us/sample - loss: 0.8677 - accuracy: 0.7035 - val_loss: 0.9822 - val_accuracy: 0.6609
# Epoch 137/1000
# 50000/50000 [==============================] - 3s 52us/sample - loss: 0.8641 - accuracy: 0.7056 - val_loss: 0.9286 - val_accuracy: 0.6841
# Epoch 138/1000
# 50000/50000 [==============================] - 3s 52us/sample - loss: 0.8571 - accuracy: 0.7079 - val_loss: 0.9732 - val_accuracy: 0.6681
# Epoch 139/1000
# 50000/50000 [==============================] - 3s 53us/sample - loss: 0.8612 - accuracy: 0.7046 - val_loss: 0.9099 - val_accuracy: 0.6907
# Epoch 140/1000
# 50000/50000 [==============================] - 3s 53us/sample - loss: 0.8502 - accuracy: 0.7110 - val_loss: 0.8972 - val_accuracy: 0.6959
# Epoch 141/1000
# 50000/50000 [==============================] - 3s 53us/sample - loss: 0.8536 - accuracy: 0.7093 - val_loss: 0.8935 - val_accuracy: 0.6901
# Epoch 142/1000
# 50000/50000 [==============================] - 3s 52us/sample - loss: 0.8452 - accuracy: 0.7116 - val_loss: 0.9533 - val_accuracy: 0.6732
# Epoch 143/1000
# 50000/50000 [==============================] - 3s 53us/sample - loss: 0.8450 - accuracy: 0.7127 - val_loss: 1.0180 - val_accuracy: 0.6577
# Epoch 144/1000
# 50000/50000 [==============================] - 3s 52us/sample - loss: 0.8457 - accuracy: 0.7130 - val_loss: 0.9775 - val_accuracy: 0.6726
# Epoch 145/1000
# 50000/50000 [==============================] - 3s 53us/sample - loss: 0.8428 - accuracy: 0.7135 - val_loss: 0.8782 - val_accuracy: 0.7000
# Epoch 146/1000
# 50000/50000 [==============================] - 3s 52us/sample - loss: 0.8358 - accuracy: 0.7152 - val_loss: 0.8583 - val_accuracy: 0.7072
# Epoch 147/1000
# 50000/50000 [==============================] - 3s 51us/sample - loss: 0.8367 - accuracy: 0.7162 - val_loss: 0.9447 - val_accuracy: 0.6694
# Epoch 148/1000
# 50000/50000 [==============================] - 3s 52us/sample - loss: 0.8318 - accuracy: 0.7187 - val_loss: 0.8702 - val_accuracy: 0.7036
# Epoch 149/1000
# 50000/50000 [==============================] - 3s 52us/sample - loss: 0.8255 - accuracy: 0.7190 - val_loss: 1.0321 - val_accuracy: 0.6512
# Epoch 150/1000
# 50000/50000 [==============================] - 3s 54us/sample - loss: 0.8243 - accuracy: 0.7200 - val_loss: 0.8433 - val_accuracy: 0.7077
# Epoch 151/1000
# 50000/50000 [==============================] - 3s 53us/sample - loss: 0.8250 - accuracy: 0.7201 - val_loss: 0.8239 - val_accuracy: 0.7167
# Epoch 152/1000
# 50000/50000 [==============================] - 3s 52us/sample - loss: 0.8218 - accuracy: 0.7201 - val_loss: 0.8809 - val_accuracy: 0.6966
# Epoch 153/1000
# 50000/50000 [==============================] - 3s 53us/sample - loss: 0.8135 - accuracy: 0.7263 - val_loss: 0.9508 - val_accuracy: 0.6805
# Epoch 154/1000
# 50000/50000 [==============================] - 3s 52us/sample - loss: 0.8153 - accuracy: 0.7232 - val_loss: 0.9261 - val_accuracy: 0.6779
# Epoch 155/1000
# 50000/50000 [==============================] - 3s 52us/sample - loss: 0.8072 - accuracy: 0.7267 - val_loss: 0.9714 - val_accuracy: 0.6720
# Epoch 156/1000
# 50000/50000 [==============================] - 3s 53us/sample - loss: 0.8096 - accuracy: 0.7268 - val_loss: 1.0878 - val_accuracy: 0.6310
# Epoch 157/1000
# 50000/50000 [==============================] - 3s 52us/sample - loss: 0.8096 - accuracy: 0.7232 - val_loss: 0.8428 - val_accuracy: 0.7129
# Epoch 158/1000
# 50000/50000 [==============================] - 3s 52us/sample - loss: 0.8030 - accuracy: 0.7277 - val_loss: 0.8519 - val_accuracy: 0.7060
# Epoch 159/1000
# 50000/50000 [==============================] - 3s 52us/sample - loss: 0.8042 - accuracy: 0.7276 - val_loss: 1.1741 - val_accuracy: 0.6191
# Epoch 160/1000
# 50000/50000 [==============================] - 3s 52us/sample - loss: 0.8013 - accuracy: 0.7284 - val_loss: 0.8769 - val_accuracy: 0.7014
# Epoch 161/1000
# 50000/50000 [==============================] - 3s 52us/sample - loss: 0.7963 - accuracy: 0.7318 - val_loss: 0.9675 - val_accuracy: 0.6750
# Epoch 162/1000
# 50000/50000 [==============================] - 3s 53us/sample - loss: 0.7910 - accuracy: 0.7331 - val_loss: 0.8124 - val_accuracy: 0.7209
# Epoch 163/1000
# 50000/50000 [==============================] - 3s 52us/sample - loss: 0.7896 - accuracy: 0.7331 - val_loss: 0.8249 - val_accuracy: 0.7161
# Epoch 164/1000
# 50000/50000 [==============================] - 3s 52us/sample - loss: 0.
1000
# 50000/50000 [==============================] - 3s 53us/sample - loss: 0.4811 - accuracy: 0.8417 - val_loss: 0.7754 - val_accuracy: 0.7551
# Epoch 314/1000
# 50000/50000 [==============================] - 3s 52us/sample - loss: 0.4746 - accuracy: 0.8447 - val_loss: 0.8037 - val_accuracy: 0.7505
# Epoch 315/1000
# ...
# Epoch 897/1000
# 50000/50000 [==============================] - 3s 51us/sample - loss: 0.0916 - accuracy: 0.9771 - val_loss: 1.0445 - val_accuracy: 0.7789
# Epoch 898/1000
# 50000/50000 [==============================] - 3s 51us/sample - loss: 0.0948 - accuracy: 0.9763 - val_loss: 1.0924 - val_accuracy: 0.7673
# Epoch 899/1000
# 50000/50000 [==============================] - 3s 51us/sample - loss: 0.0929 - accuracy: 0.9776 - val_loss: 1.0328 - val_accuracy: 0.7763
# Epoch 900/1000
# 50000/50000 [==============================] - 3s 52us/sample - loss: 0.0943 - accuracy: 0.9763 - val_loss: 1.0309 - val_accuracy: 0.7807
# Epoch 901/1000
# 50000/50000 [==============================] - 3s 51us/sample - loss: 0.0914 - accuracy: 0.9771 - val_loss: 1.0699 - val_accuracy: 0.7729
# Epoch 902/1000
# 50000/50000 [==============================] - 3s 52us/sample - loss: 0.0908 - accuracy: 0.9775 - val_loss: 1.0867 - val_accuracy: 0.7725
# Epoch 903/1000
# 50000/50000 [==============================] - 3s 51us/sample - loss: 0.0925 - accuracy: 0.9769 - val_loss: 1.0618 - val_accuracy: 0.7761
# Epoch 904/1000
# 50000/50000 [==============================] - 3s 51us/sample - loss: 0.0945 - accuracy: 0.9770 - val_loss: 1.0321 - val_accuracy: 0.7790
# Epoch 905/1000
# 50000/50000 [==============================] - 3s 52us/sample - loss: 0.0910 - accuracy: 0.9773 - val_loss: 1.0462 - val_accuracy: 0.7771
# Epoch 906/1000
# 50000/50000 [==============================] - 3s 52us/sample - loss: 0.0906 - accuracy: 0.9779 - val_loss: 1.0566 - val_accuracy: 0.7768
# Epoch 907/1000
# 50000/50000 [==============================] - 3s 52us/sample - loss: 0.0902 - accuracy: 0.9778 - val_loss: 1.0232 - val_accuracy: 0.7791
# Epoch 908/1000
# 50000/50000 [==============================] - 3s 51us/sample - loss: 0.0881 - accuracy: 0.9787 - val_loss: 1.0498 - val_accuracy: 0.7786
# Epoch 909/1000
# 50000/50000 [==============================] - 3s 52us/sample - loss: 0.0909 - accuracy: 0.9778 - val_loss: 1.0182 - val_accuracy: 0.7813
# Epoch 910/1000
# 50000/50000 [==============================] - 3s 51us/sample - loss: 0.0908 - accuracy: 0.9781 - val_loss: 1.0458 - val_accuracy: 0.7780
# Epoch 911/1000
# 50000/50000 [==============================] - 3s 52us/sample - loss: 0.0922 - accuracy: 0.9775 - val_loss: 1.0935 - val_accuracy: 0.7724
# Epoch 912/1000
# 50000/50000 [==============================] - 3s 52us/sample - loss: 0.0938 - accuracy: 0.9768 - val_loss: 1.0606 - val_accuracy: 0.7751
# Epoch 913/1000
# 50000/50000 [==============================] - 3s 51us/sample - loss: 0.0904 - accuracy: 0.9774 - val_loss: 1.0263 - val_accuracy: 0.7824
# Epoch 914/1000
# 50000/50000 [==============================] - 3s 52us/sample - loss: 0.0909 - accuracy: 0.9782 - val_loss: 1.0242 - val_accuracy: 0.7826
# Epoch 915/1000
# 50000/50000 [==============================] - 3s 51us/sample - loss: 0.0901 - accuracy: 0.9776 - val_loss: 1.0608 - val_accuracy: 0.7748
# Epoch 916/1000
# 50000/50000 [==============================] - 3s 51us/sample - loss: 0.0942 - accuracy: 0.9762 - val_loss: 1.0531 - val_accuracy: 0.7771
# Epoch 917/1000
# 50000/50000 [==============================] - 3s 51us/sample - loss: 0.0918 - accuracy: 0.9775 - val_loss: 1.0547 - val_accuracy: 0.7767
# Epoch 918/1000
# 50000/50000 [==============================] - 3s 51us/sample - loss: 0.0911 - accuracy: 0.9780 - val_loss: 1.0495 - val_accuracy: 0.7766
# Epoch 919/1000
# 50000/50000 [==============================] - 3s 52us/sample - loss: 0.0921 - accuracy: 0.9772 - val_loss: 1.0605 - val_accuracy: 0.7756
# Epoch 920/1000
# 50000/50000 [==============================] - 3s 51us/sample - loss: 0.0922 - accuracy: 0.9775 - val_loss: 1.0664 - val_accuracy: 0.7756
# Epoch 921/1000
# 50000/50000 [==============================] - 3s 52us/sample - loss: 0.0935 - accuracy: 0.9768 - val_loss: 1.0373 - val_accuracy: 0.7789
# Epoch 922/1000
# 50000/50000 [==============================] - 3s 51us/sample - loss: 0.0906 - accuracy: 0.9776 - val_loss: 1.1306 - val_accuracy: 0.7640
# Epoch 923/1000
# 50000/50000 [==============================] - 3s 52us/sample - loss: 0.0890 - accuracy: 0.9784 - val_loss: 1.0276 - val_accuracy: 0.7796
# Epoch 924/1000
# 50000/50000 [==============================] - 3s 51us/sample - loss: 0.0897 - accuracy: 0.9782 - val_loss: 1.0410 - val_accuracy: 0.7805
# Epoch 925/1000
# 50000/50000 [==============================] - 3s 52us/sample - loss: 0.0906 - accuracy: 0.9783 - val_loss: 1.0565 - val_accuracy: 0.7762
# Epoch 926/1000
# 50000/50000 [==============================] - 3s 52us/sample - loss: 0.0900 - accuracy: 0.9779 - val_loss: 1.0816 - val_accuracy: 0.7745
# Epoch 927/1000
# 50000/50000 [==============================] - 3s 51us/sample - loss: 0.0889 - accuracy: 0.9780 - val_loss: 1.0612 - val_accuracy: 0.7721
# Epoch 928/1000
# 50000/50000 [==============================] - 3s 51us/sample - loss: 0.0897 - accuracy: 0.9776 - val_loss: 1.1117 - val_accuracy: 0.7696
# Epoch 929/1000
# 50000/50000 [==============================] - 3s 51us/sample - loss: 0.0882 - accuracy: 0.9783 - val_loss: 1.0479 - val_accuracy: 0.7762
# Epoch 930/1000
# 50000/50000 [==============================] - 3s 51us/sample - loss: 0.0891 - accuracy: 0.9779 - val_loss: 1.0469 - val_accuracy: 0.7754
# Epoch 931/1000
# 50000/50000 [==============================] - 3s 51us/sample - loss: 0.0859 - accuracy: 0.9796 - val_loss: 1.0547 - val_accuracy: 0.7740
# Epoch 932/1000
# 50000/50000 [==============================] - 3s 52us/sample - loss: 0.0898 - accuracy: 0.9776 - val_loss: 1.0710 - val_accuracy: 0.7760
# Epoch 933/1000
# 50000/50000 [==============================] - 3s 52us/sample - loss: 0.0898 - accuracy: 0.9781 - val_loss: 1.0535 - val_accuracy: 0.7822
# Epoch 934/1000
# 50000/50000 [==============================] - 3s 52us/sample - loss: 0.0880 - accuracy: 0.9788 - val_loss: 1.0316 - val_accuracy: 0.7820
# Epoch 935/1000
# 50000/50000 [==============================] - 3s 51us/sample - loss: 0.0880 - accuracy: 0.9786 - val_loss: 1.0576 - val_accuracy: 0.7815
# Epoch 936/1000
# 50000/50000 [==============================] - 3s 51us/sample - loss: 0.0872 - accuracy: 0.9786 - val_loss: 1.1100 - val_accuracy: 0.7661
# Epoch 937/1000
# 50000/50000 [==============================] - 3s 53us/sample - loss: 0.0874 - accuracy: 0.9798 - val_loss: 1.0590 - val_accuracy: 0.7821
# Epoch 938/1000
# 50000/50000 [==============================] - 3s 52us/sample - loss: 0.0881 - accuracy: 0.9794 - val_loss: 1.0460 - val_accuracy: 0.7797
# Epoch 939/1000
# 50000/50000 [==============================] - 3s 51us/sample - loss: 0.0901 - accuracy: 0.9777 - val_loss: 1.0508 - val_accuracy: 0.7815
# Epoch 940/1000
# 50000/50000 [==============================] - 3s 52us/sample - loss: 0.0873 - accuracy: 0.9792 - val_loss: 1.0457 - val_accuracy: 0.7789
# Epoch 941/1000
# 50000/50000 [==============================] - 3s 51us/sample - loss: 0.0918 - accuracy: 0.9775 - val_loss: 1.0428 - val_accuracy: 0.7773
# Epoch 942/1000
# 50000/50000 [==============================] - 3s 51us/sample - loss: 0.0859 - accuracy: 0.9794 - val_loss: 1.0512 - val_accuracy: 0.7780
# Epoch 943/1000
# 50000/50000 [==============================] - 3s 52us/sample - loss: 0.0871 - accuracy: 0.9787 - val_loss: 1.0798 - val_accuracy: 0.7735
# Epoch 944/1000
# 50000/50000 [==============================] - 3s 52us/sample - loss: 0.0856 - accuracy: 0.9796 - val_loss: 1.0419 - val_accuracy: 0.7792
# Epoch 945/1000
# 50000/50000 [==============================] - 3s 52us/sample - loss: 0.0864 - accuracy: 0.9785 - val_loss: 1.0462 - val_accuracy: 0.7777
# Epoch 946/1000
# 50000/50000 [==============================] - 3s 52us/sample - loss: 0.0871 - accuracy: 0.9788 - val_loss: 1.0434 - val_accuracy: 0.7765
# Epoch 947/1000
# 50000/50000 [==============================] - 3s 51us/sample - loss: 0.0883 - accuracy: 0.9787 - val_loss: 1.0621 - val_accuracy: 0.7785
# Epoch 948/1000
# 50000/50000 [==============================] - 3s 51us/sample - loss: 0.0853 - accuracy: 0.9797 - val_loss: 1.0381 - val_accuracy: 0.7815
# Epoch 949/1000
# 50000/50000 [==============================] - 3s 52us/sample - loss: 0.0838 - accuracy: 0.9804 - val_loss: 1.0845 - val_accuracy: 0.7743
# Epoch 950/1000
# 50000/50000 [==============================] - 3s 52us/sample - loss: 0.0858 - accuracy: 0.9799 - val_loss: 1.0433 - val_accuracy: 0.7777
# Epoch 951/1000
# 50000/50000 [==============================] - 3s 51us/sample - loss: 0.0850 - accuracy: 0.9805 - val_loss: 1.0386 - val_accuracy: 0.7793
# Epoch 952/1000
# 50000/50000 [==============================] - 3s 51us/sample - loss: 0.0863 - accuracy: 0.9794 - val_loss: 1.0495 - val_accuracy: 0.7785
# Epoch 953/1000
# 50000/50000 [==============================] - 3s 51us/sample - loss: 0.0880 - accuracy: 0.9785 - val_loss: 1.0574 - val_accuracy: 0.7773
# Epoch 954/1000
# 50000/50000 [==============================] - 3s 51us/sample - loss: 0.0853 - accuracy: 0.9800 - val_loss: 1.0611 - val_accuracy: 0.7768
# Epoch 955/1000
# 50000/50000 [==============================] - 3s 51us/sample - loss: 0.0854 - accuracy: 0.9792 - val_loss: 1.0499 - val_accuracy: 0.7799
# Epoch 956/1000
# 50000/50000 [==============================] - 3s 51us/sample - loss: 0.0860 - accuracy: 0.9791 - val_loss: 1.0617 - val_accuracy: 0.7788
# Epoch 957/1000
# 50000/50000 [==============================] - 3s 52us/sample - loss: 0.0837 - accuracy: 0.9797 - val_loss: 1.0672 - val_accuracy: 0.7699
# Epoch 958/1000
# 50000/50000 [==============================] - 3s 51us/sample - loss: 0.0853 - accuracy: 0.9800 - val_loss: 1.0669 - val_accuracy: 0.7796
# Epoch 959/1000
# 50000/50000 [==============================] - 3s 52us/sample - loss: 0.0820 - accuracy: 0.9812 - val_loss: 1.0625 - val_accuracy: 0.7766
# Epoch 960/1000
# 50000/50000 [==============================] - 3s 51us/sample - loss: 0.0850 - accuracy: 0.9799 - val_loss: 1.0733 - val_accuracy: 0.7729
# Epoch 961/1000
# 50000/50000 [==============================] - 3s 52us/sample - loss: 0.0892 - accuracy: 0.9779 - val_loss: 1.0653 - val_accuracy: 0.7752
# Epoch 962/1000
# 50000/50000 [==============================] - 3s 52us/sample - loss: 0.0852 - accuracy: 0.9799 - val_loss: 1.0802 - val_accuracy: 0.7722
# Epoch 963/1000
# 50000/50000 [==============================] - 3s 51us/sample - loss: 0.0826 - accuracy: 0.9805 - val_loss: 1.1028 - val_accuracy: 0.7716
# Epoch 964/1000
# 50000/50000 [==============================] - 3s 51us/sample - loss: 0.0822 - accuracy: 0.9808 - val_loss: 1.0483 - val_accuracy: 0.7801
# Epoch 965/1000
# 50000/50000 [==============================] - 3s 52us/sample - loss: 0.0848 - accuracy: 0.9796 - val_loss: 1.0453 - val_accuracy: 0.7810
# Epoch 966/1000
# 50000/50000 [==============================] - 3s 52us/sample - loss: 0.0818 - accuracy: 0.9805 - val_loss: 1.0859 - val_accuracy: 0.7730
# Epoch 967/1000
# 50000/50000 [==============================] - 3s 51us/sample - loss: 0.0844 - accuracy: 0.9797 - val_loss: 1.0826 - val_accuracy: 0.7750
# Epoch 968/1000
# 50000/50000 [==============================] - 3s 51us/sample - loss: 0.0844 - accuracy: 0.9800 - val_loss: 1.0427 - val_accuracy: 0.7802
# Epoch 969/1000
# 50000/50000 [==============================] - 3s 51us/sample - loss: 0.0808 - accuracy: 0.9815 - val_loss: 1.0563 - val_accuracy: 0.7795
# Epoch 970/1000
# 50000/50000 [==============================] - 3s 51us/sample - loss: 0.0865 - accuracy: 0.9791 - val_loss: 1.0424 - val_accuracy: 0.7826
# Epoch 971/1000
# 50000/50000 [==============================] - 3s 51us/sample - loss: 0.0820 - accuracy: 0.9807 - val_loss: 1.0793 - val_accuracy: 0.7767
# Epoch 972/1000
# 50000/50000 [==============================] - 3s 51us/sample - loss: 0.0830 - accuracy: 0.9803 - val_loss: 1.1110 - val_accuracy: 0.7687
# Epoch 973/1000
# 50000/50000 [==============================] - 3s 52us/sample - loss: 0.0838 - accuracy: 0.9804 - val_loss: 1.1048 - val_accuracy: 0.7722
# Epoch 974/1000
# 50000/50000 [==============================] - 3s 51us/sample - loss: 0.0825 - accuracy: 0.9805 - val_loss: 1.0528 - val_accuracy: 0.7805
# Epoch 975/1000
# 50000/50000 [==============================] - 3s 51us/sample - loss: 0.0828 - accuracy: 0.9804 - val_loss: 1.0605 - val_accuracy: 0.7799
# Epoch 976/1000
# 50000/50000 [==============================] - 3s 52us/sample - loss: 0.0821 - accuracy: 0.9808 - val_loss: 1.0429 - val_accuracy: 0.7809
# Epoch 977/1000
# 50000/50000 [==============================] - 3s 52us/sample - loss: 0.0809 - accuracy: 0.9814 - val_loss: 1.0686 - val_accuracy: 0.7771
# Epoch 978/1000
# 50000/50000 [==============================] - 3s 51us/sample - loss: 0.0833 - accuracy: 0.9793 - val_loss: 1.0894 - val_accuracy: 0.7730
# Epoch 979/1000
# 50000/50000 [==============================] - 3s 51us/sample - loss: 0.0843 - accuracy: 0.9801 - val_loss: 1.0416 - val_accuracy: 0.7806
# Epoch 980/1000
# 50000/50000 [==============================] - 3s 51us/sample - loss: 0.0823 - accuracy: 0.9810 - val_loss: 1.0359 - val_accuracy: 0.7810
# Epoch 981/1000
# 50000/50000 [==============================] - 3s 51us/sample - loss: 0.0838 - accuracy: 0.9803 - val_loss: 1.0523 - val_accuracy: 0.7792
# Epoch 982/1000
# 50000/50000 [==============================] - 3s 51us/sample - loss: 0.0800 - accuracy: 0.9815 - val_loss: 1.0901 - val_accuracy: 0.7764
# Epoch 983/1000
# 50000/50000 [==============================] - 3s 52us/sample - loss: 0.0823 - accuracy: 0.9806 - val_loss: 1.0449 - val_accuracy: 0.7855
# Epoch 984/1000
# 50000/50000 [==============================] - 3s 52us/sample - loss: 0.0815 - accuracy: 0.9805 - val_loss: 1.0421 - val_accuracy: 0.7804
# Epoch 985/1000
# 50000/50000 [==============================] - 3s 52us/sample - loss: 0.0841 - accuracy: 0.9799 - val_loss: 1.0410 - val_accuracy: 0.7821
# Epoch 986/1000
# 50000/50000 [==============================] - 3s 51us/sample - loss: 0.0845 - accuracy: 0.9796 - val_loss: 1.0566 - val_accuracy: 0.7824
# Epoch 987/1000
# 50000/50000 [==============================] - 3s 51us/sample - loss: 0.0803 - accuracy: 0.9813 - val_loss: 1.0608 - val_accuracy: 0.7786
# Epoch 988/1000
# 50000/50000 [==============================] - 3s 51us/sample - loss: 0.0808 - accuracy: 0.9811 - val_loss: 1.0472 - val_accuracy: 0.7794
# Epoch 989/1000
# 50000/50000 [==============================] - 3s 51us/sample - loss: 0.0835 - accuracy: 0.9805 - val_loss: 1.0636 - val_accuracy: 0.7782
# Epoch 990/1000
# 50000/50000 [==============================] - 3s 51us/sample - loss: 0.0835 - accuracy: 0.9798 - val_loss: 1.1840 - val_accuracy: 0.7601
# Epoch 991/1000
# 50000/50000 [==============================] - 3s 52us/sample - loss: 0.0820 - accuracy: 0.9806 - val_loss: 1.0607 - val_accuracy: 0.7799
# Epoch 992/1000
# 50000/50000 [==============================] - 3s 51us/sample - loss: 0.0833 - accuracy: 0.9808 - val_loss: 1.0365 - val_accuracy: 0.7807
# Epoch 993/1000
# 50000/50000 [==============================] - 3s 51us/sample - loss: 0.0830 - accuracy: 0.9801 - val_loss: 1.0653 - val_accuracy: 0.7792
# Epoch 994/1000
# 50000/50000 [==============================] - 3s 52us/sample - loss: 0.0794 - accuracy: 0.9812 - val_loss: 1.0715 - val_accuracy: 0.7762
# Epoch 995/1000
# 50000/50000 [==============================] - 3s 51us/sample - loss: 0.0824 - accuracy: 0.9805 - val_loss: 1.0683 - val_accuracy: 0.7795
# Epoch 996/1000
# 50000/50000 [==============================] - 3s 52us/sample - loss: 0.0814 - accuracy: 0.9808 - val_loss: 1.1006 - val_accuracy: 0.7722
# Epoch 997/1000
# 50000/50000 [==============================] - 3s 51us/sample - loss: 0.0806 - accuracy: 0.9812 - val_loss: 1.0785 - val_accuracy: 0.7755
# Epoch 998/1000
# 50000/50000 [==============================] - 3s 52us/sample - loss: 0.0794 - accuracy: 0.9820 - val_loss: 1.0699 - val_accuracy: 0.7744
# Epoch 999/1000
# 50000/50000 [==============================] - 3s 52us/sample - loss: 0.0818 - accuracy: 0.9805 - val_loss: 1.1078 - val_accuracy: 0.7696
# Epoch 1000/1000
# 50000/50000 [==============================] - 3s 52us/sample - loss: 0.0768 - accuracy: 0.9831 - val_loss: 1.0762 - val_accuracy: 0.7735

# %% [markdown]
# ##  Visualization of results
# Here, I will visualize the model and the results.. Firstly, the model itself will be shown in graph form. Thereafter, a summary of the statistics and more will be shown.
# Latsly, plots showing accuracy, preccision and more will be made.

# %% [markdown]
# ### Model illustartion
#
# Not only does the graph model illustrates the layers, where we easily can see e.g. the downsampling in the maxpooling layer.  We also see the order of the layers. Here we can check that the layers indeed are in correct order (conv, activation, normalization, pooling ect)..
#
# Similarty, the number of parameters is seen and the shape of especially the output layers.

# %%
plot_model(model, to_file='model_plot_CNNmodel_name.png', show_shapes=True, show_layer_names=True)

# %% [markdown]
# ### Statistics
#
# In the statistics, we see the shape of the model, the number of weights in each layer as well as the total number of trained and non-trained parameters.

# %%
print(model.summary())
# Out:
# Model: "sequential"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# conv2d (Conv2D)              (None, 32, 32, 66)        1848
# _________________________________________________________________
# batch_normalization (BatchNo (None, 32, 32, 66)        264
# _________________________________________________________________
# activation (Activation)      (None, 32, 32, 66)        0
# _________________________________________________________________
# max_pooling2d (MaxPooling2D) (None, 16, 16, 66)        0
# _________________________________________________________________
# dropout (Dropout)            (None, 16, 16, 66)        0
# _________________________________________________________________
# conv2d_1 (Conv2D)            (None, 14, 14, 66)        39270
# _________________________________________________________________
# batch_normalization_1 (Batch (None, 14, 14, 66)        264
# _________________________________________________________________
# activation_1 (Activation)    (None, 14, 14, 66)        0
# _________________________________________________________________
# max_pooling2d_1 (MaxPooling2 (None, 7, 7, 66)          0
# _________________________________________________________________
# conv2d_2 (Conv2D)            (None, 7, 7, 132)         78540
# _________________________________________________________________
# batch_normalization_2 (Batch (None, 7, 7, 132)         528
# _________________________________________________________________
# activation_2 (Activation)    (None, 7, 7, 132)         0
# _________________________________________________________________
# max_pooling2d_2 (MaxPooling2 (None, 3, 3, 132)         0
# _________________________________________________________________
# conv2d_3 (Conv2D)            (None, 3, 3, 132)         156948
# _________________________________________________________________
# batch_normalization_3 (Batch (None, 3, 3, 132)         528
# _________________________________________________________________
# activation_3 (Activation)    (None, 3, 3, 132)         0
# _________________________________________________________________
# max_pooling2d_3 (MaxPooling2 (None, 1, 1, 132)         0
# _________________________________________________________________
# dropout_1 (Dropout)          (None, 1, 1, 132)         0
# _________________________________________________________________
# conv2d_4 (Conv2D)            (None, 1, 1, 132)         156948
# _________________________________________________________________
# batch_normalization_4 (Batch (None, 1, 1, 132)         528
# _________________________________________________________________
# activation_4 (Activation)    (None, 1, 1, 132)         0
# _________________________________________________________________
# dropout_2 (Dropout)          (None, 1, 1, 132)         0
# _________________________________________________________________
# flatten (Flatten)            (None, 132)               0
# _________________________________________________________________
# dense (Dense)                (None, 512)               68096
# _________________________________________________________________
# activation_5 (Activation)    (None, 512)               0
# _________________________________________________________________
# dropout_3 (Dropout)          (None, 512)               0
# _________________________________________________________________
# dense_1 (Dense)              (None, 10)                5130
# =================================================================
# Total params: 508,892
# Trainable params: 507,836
# Non-trainable params: 1,056
# _________________________________________________________________
# None

# %% [markdown]
# ### training and validation accuracy values

# %%
#scores = model.evaluate(x_test, y_test, verbose=1);
#print('Test loss:', scores[0])
#print('Test accuracy:', scores[1])

# %%
# list all data in history
print(history.history.keys());
# Out:
# dict_keys(['loss', 'accuracy', 'val_loss', 'val_accuracy'])

# %%
#can render the model myself..
SVG(model_to_dot(model).create(prog='dot', format='svg'))
#sometime it changes from acc to accuracy, use the list above to write correct names...
if epoch>1:
  # display if theres more than one epoch.
  # Plot training & validation accuracy values
  plt.plot(history.history['accuracy'])
  plt.plot(history.history['val_accuracy'])
  plt.title('Model accuracy')
  plt.ylabel('Accuracy')
  plt.xlabel('Epoch')
  plt.legend(['Train', 'Test'], loc='upper left')
  plt.show()
  
  # Plot training & validation loss values
  plt.plot(history.history['loss'])
  plt.plot(history.history['val_loss'])
  plt.title('Model loss')
  plt.ylabel('Loss')
  plt.xlabel('Epoch')
  plt.legend(['Train', 'Test'], loc='upper left')
  plt.show()

# %% [markdown]
#  here, it can be seen after which epoch (if more are used) the odel starts to overfit..
#
#  Here, it can be seen that after 175 epochs,the model starts to overfit. (Training acc is larger than valdation acc, which should be possible without overfitting, and training loss is less than actual valdation loss)...

# %% [markdown]
# ## Make predictions

# %% [markdown]
# #### Making a classification 'report' and a confusion matrix

# %%
predictions = model.predict(x_test, verbose=0)  #https://www.tensorflow.org/tutorials/keras/classification
# Get most likely class
predicted_classes = np.argmax(predictions, axis=1)



# Have true classes (y_test). in order to make confusion matrix im chaning to Pythn scikit lib. (could use others)
import sklearn.metrics as metrics
#therefore, getting stats in scicit (even if I have it fron keras..)
report = metrics.classification_report(y_test_scivit, predicted_classes)
print(report)
# Out:
#               precision    recall  f1-score   support
#
#            0       0.86      0.72      0.78      1000
#            1       0.91      0.86      0.88      1000
#            2       0.70      0.69      0.69      1000
#            3       0.59      0.61      0.60      1000
#            4       0.67      0.81      0.73      1000
#            5       0.72      0.65      0.68      1000
#            6       0.81      0.84      0.82      1000
#            7       0.84      0.81      0.83      1000
#            8       0.81      0.90      0.85      1000
#            9       0.87      0.84      0.86      1000
#
#     accuracy                           0.77     10000
#    macro avg       0.78      0.77      0.77     10000
# weighted avg       0.78      0.77      0.77     10000

# %% [markdown]
# Making confusion matrix and showing (normalized and not). If values are wanted, remove ''' in function...

# %%
import numpy as np
#Defining classes for confusion matrix plot
classes = np.array(['airplanes', 'cars', 'birds', 'cats', 'deer', 'dogs', 'frogs', 'horses', 'ships', 'trucks']);
# Plot non-normalized confusion matrix
plot_confusion_matrix(y_test_scivit, predicted_classes, classes=classes,title='Confusion matrix, without normalization');
# Plot normalized confusion matrix
plot_confusion_matrix(y_test_scivit, predicted_classes, classes=classes, normalize=True,title='Normalized confusion matrix');
# Out:
# Confusion matrix, without normalization
# [[724  14  65  24  37   8  10  13  80  25]
#  [ 13 859   4   9   6   4   8   2  38  57]
#  [ 25   3 687  48  95  42  56  26  12   6]
#  [  9   3  69 610  77 131  55  19  19   8]
#  [  6   1  45  44 807  18  28  38  11   2]
#  [  3   1  45 176  54 651  20  41   8   1]
#  [  1   4  34  55  47   9 842   2   5   1]
#  [  7   1  26  30  67  37   9 814   2   7]
#  [ 38  15   7  15   8   0   5   1 897  14]
#  [ 19  47   6  16   6   3  10  14  35 844]]
# Normalized confusion matrix
# [[0.724 0.014 0.065 0.024 0.037 0.008 0.01  0.013 0.08  0.025]
#  [0.013 0.859 0.004 0.009 0.006 0.004 0.008 0.002 0.038 0.057]
#  [0.025 0.003 0.687 0.048 0.095 0.042 0.056 0.026 0.012 0.006]
#  [0.009 0.003 0.069 0.61  0.077 0.131 0.055 0.019 0.019 0.008]
#  [0.006 0.001 0.045 0.044 0.807 0.018 0.028 0.038 0.011 0.002]
#  [0.003 0.001 0.045 0.176 0.054 0.651 0.02  0.041 0.008 0.001]
#  [0.001 0.004 0.034 0.055 0.047 0.009 0.842 0.002 0.005 0.001]
#  [0.007 0.001 0.026 0.03  0.067 0.037 0.009 0.814 0.002 0.007]
#  [0.038 0.015 0.007 0.015 0.008 0.    0.005 0.001 0.897 0.014]
#  [0.019 0.047 0.006 0.016 0.006 0.003 0.01  0.014 0.035 0.844]]

# %% [markdown]
# ## Save model and weights for further use.

# %%
from keras.models import load_model
from keras.models import model_from_json
from keras.models import model_from_yaml
import keras
 # creates a HDF5 file 

model.save(model_name) 
# Creates json file, to see architecture
# serialize model to JSON
model_json = model.to_json()
with open("last_try.json", "w") as json_file:
    json_file.write(model_json)
# serialize weights to HDF5
model.save_weights("weights_last_try.h5")
print("Saved model to disk")

print(model_name)
# Out:
# Saved model to disk
# good_prediction.h5

# %%
# !ls
# Out:
#  airplane.jpg
#  deer.jpg
#  frog.jpg
#  good_prediction.h5
#  last_try.h5
#  last_try.json
#  model_200Epochs.json
#  model_plot_CNNmodel_name.png
#  model_plot_CNN.png
#  myCar2.png
#  myCar.jpg
#  sample_data
#  ship.jpg
# 'Users'$'\002''8669364\Desktop\model\model_200Epochs.h5'
# 'Users'$'\002''8669364\Downloads\model_200Epochs.json'
# 'Users'$'\002''8669364\Downloads\weights_200Epochs.h5'
#  weights_last_try.h5

# %%
from keras.preprocessing import image
image2 = image.load_img('airplane.jpg',target_size=(32,32))
plt.imshow(image2)
image2 = image.img_to_array(image2)/255
image2 = np.expand_dims(image2,axis=0)
result = model.predict(image2)
predicted_class_indices=np.argmax(result)
print(result)
classes = np.array(['airplanes', 'cars', 'birds', 'cats', 'deer', 'dogs', 'frogs', 'horses', 'ships', 'trucks']);
print('The picture belongs to class: ',classes[predicted_class_indices])
# Out:
# [[9.99969840e-01 9.32590254e-08 1.42870749e-05 5.83321082e-07
#   1.42193685e-05 1.68098466e-10 2.69992313e-08 2.43393401e-07
#   3.88019401e-07 1.61636748e-07]]
# The picture belongs to class:  airplanes

# %%
from keras.preprocessing import image
image2 = image.load_img('frog.jpg',target_size=(32,32))
plt.imshow(image2)
image2 = image.img_to_array(image2)/255
image2 = np.expand_dims(image2,axis=0)
result = model.predict(image2)
predicted_class_indices=np.argmax(result)
print(result)
classes = np.array(['airplanes', 'cars', 'birds', 'cats', 'deer', 'dogs', 'frogs', 'horses', 'ships', 'trucks']);
print('The picture belongs to class: ',classes[predicted_class_indices])
# Out:
# [[3.6176411e-04 2.2169974e-04 2.1325648e-02 1.6684180e-04 1.6418646e-05
#   5.1447303e-05 9.7757393e-01 1.3520502e-06 2.3717365e-04 4.3648150e-05]]
# The picture belongs to class:  frogs

# %%
image2 = image.load_img('myCar.jpg',target_size=(32,32))
plt.imshow(image2)
image2 = image.img_to_array(image2)/255
image2 = np.expand_dims(image2,axis=0)
result = model.predict(image2)
predicted_class_indices=np.argmax(result,axis=1)
predicted_class_indices=np.argmax(result)
classes = np.array(['airplanes', 'cars', 'birds', 'cats', 'deer', 'dogs', 'frogs', 'horses', 'ships', 'trucks']);
print('The picture belongs to class: ',classes[predicted_class_indices])
# Out:
# The picture belongs to class:  deer

# %%
image2 = image.load_img('ship.jpg',target_size=(32,32))
plt.imshow(image2)
image2 = image.img_to_array(image2)/255
image2 = np.expand_dims(image2,axis=0)
result = model.predict(image2)
predicted_class_indices=np.argmax(result)
classes = np.array(['airplanes', 'cars', 'birds', 'cats', 'deer', 'dogs', 'frogs', 'horses', 'ships', 'trucks']);
print('The picture belongs to class: ',classes[predicted_class_indices])
# Out:
# The picture belongs to class:  ships

# %%
image2 = image.load_img('deer.jpg',target_size=(32,32))
image2 = x_train[105]
plt.imshow(image2)
image2 = image.img_to_array(image2)
image2 = np.expand_dims(image2,axis=0)
result = model.predict(image2)
predicted_class_indices=np.argmax(result)
classes = np.array(['airplanes', 'cars', 'birds', 'cats', 'deer', 'dogs', 'frogs', 'horses', 'ships', 'trucks']);
print('The picture belongs to class: ',classes[predicted_class_indices])
# Out:
# The picture belongs to class:  cars

# %%
image2 = x_train[1]
plt.imshow(image2)
image2 = image.img_to_array(image2)
image2 = np.expand_dims(image2,axis=0)
result = model.predict(image2)
predicted_class_indices=np.argmax(result)
classes = np.array(['airplanes', 'cars', 'birds', 'cats', 'deer', 'dogs', 'frogs', 'horses', 'ships', 'trucks']);
print('The picture belongs to class: ',classes[predicted_class_indices])
# Out:
# The picture belongs to class:  trucks

# %%
image2 = image.load_img('deer.jpg',target_size=(32,32))
plt.imshow(image2)
image2 = image.img_to_array(image2)/255
image2 = np.expand_dims(image2,axis=0)
result = model.predict(image2)
predicted_class_indices=np.argmax(result)
classes = np.array(['airplanes', 'cars', 'birds', 'cats', 'deer', 'dogs', 'frogs', 'horses', 'ships', 'trucks']);
print('The picture belongs to class: ',classes[predicted_class_indices])
# Out:
# The picture belongs to class:  deer
